# %%
from pprint import pprint
from pymongo import MongoClient
import pyfpgrowth
import time

client = MongoClient()
db = client.test

# %% [markdown]
# ### setting constants for calculating the minimum confidence for calculation of rules, minimum star ratings to consider to generate itemset and the city to run the algorithm on.

# %%
minimum_support = 5
minimum_confidence = 0.9
minimum_stars = 3
city='Pittsburgh'

# %%
'''
This method creates a list of business ids which have recived a star above the given threshold,
in the user reviews.
    reviews_cur : a cursor of reviews, for the busness of the selected city.
    type : cursor
    
    min_stars : minimum stars threshold in the reating to consider for a business to added to itemset.
    type : number
    
returns: list of business_ids to get categories from.
'''
def create_business_list_with_weights_by_stars(reviews_cur, min_stars):
    busness_ids_review_counts_dict = {}
    for review in reviews_cur:
        if review['stars'] >= min_stars:
            if review['business_id'] not in busness_ids_review_counts_dict:
                busness_ids_review_counts_dict[review['business_id']] = 1
    return busness_ids_review_counts_dict

# %%
'''
Get business's cursor by given a list of business ids.
Inputs:
        business_id_list : list of business ids.
        type : list
        
Returns:
    cursor of business
'''
def get_category_list_by_business_ids(business_id_list):
    return db.business.find({'business_id': {'$in': business_id_list }})


'''
create catefories list to feed the frequent itemset
Inputs : business_ids
return : itemset list
'''
def create_weighted_categories_list(busness_ids_with_weights):
    categories_fp_input = []
    list_busness_ids = list(busness_ids_with_weights.keys())
    business_cur = get_category_list_by_business_ids(list_busness_ids)
    
    for business in business_cur:
        if business['business_id'] in list_busness_ids:
            lists = [business['categories'] for i in range(busness_ids_with_weights[business['business_id']])]
            categories_fp_input.extend(lists)
    
    return categories_fp_input

# %%
'''
Creates the frequent itemset for patterns and rules
'''
def create_frequent_itemset(reviews_cursor, min_stars):
    business_list = create_business_list_with_weights_by_stars(reviews_cursor, min_stars)
    return create_weighted_categories_list(business_list)


'''
creates patterns using minimum support and itemset
'''
def find_patterns(itemset, min_support):
    return pyfpgrowth.find_frequent_patterns(itemset, min_support)


'''
finds rules from the patterns generated
'''
def find_rules(patterns, min_confidence):
    return pyfpgrowth.generate_association_rules(patterns, min_confidence)

# %%
'''
Returns a cursor from revies by business_ids list
'''
def get_reviews_cursor_by_city(business_ids):
    return db.review.find({'business_id': {'$in': business_ids }})


'''
returns business cursor for the given city
input- city: name of city to get all business for
'''
def get_business_by_city(city):
    return db.business.find({'city': city})

business_cursor = get_business_by_city(city)

def get_reviews_cursor_for_city():
    business_id_list = [x['business_id'] for x in business_cursor]
    return get_reviews_cursor_by_city(business_id_list)

# %%
reviews_for_city = get_reviews_cursor_for_city()
itemset = create_frequent_itemset(reviews_for_city, minimum_stars)

# %%
patterns = find_patterns(itemset, minimum_support)

# %%
rules = find_rules(patterns, minimum_confidence)

# %% [markdown]
# ### print suggestions of busness domains from the rules.

# %%
item_together_counts = {}
for key, rule in rules.items():
    if len(key) > len(rule):
        should_include = str(rule[0])
        items = tuple(i for i in key)
        if items not in item_together_counts:
            item_together_counts[items] = should_include
        else:
            item_together_counts[items].extend(should_include)

for key, val in item_together_counts.items():
    print(str(key) + " ---> " + str(val))
# Out:
# ('Guitar Stores', 'Local Services', 'Musical Instrument Services') ---> ('Musical Instruments & Teachers', 'Shopping')
# ('Guitar Stores', 'Local Services', 'Musical Instruments & Teachers') ---> ('Musical Instrument Services', 'Shopping')
# ('Guitar Stores', 'Musical Instrument Services', 'Musical Instruments & Teachers') ---> ('Local Services', 'Shopping')
# ('Local Services', 'Musical Instrument Services', 'Musical Instruments & Teachers') ---> ('Shopping',)
# ('Guitar Stores', 'Musical Instrument Services', 'Shopping') ---> ('Local Services', 'Musical Instruments & Teachers')
# ('Guitar Stores', 'Musical Instruments & Teachers', 'Shopping') ---> ('Local Services', 'Musical Instrument Services')
# ('Musical Instrument Services', 'Musical Instruments & Teachers', 'Shopping') ---> ('Local Services',)
# ('Guitar Stores', 'Local Services', 'Shopping') ---> ('Musical Instrument Services', 'Musical Instruments & Teachers')
# ('Local Services', 'Musical Instruments & Teachers', 'Shopping') ---> ('Musical Instrument Services',)
# ('Guitar Stores', 'Local Services', 'Musical Instrument Services', 'Musical Instruments & Teachers') ---> ('Shopping',)
# ('Guitar Stores', 'Local Services', 'Musical Instrument Services', 'Shopping') ---> ('Musical Instruments & Teachers',)
# ('Guitar Stores', 'Local Services', 'Musical Instruments & Teachers', 'Shopping') ---> ('Musical Instrument Services',)
# ('Guitar Stores', 'Musical Instrument Services', 'Musical Instruments & Teachers', 'Shopping') ---> ('Local Services',)
# ('Local Services', 'Musical Instrument Services', 'Musical Instruments & Teachers', 'Shopping') ---> ('Guitar Stores',)
# ('Auto Insurance', 'Financial Services', 'Home & Rental Insurance') ---> ('Insurance',)
# ('Auto Insurance', 'Home & Rental Insurance', 'Insurance') ---> ('Financial Services',)
# ('Financial Services', 'Home & Rental Insurance', 'Insurance') ---> ('Auto Insurance',)
# ('Home Services', 'Internet Service Providers', 'Television Service Providers') ---> ('Professional Services',)
# ('Home Services', 'Professional Services', 'Television Service Providers') ---> ('Internet Service Providers',)
# ('Internet Service Providers', 'Professional Services', 'Television Service Providers') ---> ('Home Services',)
# ('Active Life', 'Boxing', 'Gyms') ---> ('Fitness & Instruction',)
# ('Boxing', 'Fitness & Instruction', 'Gyms') ---> ('Active Life',)
# ('Art Classes', 'Arts & Entertainment', 'Paint & Sip') ---> ('Education',)
# ('Art Classes', 'Education', 'Paint & Sip') ---> ('Arts & Entertainment',)
# ('Arts & Entertainment', 'Education', 'Party & Event Planning') ---> ('Event Planning & Services',)
# ('Arts & Entertainment', 'Paint & Sip', 'Party & Event Planning') ---> ('Education', 'Event Planning & Services')
# ('Education', 'Paint & Sip', 'Party & Event Planning') ---> ('Arts & Entertainment', 'Event Planning & Services')
# ('Arts & Entertainment', 'Event Planning & Services', 'Paint & Sip') ---> ('Education', 'Party & Event Planning')
# ('Event Planning & Services', 'Paint & Sip', 'Party & Event Planning') ---> ('Arts & Entertainment', 'Education')
# ('Education', 'Event Planning & Services', 'Paint & Sip') ---> ('Arts & Entertainment', 'Party & Event Planning')
# ('Arts & Entertainment', 'Education', 'Event Planning & Services', 'Paint & Sip') ---> ('Party & Event Planning',)
# ('Arts & Entertainment', 'Education', 'Event Planning & Services', 'Party & Event Planning') ---> ('Paint & Sip',)
# ('Arts & Entertainment', 'Education', 'Paint & Sip', 'Party & Event Planning') ---> ('Event Planning & Services',)
# ('Arts & Entertainment', 'Event Planning & Services', 'Paint & Sip', 'Party & Event Planning') ---> ('Education',)
# ('Education', 'Event Planning & Services', 'Paint & Sip', 'Party & Event Planning') ---> ('Arts & Entertainment',)
# ('Lebanese', 'Mediterranean', 'Middle Eastern') ---> ('Restaurants',)
# ('Lebanese', 'Mediterranean', 'Restaurants') ---> ('Middle Eastern',)
# ('Accountants', 'Financial Services', 'Professional Services') ---> ('Tax Services',)
# ('Accountants', 'Financial Services', 'Tax Services') ---> ('Professional Services',)
# ('Accountants', 'Professional Services', 'Tax Services') ---> ('Financial Services',)
# ('Financial Services', 'Professional Services', 'Tax Services') ---> ('Accountants',)
# ('Active Life', 'Child Care & Day Care', 'Fitness & Instruction') ---> ('Gyms', 'Local Services')
# ('Active Life', 'Child Care & Day Care', 'Gyms') ---> ('Fitness & Instruction', 'Local Services')
# ('Child Care & Day Care', 'Fitness & Instruction', 'Gyms') ---> ('Active Life', 'Local Services')
# ('Child Care & Day Care', 'Fitness & Instruction', 'Local Services') ---> ('Active Life', 'Gyms')
# ('Child Care & Day Care', 'Gyms', 'Local Services') ---> ('Active Life', 'Fitness & Instruction')
# ('Fitness & Instruction', 'Gyms', 'Local Services') ---> ('Active Life',)
# ('Active Life', 'Gyms', 'Local Services') ---> ('Fitness & Instruction',)
# ('Active Life', 'Fitness & Instruction', 'Local Services') ---> ('Gyms',)
# ('Active Life', 'Child Care & Day Care', 'Fitness & Instruction', 'Gyms') ---> ('Local Services',)
# ('Active Life', 'Child Care & Day Care', 'Fitness & Instruction', 'Local Services') ---> ('Gyms',)
# ('Active Life', 'Child Care & Day Care', 'Gyms', 'Local Services') ---> ('Fitness & Instruction',)
# ('Active Life', 'Fitness & Instruction', 'Gyms', 'Local Services') ---> ('Child Care & Day Care',)
# ('Child Care & Day Care', 'Fitness & Instruction', 'Gyms', 'Local Services') ---> ('Active Life',)
# ('Automotive', 'Local Services', 'Truck Rental') ---> ('Self Storage',)
# ('Automotive', 'Self Storage', 'Truck Rental') ---> ('Local Services',)
# ('Local Services', 'Self Storage', 'Truck Rental') ---> ('Automotive',)
# ('Food', 'Pasta Shops', 'Restaurants') ---> ('Specialty Food',)
# ('Pasta Shops', 'Restaurants', 'Specialty Food') ---> ('Food',)
# ('Active Life', 'Fitness & Instruction', 'Nutritionists') ---> ('Health & Medical',)
# ('Active Life', 'Health & Medical', 'Nutritionists') ---> ('Fitness & Instruction',)
# ('Fitness & Instruction', 'Health & Medical', 'Nutritionists') ---> ('Active Life',)
# ('Apartments', 'Commercial Real Estate', 'Home Services') ---> ('Real Estate',)
# ('Apartments', 'Commercial Real Estate', 'Real Estate') ---> ('Home Services',)
# ('Home Cleaning', 'Home Services', 'Office Cleaning') ---> ('Professional Services',)
# ('Home Cleaning', 'Office Cleaning', 'Professional Services') ---> ('Home Services',)
# ('Home Services', 'Office Cleaning', 'Professional Services') ---> ('Home Cleaning',)
# ('Active Life', 'Arts & Entertainment', 'Dance Studios') ---> ('Fitness & Instruction',)
# ('Arts & Entertainment', 'Dance Studios', 'Fitness & Instruction') ---> ('Active Life',)
# ('Beauty & Spas', 'Eyebrow Services', 'Waxing') ---> ('Hair Removal',)
# ('Eyebrow Services', 'Hair Removal', 'Waxing') ---> ('Beauty & Spas',)
# ('Home Cleaning', 'Home Services', 'Junk Removal & Hauling') ---> ('Local Services',)
# ('Home Cleaning', 'Junk Removal & Hauling', 'Local Services') ---> ('Home Services',)
# ('Fitness & Instruction', 'Interval Training Gyms', 'Trainers') ---> ('Active Life', 'Gyms')
# ('Gyms', 'Interval Training Gyms', 'Trainers') ---> ('Active Life', 'Fitness & Instruction')
# ('Active Life', 'Interval Training Gyms', 'Trainers') ---> ('Fitness & Instruction', 'Gyms')
# ('Active Life', 'Fitness & Instruction', 'Interval Training Gyms') ---> ('Gyms',)
# ('Active Life', 'Gyms', 'Interval Training Gyms') ---> ('Fitness & Instruction',)
# ('Fitness & Instruction', 'Gyms', 'Interval Training Gyms') ---> ('Active Life',)
# ('Active Life', 'Fitness & Instruction', 'Interval Training Gyms', 'Trainers') ---> ('Gyms',)
# ('Active Life', 'Gyms', 'Interval Training Gyms', 'Trainers') ---> ('Fitness & Instruction',)
# ('Fitness & Instruction', 'Gyms', 'Interval Training Gyms', 'Trainers') ---> ('Active Life',)
# ('Home & Garden', 'Home Services', 'Interior Design') ---> ('Shopping',)
# ('Home & Garden', 'Interior Design', 'Shopping') ---> ('Home Services',)
# ('Desserts', 'Food', 'Shaved Ice') ---> ('Ice Cream & Frozen Yogurt',)
# ('Desserts', 'Ice Cream & Frozen Yogurt', 'Shaved Ice') ---> ('Food',)
# ('Food', 'Ice Cream & Frozen Yogurt', 'Shaved Ice') ---> ('Desserts',)
# ('Mobile Phone Repair', 'Office Equipment', 'Printing Services') ---> ('IT Services & Computer Repair', 'Local Services', 'Shipping Centers', 'Shopping')
# ('Mobile Phone Repair', 'Office Equipment', 'Shopping') ---> ('IT Services & Computer Repair', 'Local Services', 'Printing Services', 'Shipping Centers')
# ('Mobile Phone Repair', 'Printing Services', 'Shopping') ---> ('IT Services & Computer Repair', 'Local Services', 'Shipping Centers')
# ('Office Equipment', 'Printing Services', 'Shopping') ---> ('IT Services & Computer Repair', 'Local Services', 'Mobile Phone Repair', 'Shipping Centers')
# ('IT Services & Computer Repair', 'Mobile Phone Repair', 'Office Equipment') ---> ('Local Services', 'Printing Services', 'Shipping Centers', 'Shopping')
# ('IT Services & Computer Repair', 'Office Equipment', 'Shopping') ---> ('Local Services', 'Mobile Phone Repair', 'Printing Services', 'Shipping Centers')
# ('Mobile Phone Repair', 'Office Equipment', 'Shipping Centers') ---> ('IT Services & Computer Repair', 'Local Services', 'Printing Services', 'Shopping')
# ('Mobile Phone Repair', 'Shipping Centers', 'Shopping') ---> ('IT Services & Computer Repair', 'Local Services', 'Printing Services')
# ('Office Equipment', 'Shipping Centers', 'Shopping') ---> ('IT Services & Computer Repair', 'Local Services', 'Mobile Phone Repair', 'Printing Services')
# ('Local Services', 'Mobile Phone Repair', 'Office Equipment') ---> ('IT Services & Computer Repair', 'Printing Services', 'Shipping Centers', 'Shopping')
# ('Local Services', 'Office Equipment', 'Shopping') ---> ('IT Services & Computer Repair', 'Mobile Phone Repair', 'Printing Services', 'Shipping Centers')
# ('IT Services & Computer Repair', 'Office Equipment', 'Printing Services') ---> ('Local Services', 'Mobile Phone Repair', 'Shipping Centers', 'Shopping')
# ('IT Services & Computer Repair', 'Printing Services', 'Shopping') ---> ('Local Services', 'Shipping Centers')
# ('Office Equipment', 'Printing Services', 'Shipping Centers') ---> ('IT Services & Computer Repair', 'Local Services', 'Mobile Phone Repair', 'Shopping')
# ('Printing Services', 'Shipping Centers', 'Shopping') ---> ('Local Services',)
# ('Local Services', 'Office Equipment', 'Printing Services') ---> ('IT Services & Computer Repair', 'Mobile Phone Repair', 'Shipping Centers', 'Shopping')
# ('IT Services & Computer Repair', 'Office Equipment', 'Shipping Centers') ---> ('Local Services', 'Mobile Phone Repair', 'Printing Services', 'Shopping')
# ('IT Services & Computer Repair', 'Shipping Centers', 'Shopping') ---> ('Local Services',)
# ('IT Services & Computer Repair', 'Local Services', 'Office Equipment') ---> ('Mobile Phone Repair', 'Printing Services', 'Shipping Centers', 'Shopping')
# ('Local Services', 'Office Equipment', 'Shipping Centers') ---> ('IT Services & Computer Repair', 'Mobile Phone Repair', 'Printing Services', 'Shopping')
# ('Local Services', 'Shipping Centers', 'Shopping') ---> ('IT Services & Computer Repair',)
# ('IT Services & Computer Repair', 'Mobile Phone Repair', 'Printing Services') ---> ('Local Services', 'Shipping Centers', 'Shopping')
# ('Mobile Phone Repair', 'Printing Services', 'Shipping Centers') ---> ('IT Services & Computer Repair', 'Local Services', 'Shopping')
# ('Local Services', 'Mobile Phone Repair', 'Printing Services') ---> ('IT Services & Computer Repair', 'Shipping Centers', 'Shopping')
# ('IT Services & Computer Repair', 'Mobile Phone Repair', 'Shipping Centers') ---> ('Local Services', 'Printing Services', 'Shopping')
# ('Local Services', 'Mobile Phone Repair', 'Shipping Centers') ---> ('IT Services & Computer Repair', 'Printing Services', 'Shopping')
# ('IT Services & Computer Repair', 'Printing Services', 'Shipping Centers') ---> ('Local Services', 'Shopping')
# ('IT Services & Computer Repair', 'Local Services', 'Printing Services') ---> ('Shipping Centers', 'Shopping')
# ('IT Services & Computer Repair', 'Local Services', 'Shipping Centers') ---> ('Shopping',)
# ('IT Services & Computer Repair', 'Mobile Phone Repair', 'Office Equipment', 'Printing Services') ---> ('Local Services', 'Shipping Centers', 'Shopping')
# ('IT Services & Computer Repair', 'Mobile Phone Repair', 'Office Equipment', 'Shopping') ---> ('Local Services', 'Printing Services', 'Shipping Centers')
# ('IT Services & Computer Repair', 'Mobile Phone Repair', 'Printing Services', 'Shopping') ---> ('Local Services', 'Shipping Centers')
# ('IT Services & Computer Repair', 'Office Equipment', 'Printing Services', 'Shopping') ---> ('Local Services', 'Mobile Phone Repair', 'Shipping Centers')
# ('Mobile Phone Repair', 'Office Equipment', 'Printing Services', 'Shopping') ---> ('IT Services & Computer Repair', 'Local Services', 'Shipping Centers')
# ('Mobile Phone Repair', 'Office Equipment', 'Printing Services', 'Shipping Centers') ---> ('IT Services & Computer Repair', 'Local Services', 'Shopping')
# ('Mobile Phone Repair', 'Office Equipment', 'Shipping Centers', 'Shopping') ---> ('IT Services & Computer Repair', 'Local Services', 'Printing Services')
# ('Mobile Phone Repair', 'Printing Services', 'Shipping Centers', 'Shopping') ---> ('IT Services & Computer Repair', 'Local Services')
# ('Office Equipment', 'Printing Services', 'Shipping Centers', 'Shopping') ---> ('IT Services & Computer Repair', 'Local Services', 'Mobile Phone Repair')
# ('Local Services', 'Mobile Phone Repair', 'Office Equipment', 'Printing Services') ---> ('IT Services & Computer Repair', 'Shipping Centers', 'Shopping')
# ('Local Services', 'Mobile Phone Repair', 'Office Equipment', 'Shopping') ---> ('IT Services & Computer Repair', 'Printing Services', 'Shipping Centers')
# ('Local Services', 'Mobile Phone Repair', 'Printing Services', 'Shopping') ---> ('IT Services & Computer Repair', 'Shipping Centers')
# ('Local Services', 'Office Equipment', 'Printing Services', 'Shopping') ---> ('IT Services & Computer Repair', 'Mobile Phone Repair', 'Shipping Centers')
# ('IT Services & Computer Repair', 'Mobile Phone Repair', 'Office Equipment', 'Shipping Centers') ---> ('Local Services', 'Printing Services', 'Shopping')
# ('IT Services & Computer Repair', 'Mobile Phone Repair', 'Shipping Centers', 'Shopping') ---> ('Local Services', 'Printing Services')
# ('IT Services & Computer Repair', 'Office Equipment', 'Shipping Centers', 'Shopping') ---> ('Local Services', 'Mobile Phone Repair', 'Printing Services')
# ('IT Services & Computer Repair', 'Local Services', 'Mobile Phone Repair', 'Office Equipment') ---> ('Printing Services', 'Shipping Centers', 'Shopping')
# ('IT Services & Computer Repair', 'Local Services', 'Office Equipment', 'Shopping') ---> ('Mobile Phone Repair', 'Printing Services', 'Shipping Centers')
# ('Local Services', 'Mobile Phone Repair', 'Office Equipment', 'Shipping Centers') ---> ('IT Services & Computer Repair', 'Printing Services', 'Shopping')
# ('Local Services', 'Mobile Phone Repair', 'Shipping Centers', 'Shopping') ---> ('IT Services & Computer Repair', 'Printing Services')
# ('Local Services', 'Office Equipment', 'Shipping Centers', 'Shopping') ---> ('IT Services & Computer Repair', 'Mobile Phone Repair', 'Printing Services')
# ('IT Services & Computer Repair', 'Office Equipment', 'Printing Services', 'Shipping Centers') ---> ('Local Services', 'Mobile Phone Repair', 'Shopping')
# ('IT Services & Computer Repair', 'Printing Services', 'Shipping Centers', 'Shopping') ---> ('Local Services',)
# ('IT Services & Computer Repair', 'Local Services', 'Office Equipment', 'Printing Services') ---> ('Mobile Phone Repair', 'Shipping Centers', 'Shopping')
# ('IT Services & Computer Repair', 'Local Services', 'Printing Services', 'Shopping') ---> ('Shipping Centers',)
# ('Local Services', 'Office Equipment', 'Printing Services', 'Shipping Centers') ---> ('IT Services & Computer Repair', 'Mobile Phone Repair', 'Shopping')
# ('Local Services', 'Printing Services', 'Shipping Centers', 'Shopping') ---> ('IT Services & Computer Repair',)
# ('IT Services & Computer Repair', 'Local Services', 'Office Equipment', 'Shipping Centers') ---> ('Mobile Phone Repair', 'Printing Services', 'Shopping')
# ('IT Services & Computer Repair', 'Local Services', 'Shipping Centers', 'Shopping') ---> ('Printing Services',)
# ('IT Services & Computer Repair', 'Mobile Phone Repair', 'Printing Services', 'Shipping Centers') ---> ('Local Services', 'Shopping')
# ('IT Services & Computer Repair', 'Local Services', 'Mobile Phone Repair', 'Printing Services') ---> ('Shipping Centers', 'Shopping')
# ('Local Services', 'Mobile Phone Repair', 'Printing Services', 'Shipping Centers') ---> ('IT Services & Computer Repair', 'Shopping')
# ('IT Services & Computer Repair', 'Local Services', 'Mobile Phone Repair', 'Shipping Centers') ---> ('Printing Services', 'Shopping')
# ('IT Services & Computer Repair', 'Local Services', 'Printing Services', 'Shipping Centers') ---> ('Shopping',)
# ('IT Services & Computer Repair', 'Mobile Phone Repair', 'Office Equipment', 'Printing Services', 'Shipping Centers') ---> ('Local Services', 'Shopping')
# ('IT Services & Computer Repair', 'Mobile Phone Repair', 'Office Equipment', 'Printing Services', 'Shopping') ---> ('Local Services', 'Shipping Centers')
# ('IT Services & Computer Repair', 'Mobile Phone Repair', 'Office Equipment', 'Shipping Centers', 'Shopping') ---> ('Local Services', 'Printing Services')
# ('IT Services & Computer Repair', 'Mobile Phone Repair', 'Printing Services', 'Shipping Centers', 'Shopping') ---> ('Local Services',)
# ('IT Services & Computer Repair', 'Office Equipment', 'Printing Services', 'Shipping Centers', 'Shopping') ---> ('Local Services', 'Mobile Phone Repair')
# ('Mobile Phone Repair', 'Office Equipment', 'Printing Services', 'Shipping Centers', 'Shopping') ---> ('IT Services & Computer Repair', 'Local Services')
# ('IT Services & Computer Repair', 'Local Services', 'Mobile Phone Repair', 'Office Equipment', 'Printing Services') ---> ('Shipping Centers', 'Shopping')
# ('IT Services & Computer Repair', 'Local Services', 'Mobile Phone Repair', 'Office Equipment', 'Shopping') ---> ('Printing Services', 'Shipping Centers')
# ('IT Services & Computer Repair', 'Local Services', 'Mobile Phone Repair', 'Printing Services', 'Shopping') ---> ('Shipping Centers',)
# ('IT Services & Computer Repair', 'Local Services', 'Office Equipment', 'Printing Services', 'Shopping') ---> ('Mobile Phone Repair', 'Shipping Centers')
# ('Local Services', 'Mobile Phone Repair', 'Office Equipment', 'Printing Services', 'Shopping') ---> ('IT Services & Computer Repair', 'Shipping Centers')
# ('Local Services', 'Mobile Phone Repair', 'Office Equipment', 'Printing Services', 'Shipping Centers') ---> ('IT Services & Computer Repair', 'Shopping')
# ('Local Services', 'Mobile Phone Repair', 'Office Equipment', 'Shipping Centers', 'Shopping') ---> ('IT Services & Computer Repair', 'Printing Services')
# ('Local Services', 'Mobile Phone Repair', 'Printing Services', 'Shipping Centers', 'Shopping') ---> ('IT Services & Computer Repair',)
# ('Local Services', 'Office Equipment', 'Printing Services', 'Shipping Centers', 'Shopping') ---> ('IT Services & Computer Repair', 'Mobile Phone Repair')
# ('IT Services & Computer Repair', 'Local Services', 'Mobile Phone Repair', 'Office Equipment', 'Shipping Centers') ---> ('Printing Services', 'Shopping')
# ('IT Services & Computer Repair', 'Local Services', 'Mobile Phone Repair', 'Shipping Centers', 'Shopping') ---> ('Printing Services',)
# ('IT Services & Computer Repair', 'Local Services', 'Office Equipment', 'Shipping Centers', 'Shopping') ---> ('Mobile Phone Repair', 'Printing Services')
# ('IT Services & Computer Repair', 'Local Services', 'Office Equipment', 'Printing Services', 'Shipping Centers') ---> ('Mobile Phone Repair', 'Shopping')
# ('IT Services & Computer Repair', 'Local Services', 'Printing Services', 'Shipping Centers', 'Shopping') ---> ('Mobile Phone Repair',)
# ('IT Services & Computer Repair', 'Local Services', 'Mobile Phone Repair', 'Printing Services', 'Shipping Centers') ---> ('Shopping',)
# ('IT Services & Computer Repair', 'Local Services', 'Mobile Phone Repair', 'Office Equipment', 'Printing Services', 'Shipping Centers') ---> ('Shopping',)
# ('IT Services & Computer Repair', 'Local Services', 'Mobile Phone Repair', 'Office Equipment', 'Printing Services', 'Shopping') ---> ('Shipping Centers',)
# ('IT Services & Computer Repair', 'Local Services', 'Mobile Phone Repair', 'Office Equipment', 'Shipping Centers', 'Shopping') ---> ('Printing Services',)
# ('IT Services & Computer Repair', 'Local Services', 'Mobile Phone Repair', 'Printing Services', 'Shipping Centers', 'Shopping') ---> ('Office Equipment',)
# ('IT Services & Computer Repair', 'Local Services', 'Office Equipment', 'Printing Services', 'Shipping Centers', 'Shopping') ---> ('Mobile Phone Repair',)
# ('IT Services & Computer Repair', 'Mobile Phone Repair', 'Office Equipment', 'Printing Services', 'Shipping Centers', 'Shopping') ---> ('Local Services',)
# ('Local Services', 'Mobile Phone Repair', 'Office Equipment', 'Printing Services', 'Shipping Centers', 'Shopping') ---> ('IT Services & Computer Repair',)
# ('Mags', 'Music & DVDs', 'Vinyl Records') ---> ('Books', 'Music & Video', 'Shopping')
# ('Music & DVDs', 'Music & Video', 'Vinyl Records') ---> ('Books', 'Mags', 'Shopping')
# ('Books', 'Music & DVDs', 'Vinyl Records') ---> ('Mags', 'Music & Video', 'Shopping')
# ('Music & DVDs', 'Shopping', 'Vinyl Records') ---> ('Books', 'Mags', 'Music & Video')
# ('Books', 'Mags', 'Vinyl Records') ---> ('Music & Video', 'Shopping')
# ('Books', 'Music & Video', 'Vinyl Records') ---> ('Mags', 'Shopping')
# ('Mags', 'Music & Video', 'Vinyl Records') ---> ('Books', 'Shopping')
# ('Mags', 'Shopping', 'Vinyl Records') ---> ('Books', 'Music & Video')
# ('Music & Video', 'Shopping', 'Vinyl Records') ---> ('Books', 'Mags')
# ('Books', 'Shopping', 'Vinyl Records') ---> ('Mags', 'Music & Video')
# ('Books', 'Mags', 'Music & DVDs', 'Vinyl Records') ---> ('Music & Video', 'Shopping')
# ('Books', 'Music & DVDs', 'Music & Video', 'Vinyl Records') ---> ('Mags', 'Shopping')
# ('Mags', 'Music & DVDs', 'Music & Video', 'Vinyl Records') ---> ('Books', 'Shopping')
# ('Mags', 'Music & DVDs', 'Shopping', 'Vinyl Records') ---> ('Books', 'Music & Video')
# ('Music & DVDs', 'Music & Video', 'Shopping', 'Vinyl Records') ---> ('Books', 'Mags')
# ('Books', 'Music & DVDs', 'Shopping', 'Vinyl Records') ---> ('Mags', 'Music & Video')
# ('Books', 'Mags', 'Music & Video', 'Vinyl Records') ---> ('Shopping',)
# ('Books', 'Mags', 'Shopping', 'Vinyl Records') ---> ('Music & Video',)
# ('Books', 'Music & Video', 'Shopping', 'Vinyl Records') ---> ('Mags',)
# ('Mags', 'Music & Video', 'Shopping', 'Vinyl Records') ---> ('Books',)
# ('Books', 'Mags', 'Music & DVDs', 'Music & Video', 'Vinyl Records') ---> ('Shopping',)
# ('Books', 'Mags', 'Music & DVDs', 'Shopping', 'Vinyl Records') ---> ('Music & Video',)
# ('Books', 'Music & DVDs', 'Music & Video', 'Shopping', 'Vinyl Records') ---> ('Mags',)
# ('Mags', 'Music & DVDs', 'Music & Video', 'Shopping', 'Vinyl Records') ---> ('Books',)
# ('Active Life', 'Martial Arts', 'Trainers') ---> ('Fitness & Instruction',)
# ('Fitness & Instruction', 'Martial Arts', 'Trainers') ---> ('Active Life',)
# ('Active Life', 'Gyms', 'Weight Loss Centers') ---> ('Fitness & Instruction', 'Health & Medical')
# ('Fitness & Instruction', 'Gyms', 'Weight Loss Centers') ---> ('Active Life', 'Health & Medical')
# ('Gyms', 'Health & Medical', 'Weight Loss Centers') ---> ('Active Life', 'Fitness & Instruction')
# ('Active Life', 'Fitness & Instruction', 'Weight Loss Centers') ---> ('Health & Medical',)
# ('Active Life', 'Health & Medical', 'Weight Loss Centers') ---> ('Fitness & Instruction',)
# ('Fitness & Instruction', 'Health & Medical', 'Weight Loss Centers') ---> ('Active Life',)
# ('Active Life', 'Fitness & Instruction', 'Gyms', 'Weight Loss Centers') ---> ('Health & Medical',)
# ('Active Life', 'Gyms', 'Health & Medical', 'Weight Loss Centers') ---> ('Fitness & Instruction',)
# ('Fitness & Instruction', 'Gyms', 'Health & Medical', 'Weight Loss Centers') ---> ('Active Life',)
# ('Beauty & Spas', 'Health & Medical', 'Reflexology') ---> ('Massage',)
# ('Beauty & Spas', 'Massage', 'Reflexology') ---> ('Health & Medical',)
# ('Health & Medical', 'Massage', 'Reflexology') ---> ('Beauty & Spas',)
# ('Electronics Repair', 'IT Services & Computer Repair', 'Local Services') ---> ('Mobile Phone Repair',)
# ('Electronics Repair', 'IT Services & Computer Repair', 'Mobile Phone Repair') ---> ('Local Services',)
# ('Electronics Repair', 'Local Services', 'Mobile Phone Repair') ---> ('IT Services & Computer Repair',)
# ('Books', 'Comic Books', 'Mags') ---> ('Music & Video', 'Shopping')
# ('Books', 'Comic Books', 'Music & Video') ---> ('Mags', 'Shopping')
# ('Comic Books', 'Mags', 'Music & Video') ---> ('Books', 'Shopping')
# ('Comic Books', 'Mags', 'Shopping') ---> ('Books', 'Music & Video')
# ('Comic Books', 'Music & Video', 'Shopping') ---> ('Books', 'Mags')
# ('Books', 'Comic Books', 'Shopping') ---> ('Mags', 'Music & Video')
# ('Books', 'Comic Books', 'Mags', 'Music & Video') ---> ('Shopping',)
# ('Books', 'Comic Books', 'Mags', 'Shopping') ---> ('Music & Video',)
# ('Books', 'Comic Books', 'Music & Video', 'Shopping') ---> ('Mags',)
# ('Comic Books', 'Mags', 'Music & Video', 'Shopping') ---> ('Books',)
# ('Boot Camps', 'Gyms', 'Trainers') ---> ('Active Life', 'Fitness & Instruction')
# ('Active Life', 'Boot Camps', 'Trainers') ---> ('Fitness & Instruction',)
# ('Boot Camps', 'Fitness & Instruction', 'Trainers') ---> ('Active Life',)
# ('Active Life', 'Boot Camps', 'Gyms', 'Trainers') ---> ('Fitness & Instruction',)
# ('Boot Camps', 'Fitness & Instruction', 'Gyms', 'Trainers') ---> ('Active Life',)
# ('Active Life', 'Boot Camps', 'Gyms') ---> ('Fitness & Instruction',)
# ('Boot Camps', 'Fitness & Instruction', 'Gyms') ---> ('Active Life',)
# ('Cosmetic Dentists', 'Dentists', 'Endodontists') ---> ('General Dentistry', 'Health & Medical')
# ('Cosmetic Dentists', 'Endodontists', 'General Dentistry') ---> ('Dentists', 'Health & Medical')
# ('Cosmetic Dentists', 'Endodontists', 'Health & Medical') ---> ('Dentists', 'General Dentistry')
# ('Dentists', 'Endodontists', 'General Dentistry') ---> ('Health & Medical',)
# ('Endodontists', 'General Dentistry', 'Health & Medical') ---> ('Dentists',)
# ('Cosmetic Dentists', 'Dentists', 'Endodontists', 'General Dentistry') ---> ('Health & Medical',)
# ('Cosmetic Dentists', 'Dentists', 'Endodontists', 'Health & Medical') ---> ('General Dentistry',)
# ('Cosmetic Dentists', 'Endodontists', 'General Dentistry', 'Health & Medical') ---> ('Dentists',)
# ('Food', 'Food Stands', 'Food Trucks') ---> ('Restaurants',)
# ('Food Stands', 'Food Trucks', 'Restaurants') ---> ('Food',)
# ('Beauty & Spas', 'Laser Hair Removal', 'Skin Care') ---> ('Hair Removal', 'Health & Medical')
# ('Health & Medical', 'Laser Hair Removal', 'Skin Care') ---> ('Beauty & Spas', 'Hair Removal')
# ('Hair Removal', 'Laser Hair Removal', 'Skin Care') ---> ('Beauty & Spas', 'Health & Medical')
# ('Beauty & Spas', 'Hair Removal', 'Laser Hair Removal', 'Skin Care') ---> ('Health & Medical',)
# ('Beauty & Spas', 'Health & Medical', 'Laser Hair Removal', 'Skin Care') ---> ('Hair Removal',)
# ('Hair Removal', 'Health & Medical', 'Laser Hair Removal', 'Skin Care') ---> ('Beauty & Spas',)
# ('Beauty & Spas', 'Laser Hair Removal', 'Medical Spas') ---> ('Hair Removal', 'Health & Medical')
# ('Health & Medical', 'Laser Hair Removal', 'Medical Spas') ---> ('Beauty & Spas', 'Hair Removal')
# ('Hair Removal', 'Laser Hair Removal', 'Medical Spas') ---> ('Beauty & Spas', 'Health & Medical')
# ('Beauty & Spas', 'Hair Removal', 'Laser Hair Removal', 'Medical Spas') ---> ('Health & Medical',)
# ('Beauty & Spas', 'Health & Medical', 'Laser Hair Removal', 'Medical Spas') ---> ('Hair Removal',)
# ('Hair Removal', 'Health & Medical', 'Laser Hair Removal', 'Medical Spas') ---> ('Beauty & Spas',)
# ('Beauty & Spas', 'Cosmetic Surgeons', 'Laser Hair Removal') ---> ('Doctors', 'Hair Removal', 'Health & Medical')
# ('Cosmetic Surgeons', 'Health & Medical', 'Laser Hair Removal') ---> ('Beauty & Spas', 'Doctors', 'Hair Removal')
# ('Cosmetic Surgeons', 'Hair Removal', 'Laser Hair Removal') ---> ('Beauty & Spas', 'Doctors', 'Health & Medical')
# ('Beauty & Spas', 'Cosmetic Surgeons', 'Hair Removal', 'Laser Hair Removal') ---> ('Doctors', 'Health & Medical')
# ('Beauty & Spas', 'Cosmetic Surgeons', 'Health & Medical', 'Laser Hair Removal') ---> ('Doctors', 'Hair Removal')
# ('Cosmetic Surgeons', 'Hair Removal', 'Health & Medical', 'Laser Hair Removal') ---> ('Beauty & Spas', 'Doctors')
# ('Cosmetic Surgeons', 'Doctors', 'Laser Hair Removal') ---> ('Beauty & Spas', 'Hair Removal', 'Health & Medical')
# ('Doctors', 'Health & Medical', 'Laser Hair Removal') ---> ('Beauty & Spas', 'Cosmetic Surgeons', 'Hair Removal')
# ('Beauty & Spas', 'Doctors', 'Laser Hair Removal') ---> ('Cosmetic Surgeons', 'Hair Removal', 'Health & Medical')
# ('Doctors', 'Hair Removal', 'Laser Hair Removal') ---> ('Beauty & Spas', 'Cosmetic Surgeons', 'Health & Medical')
# ('Beauty & Spas', 'Cosmetic Surgeons', 'Doctors', 'Laser Hair Removal') ---> ('Hair Removal', 'Health & Medical')
# ('Beauty & Spas', 'Doctors', 'Health & Medical', 'Laser Hair Removal') ---> ('Cosmetic Surgeons', 'Hair Removal')
# ('Cosmetic Surgeons', 'Doctors', 'Health & Medical', 'Laser Hair Removal') ---> ('Beauty & Spas', 'Hair Removal')
# ('Cosmetic Surgeons', 'Doctors', 'Hair Removal', 'Laser Hair Removal') ---> ('Beauty & Spas', 'Health & Medical')
# ('Doctors', 'Hair Removal', 'Health & Medical', 'Laser Hair Removal') ---> ('Beauty & Spas', 'Cosmetic Surgeons')
# ('Beauty & Spas', 'Doctors', 'Hair Removal', 'Laser Hair Removal') ---> ('Cosmetic Surgeons', 'Health & Medical')
# ('Beauty & Spas', 'Cosmetic Surgeons', 'Doctors', 'Hair Removal', 'Laser Hair Removal') ---> ('Health & Medical',)
# ('Beauty & Spas', 'Cosmetic Surgeons', 'Doctors', 'Health & Medical', 'Laser Hair Removal') ---> ('Hair Removal',)
# ('Beauty & Spas', 'Cosmetic Surgeons', 'Hair Removal', 'Health & Medical', 'Laser Hair Removal') ---> ('Doctors',)
# ('Beauty & Spas', 'Doctors', 'Hair Removal', 'Health & Medical', 'Laser Hair Removal') ---> ('Cosmetic Surgeons',)
# ('Cosmetic Surgeons', 'Doctors', 'Hair Removal', 'Health & Medical', 'Laser Hair Removal') ---> ('Beauty & Spas',)
# ('Beauty & Spas', 'Hair Removal', 'Laser Hair Removal') ---> ('Health & Medical',)
# ('Beauty & Spas', 'Health & Medical', 'Laser Hair Removal') ---> ('Hair Removal',)
# ('Hair Removal', 'Health & Medical', 'Laser Hair Removal') ---> ('Beauty & Spas',)
# ('Beauty & Spas', 'Blow Dry/Out Services', 'Hair Extensions') ---> ('Hair Salons',)
# ('Blow Dry/Out Services', 'Hair Extensions', 'Hair Salons') ---> ('Beauty & Spas',)
# ('Beauty & Spas', 'Blow Dry/Out Services', 'Hair Stylists') ---> ('Hair Salons',)
# ('Blow Dry/Out Services', 'Hair Salons', 'Hair Stylists') ---> ('Beauty & Spas',)
# ('Dry Cleaning', 'Dry Cleaning & Laundry', 'Laundry Services') ---> ('Local Services', 'Sewing & Alterations')
# ('Dry Cleaning', 'Dry Cleaning & Laundry', 'Sewing & Alterations') ---> ('Laundry Services', 'Local Services')
# ('Dry Cleaning', 'Laundry Services', 'Sewing & Alterations') ---> ('Dry Cleaning & Laundry', 'Local Services')
# ('Dry Cleaning', 'Laundry Services', 'Local Services') ---> ('Dry Cleaning & Laundry', 'Sewing & Alterations')
# ('Dry Cleaning', 'Local Services', 'Sewing & Alterations') ---> ('Dry Cleaning & Laundry', 'Laundry Services')
# ('Dry Cleaning', 'Dry Cleaning & Laundry', 'Local Services') ---> ('Laundry Services', 'Sewing & Alterations')
# ('Dry Cleaning', 'Dry Cleaning & Laundry', 'Laundry Services', 'Local Services') ---> ('Sewing & Alterations',)
# ('Dry Cleaning', 'Dry Cleaning & Laundry', 'Laundry Services', 'Sewing & Alterations') ---> ('Local Services',)
# ('Dry Cleaning', 'Dry Cleaning & Laundry', 'Local Services', 'Sewing & Alterations') ---> ('Laundry Services',)
# ('Dry Cleaning', 'Laundry Services', 'Local Services', 'Sewing & Alterations') ---> ('Dry Cleaning & Laundry',)
# ('Gyms', 'Sports Clubs', 'Yoga') ---> ('Active Life', 'Fitness & Instruction', 'Trainers')
# ('Sports Clubs', 'Trainers', 'Yoga') ---> ('Active Life', 'Fitness & Instruction', 'Gyms')
# ('Fitness & Instruction', 'Sports Clubs', 'Yoga') ---> ('Active Life', 'Gyms', 'Trainers')
# ('Active Life', 'Sports Clubs', 'Yoga') ---> ('Fitness & Instruction', 'Gyms', 'Trainers')
# ('Fitness & Instruction', 'Gyms', 'Sports Clubs') ---> ('Active Life', 'Trainers')
# ('Fitness & Instruction', 'Sports Clubs', 'Trainers') ---> ('Active Life', 'Gyms')
# ('Gyms', 'Sports Clubs', 'Trainers') ---> ('Active Life', 'Fitness & Instruction')
# ('Active Life', 'Gyms', 'Sports Clubs') ---> ('Fitness & Instruction', 'Trainers')
# ('Active Life', 'Sports Clubs', 'Trainers') ---> ('Fitness & Instruction', 'Gyms')
# ('Active Life', 'Fitness & Instruction', 'Sports Clubs') ---> ('Gyms', 'Trainers')
# ('Fitness & Instruction', 'Gyms', 'Sports Clubs', 'Yoga') ---> ('Active Life', 'Trainers')
# ('Fitness & Instruction', 'Sports Clubs', 'Trainers', 'Yoga') ---> ('Active Life', 'Gyms')
# ('Gyms', 'Sports Clubs', 'Trainers', 'Yoga') ---> ('Active Life', 'Fitness & Instruction')
# ('Active Life', 'Gyms', 'Sports Clubs', 'Yoga') ---> ('Fitness & Instruction', 'Trainers')
# ('Active Life', 'Sports Clubs', 'Trainers', 'Yoga') ---> ('Fitness & Instruction', 'Gyms')
# ('Active Life', 'Fitness & Instruction', 'Sports Clubs', 'Yoga') ---> ('Gyms', 'Trainers')
# ('Active Life', 'Fitness & Instruction', 'Gyms', 'Sports Clubs') ---> ('Trainers',)
# ('Active Life', 'Fitness & Instruction', 'Sports Clubs', 'Trainers') ---> ('Gyms',)
# ('Active Life', 'Gyms', 'Sports Clubs', 'Trainers') ---> ('Fitness & Instruction',)
# ('Fitness & Instruction', 'Gyms', 'Sports Clubs', 'Trainers') ---> ('Active Life',)
# ('Active Life', 'Fitness & Instruction', 'Gyms', 'Sports Clubs', 'Yoga') ---> ('Trainers',)
# ('Active Life', 'Fitness & Instruction', 'Sports Clubs', 'Trainers', 'Yoga') ---> ('Gyms',)
# ('Active Life', 'Gyms', 'Sports Clubs', 'Trainers', 'Yoga') ---> ('Fitness & Instruction',)
# ('Fitness & Instruction', 'Gyms', 'Sports Clubs', 'Trainers', 'Yoga') ---> ('Active Life',)
# ('Bed & Breakfast', 'Event Planning & Services', 'Hotels') ---> ('Hotels & Travel',)
# ('Bed & Breakfast', 'Event Planning & Services', 'Hotels & Travel') ---> ('Hotels',)
# ('Bed & Breakfast', 'Hotels', 'Hotels & Travel') ---> ('Event Planning & Services',)
# ('Bars', 'Food', 'Hookah Bars') ---> ('Nightlife',)
# ('Food', 'Hookah Bars', 'Nightlife') ---> ('Bars',)
# ('Bars', 'Hookah Bars', 'Restaurants') ---> ('Nightlife',)
# ('Hookah Bars', 'Nightlife', 'Restaurants') ---> ('Bars',)
# ('Fashion', 'Formal Wear', "Men's Clothing") ---> ('Shopping',)
# ('Formal Wear', "Men's Clothing", 'Shopping') ---> ('Fashion',)
# ('Electronics', 'Home Services', 'Internet Service Providers') ---> ('Mobile Phones', 'Professional Services', 'Shopping')
# ('Electronics', 'Home Services', 'Professional Services') ---> ('Mobile Phones', 'Shopping')
# ('Electronics', 'Internet Service Providers', 'Professional Services') ---> ('Home Services', 'Mobile Phones', 'Shopping')
# ('Home Services', 'Internet Service Providers', 'Mobile Phones') ---> ('Electronics', 'Professional Services', 'Shopping')
# ('Home Services', 'Mobile Phones', 'Professional Services') ---> ('Shopping',)
# ('Internet Service Providers', 'Mobile Phones', 'Professional Services') ---> ('Electronics', 'Home Services', 'Shopping')
# ('Home Services', 'Internet Service Providers', 'Shopping') ---> ('Electronics', 'Mobile Phones', 'Professional Services')
# ('Internet Service Providers', 'Professional Services', 'Shopping') ---> ('Electronics', 'Home Services', 'Mobile Phones')
# ('Electronics', 'Internet Service Providers', 'Mobile Phones') ---> ('Home Services', 'Professional Services', 'Shopping')
# ('Electronics', 'Mobile Phones', 'Professional Services') ---> ('Home Services', 'Shopping')
# ('Electronics', 'Internet Service Providers', 'Shopping') ---> ('Home Services', 'Mobile Phones', 'Professional Services')
# ('Electronics', 'Professional Services', 'Shopping') ---> ('Home Services', 'Mobile Phones')
# ('Internet Service Providers', 'Mobile Phones', 'Shopping') ---> ('Electronics', 'Home Services', 'Professional Services')
# ('Mobile Phones', 'Professional Services', 'Shopping') ---> ('Home Services',)
# ('Electronics', 'Home Services', 'Mobile Phones') ---> ('Shopping',)
# ('Home Services', 'Mobile Phones', 'Shopping') ---> ('Professional Services',)
# ('Electronics', 'Home Services', 'Internet Service Providers', 'Mobile Phones') ---> ('Professional Services', 'Shopping')
# ('Electronics', 'Home Services', 'Internet Service Providers', 'Professional Services') ---> ('Mobile Phones', 'Shopping')
# ('Electronics', 'Home Services', 'Mobile Phones', 'Professional Services') ---> ('Shopping',)
# ('Electronics', 'Internet Service Providers', 'Mobile Phones', 'Professional Services') ---> ('Home Services', 'Shopping')
# ('Home Services', 'Internet Service Providers', 'Mobile Phones', 'Professional Services') ---> ('Electronics', 'Shopping')
# ('Electronics', 'Home Services', 'Internet Service Providers', 'Shopping') ---> ('Mobile Phones', 'Professional Services')
# ('Electronics', 'Home Services', 'Professional Services', 'Shopping') ---> ('Mobile Phones',)
# ('Electronics', 'Internet Service Providers', 'Professional Services', 'Shopping') ---> ('Home Services', 'Mobile Phones')
# ('Home Services', 'Internet Service Providers', 'Professional Services', 'Shopping') ---> ('Electronics', 'Mobile Phones')
# ('Home Services', 'Internet Service Providers', 'Mobile Phones', 'Shopping') ---> ('Electronics', 'Professional Services')
# ('Home Services', 'Mobile Phones', 'Professional Services', 'Shopping') ---> ('Electronics',)
# ('Internet Service Providers', 'Mobile Phones', 'Professional Services', 'Shopping') ---> ('Electronics', 'Home Services')
# ('Electronics', 'Internet Service Providers', 'Mobile Phones', 'Shopping') ---> ('Home Services', 'Professional Services')
# ('Electronics', 'Mobile Phones', 'Professional Services', 'Shopping') ---> ('Home Services',)
# ('Electronics', 'Home Services', 'Mobile Phones', 'Shopping') ---> ('Professional Services',)
# ('Electronics', 'Home Services', 'Internet Service Providers', 'Mobile Phones', 'Professional Services') ---> ('Shopping',)
# ('Electronics', 'Home Services', 'Internet Service Providers', 'Mobile Phones', 'Shopping') ---> ('Professional Services',)
# ('Electronics', 'Home Services', 'Internet Service Providers', 'Professional Services', 'Shopping') ---> ('Mobile Phones',)
# ('Electronics', 'Home Services', 'Mobile Phones', 'Professional Services', 'Shopping') ---> ('Internet Service Providers',)
# ('Electronics', 'Internet Service Providers', 'Mobile Phones', 'Professional Services', 'Shopping') ---> ('Home Services',)
# ('Home Services', 'Internet Service Providers', 'Mobile Phones', 'Professional Services', 'Shopping') ---> ('Electronics',)
# ('Local Services', 'Notaries', 'Printing Services') ---> ('Shipping Centers',)
# ('Local Services', 'Notaries', 'Shipping Centers') ---> ('Printing Services',)
# ('Notaries', 'Printing Services', 'Shipping Centers') ---> ('Local Services',)
# ('Food', 'Fruits & Veggies', 'Grocery') ---> ('Specialty Food',)
# ('Fruits & Veggies', 'Grocery', 'Specialty Food') ---> ('Food',)
# ('Active Life', 'Arcades', 'Event Planning & Services') ---> ('Arts & Entertainment',)
# ('Arcades', 'Arts & Entertainment', 'Event Planning & Services') ---> ('Active Life',)
# ('Art Schools', 'Arts & Entertainment', 'Shopping') ---> ('Education', 'Specialty Schools')
# ('Arts & Entertainment', 'Shopping', 'Specialty Schools') ---> ('Education',)
# ('Art Schools', 'Arts & Entertainment', 'Education') ---> ('Specialty Schools',)
# ('Art Schools', 'Arts & Entertainment', 'Specialty Schools') ---> ('Education',)
# ('Art Schools', 'Arts & Entertainment', 'Education', 'Shopping') ---> ('Specialty Schools',)
# ('Art Schools', 'Arts & Entertainment', 'Shopping', 'Specialty Schools') ---> ('Education',)
# ('Arts & Entertainment', 'Education', 'Shopping', 'Specialty Schools') ---> ('Art Schools',)
# ('Art Schools', 'Education', 'Shopping') ---> ('Specialty Schools',)
# ('Art Schools', 'Shopping', 'Specialty Schools') ---> ('Education',)
# ('Local Services', 'Post Offices', 'Public Services & Government') ---> ('Shipping Centers',)
# ('Local Services', 'Post Offices', 'Shipping Centers') ---> ('Public Services & Government',)
# ('Local Services', 'Public Services & Government', 'Shipping Centers') ---> ('Post Offices',)
# ('Post Offices', 'Public Services & Government', 'Shipping Centers') ---> ('Local Services',)
# ('Home Services', 'Real Estate Agents', 'Real Estate Services') ---> ('Real Estate',)
# ('Real Estate', 'Real Estate Agents', 'Real Estate Services') ---> ('Home Services',)
# ('Jewelry', 'Local Services', 'Watches') ---> ('Shopping',)
# ('Local Services', 'Shopping', 'Watches') ---> ('Jewelry',)
# ('Computers', 'IT Services & Computer Repair', 'Local Services') ---> ('Shopping',)
# ('Computers', 'IT Services & Computer Repair', 'Shopping') ---> ('Local Services',)
# ('Fashion', 'Outdoor Gear', 'Sports Wear') ---> ('Shopping', 'Sporting Goods')
# ('Outdoor Gear', 'Sporting Goods', 'Sports Wear') ---> ('Fashion', 'Shopping')
# ('Outdoor Gear', 'Shopping', 'Sports Wear') ---> ('Fashion', 'Sporting Goods')
# ('Fashion', 'Outdoor Gear', 'Shopping') ---> ('Sporting Goods',)
# ('Fashion', 'Outdoor Gear', 'Sporting Goods') ---> ('Shopping',)
# ('Fashion', 'Outdoor Gear', 'Shopping', 'Sports Wear') ---> ('Sporting Goods',)
# ('Fashion', 'Outdoor Gear', 'Sporting Goods', 'Sports Wear') ---> ('Shopping',)
# ('Outdoor Gear', 'Shopping', 'Sporting Goods', 'Sports Wear') ---> ('Fashion',)
# ('Chocolatiers & Shops', 'Flowers & Gifts', 'Shopping') ---> ('Food', 'Specialty Food')
# ('Chocolatiers & Shops', 'Flowers & Gifts', 'Specialty Food') ---> ('Food', 'Shopping')
# ('Chocolatiers & Shops', 'Shopping', 'Specialty Food') ---> ('Flowers & Gifts', 'Food')
# ('Chocolatiers & Shops', 'Flowers & Gifts', 'Food') ---> ('Shopping', 'Specialty Food')
# ('Chocolatiers & Shops', 'Food', 'Shopping') ---> ('Flowers & Gifts', 'Specialty Food')
# ('Chocolatiers & Shops', 'Flowers & Gifts', 'Food', 'Shopping') ---> ('Specialty Food',)
# ('Chocolatiers & Shops', 'Flowers & Gifts', 'Food', 'Specialty Food') ---> ('Shopping',)
# ('Chocolatiers & Shops', 'Flowers & Gifts', 'Shopping', 'Specialty Food') ---> ('Food',)
# ('Chocolatiers & Shops', 'Food', 'Shopping', 'Specialty Food') ---> ('Flowers & Gifts',)
# ('Jewelry', 'Jewelry Repair', 'Local Services') ---> ('Shopping',)
# ('Jewelry', 'Jewelry Repair', 'Shopping') ---> ('Local Services',)
# ('Jewelry Repair', 'Local Services', 'Shopping') ---> ('Jewelry',)
# ('Arts & Crafts', 'Cards & Stationery', 'Gift Shops') ---> ('Event Planning & Services', 'Flowers & Gifts', 'Shopping')
# ('Cards & Stationery', 'Flowers & Gifts', 'Gift Shops') ---> ('Arts & Crafts', 'Event Planning & Services', 'Shopping')
# ('Arts & Crafts', 'Event Planning & Services', 'Gift Shops') ---> ('Flowers & Gifts', 'Shopping')
# ('Cards & Stationery', 'Event Planning & Services', 'Gift Shops') ---> ('Arts & Crafts', 'Flowers & Gifts', 'Shopping')
# ('Cards & Stationery', 'Gift Shops', 'Shopping') ---> ('Arts & Crafts', 'Event Planning & Services', 'Flowers & Gifts')
# ('Arts & Crafts', 'Cards & Stationery', 'Event Planning & Services') ---> ('Flowers & Gifts', 'Shopping')
# ('Arts & Crafts', 'Cards & Stationery', 'Flowers & Gifts') ---> ('Event Planning & Services', 'Shopping')
# ('Arts & Crafts', 'Event Planning & Services', 'Flowers & Gifts') ---> ('Shopping',)
# ('Cards & Stationery', 'Event Planning & Services', 'Flowers & Gifts') ---> ('Arts & Crafts', 'Shopping')
# ('Arts & Crafts', 'Cards & Stationery', 'Shopping') ---> ('Event Planning & Services', 'Flowers & Gifts')
# ('Cards & Stationery', 'Flowers & Gifts', 'Shopping') ---> ('Arts & Crafts', 'Event Planning & Services')
# ('Cards & Stationery', 'Event Planning & Services', 'Shopping') ---> ('Arts & Crafts', 'Flowers & Gifts')
# ('Arts & Crafts', 'Cards & Stationery', 'Event Planning & Services', 'Gift Shops') ---> ('Flowers & Gifts', 'Shopping')
# ('Arts & Crafts', 'Cards & Stationery', 'Flowers & Gifts', 'Gift Shops') ---> ('Event Planning & Services', 'Shopping')
# ('Arts & Crafts', 'Event Planning & Services', 'Flowers & Gifts', 'Gift Shops') ---> ('Shopping',)
# ('Cards & Stationery', 'Event Planning & Services', 'Flowers & Gifts', 'Gift Shops') ---> ('Arts & Crafts', 'Shopping')
# ('Arts & Crafts', 'Cards & Stationery', 'Gift Shops', 'Shopping') ---> ('Event Planning & Services', 'Flowers & Gifts')
# ('Cards & Stationery', 'Flowers & Gifts', 'Gift Shops', 'Shopping') ---> ('Arts & Crafts', 'Event Planning & Services')
# ('Arts & Crafts', 'Event Planning & Services', 'Gift Shops', 'Shopping') ---> ('Flowers & Gifts',)
# ('Cards & Stationery', 'Event Planning & Services', 'Gift Shops', 'Shopping') ---> ('Arts & Crafts', 'Flowers & Gifts')
# ('Arts & Crafts', 'Cards & Stationery', 'Event Planning & Services', 'Flowers & Gifts') ---> ('Shopping',)
# ('Arts & Crafts', 'Cards & Stationery', 'Event Planning & Services', 'Shopping') ---> ('Flowers & Gifts',)
# ('Arts & Crafts', 'Cards & Stationery', 'Flowers & Gifts', 'Shopping') ---> ('Event Planning & Services',)
# ('Arts & Crafts', 'Event Planning & Services', 'Flowers & Gifts', 'Shopping') ---> ('Cards & Stationery',)
# ('Cards & Stationery', 'Event Planning & Services', 'Flowers & Gifts', 'Shopping') ---> ('Arts & Crafts',)
# ('Arts & Crafts', 'Cards & Stationery', 'Event Planning & Services', 'Flowers & Gifts', 'Gift Shops') ---> ('Shopping',)
# ('Arts & Crafts', 'Cards & Stationery', 'Event Planning & Services', 'Gift Shops', 'Shopping') ---> ('Flowers & Gifts',)
# ('Arts & Crafts', 'Cards & Stationery', 'Flowers & Gifts', 'Gift Shops', 'Shopping') ---> ('Event Planning & Services',)
# ('Arts & Crafts', 'Event Planning & Services', 'Flowers & Gifts', 'Gift Shops', 'Shopping') ---> ('Cards & Stationery',)
# ('Cards & Stationery', 'Event Planning & Services', 'Flowers & Gifts', 'Gift Shops', 'Shopping') ---> ('Arts & Crafts',)
# ('Printing Services', 'Professional Services', 'Shipping Centers') ---> ('Local Services',)
# ('Printing Services', 'Professional Services', 'Signmaking') ---> ('Local Services', 'Shipping Centers')
# ('Printing Services', 'Shipping Centers', 'Signmaking') ---> ('Local Services', 'Professional Services')
# ('Professional Services', 'Shipping Centers', 'Signmaking') ---> ('Local Services', 'Printing Services')
# ('Local Services', 'Printing Services', 'Signmaking') ---> ('Professional Services', 'Shipping Centers')
# ('Local Services', 'Shipping Centers', 'Signmaking') ---> ('Printing Services', 'Professional Services')
# ('Local Services', 'Printing Services', 'Professional Services') ---> ('Signmaking',)
# ('Local Services', 'Professional Services', 'Signmaking') ---> ('Printing Services', 'Shipping Centers')
# ('Local Services', 'Professional Services', 'Shipping Centers') ---> ('Printing Services',)
# ('Local Services', 'Printing Services', 'Professional Services', 'Shipping Centers') ---> ('Signmaking',)
# ('Local Services', 'Printing Services', 'Professional Services', 'Signmaking') ---> ('Shipping Centers',)
# ('Local Services', 'Printing Services', 'Shipping Centers', 'Signmaking') ---> ('Professional Services',)
# ('Local Services', 'Professional Services', 'Shipping Centers', 'Signmaking') ---> ('Printing Services',)
# ('Printing Services', 'Professional Services', 'Shipping Centers', 'Signmaking') ---> ('Local Services',)
# ('Carpet Cleaning', 'Home Cleaning', 'Home Services') ---> ('Local Services',)
# ('Carpet Cleaning', 'Home Cleaning', 'Local Services') ---> ('Home Services',)
# ('Local Services', 'Mobile Phone Repair', 'Mobile Phones') ---> ('IT Services & Computer Repair', 'Shopping')
# ('Mobile Phone Repair', 'Mobile Phones', 'Shopping') ---> ('IT Services & Computer Repair', 'Local Services')
# ('IT Services & Computer Repair', 'Mobile Phone Repair', 'Mobile Phones') ---> ('Local Services', 'Shopping')
# ('IT Services & Computer Repair', 'Local Services', 'Mobile Phone Repair', 'Mobile Phones') ---> ('Shopping',)
# ('IT Services & Computer Repair', 'Mobile Phone Repair', 'Mobile Phones', 'Shopping') ---> ('Local Services',)
# ...
# ('Food', 'Pizza', 'Specialty Food') ---> ('Restaurants',)
# ('Pizza', 'Restaurants', 'Specialty Food') ---> ('Food',)
# ('Food', 'Italian', 'Specialty Food') ---> ('Restaurants',)
# ('Italian', 'Restaurants', 'Specialty Food') ---> ('Food',)
# ('Active Life', 'Beauty & Spas', 'Health & Medical') ---> ('Fitness & Instruction',)
# ('Beauty & Spas', 'Fitness & Instruction', 'Health & Medical') ---> ('Active Life',)
# ('Home & Garden', 'Home Services', 'Local Services') ---> ('Shopping',)
# ('American (New)', 'Burgers', 'Fast Food') ---> ('Restaurants',)
# ('Burgers', 'Pizza', 'Sandwiches') ---> ('Restaurants',)
# ('American (New)', 'Breakfast & Brunch', 'Burgers') ---> ('Restaurants',)
# ('Breakfast & Brunch', 'Burgers', 'Nightlife') ---> ('Bars', 'Restaurants')
# ('Bars', 'Breakfast & Brunch', 'Burgers') ---> ('Nightlife', 'Restaurants')
# ('Bars', 'Breakfast & Brunch', 'Burgers', 'Nightlife') ---> ('Restaurants',)
# ('Bars', 'Breakfast & Brunch', 'Burgers', 'Restaurants') ---> ('Nightlife',)
# ('Breakfast & Brunch', 'Burgers', 'Nightlife', 'Restaurants') ---> ('Bars',)
# ('Burgers', 'Food', 'Sandwiches') ---> ('Restaurants',)
# ('American (Traditional)', 'Burgers', 'Food') ---> ('Restaurants',)
# ('Burgers', 'Food', 'Nightlife') ---> ('Bars', 'Restaurants')
# ('Bars', 'Burgers', 'Food') ---> ('Nightlife', 'Restaurants')
# ('Bars', 'Burgers', 'Food', 'Nightlife') ---> ('Restaurants',)
# ('Bars', 'Burgers', 'Food', 'Restaurants') ---> ('Nightlife',)
# ('Burgers', 'Food', 'Nightlife', 'Restaurants') ---> ('Bars',)
# ('Burgers', 'Nightlife', 'Sandwiches') ---> ('Bars', 'Restaurants')
# ('American (Traditional)', 'Burgers', 'Nightlife', 'Sandwiches') ---> ('Bars', 'Restaurants')
# ('Bars', 'Burgers', 'Sandwiches') ---> ('Nightlife', 'Restaurants')
# ('American (Traditional)', 'Bars', 'Burgers', 'Sandwiches') ---> ('Nightlife', 'Restaurants')
# ('Bars', 'Burgers', 'Nightlife', 'Sandwiches') ---> ('Restaurants',)
# ('Bars', 'Burgers', 'Restaurants', 'Sandwiches') ---> ('Nightlife',)
# ('Burgers', 'Nightlife', 'Restaurants', 'Sandwiches') ---> ('Bars',)
# ('American (Traditional)', 'Bars', 'Burgers', 'Nightlife', 'Sandwiches') ---> ('Restaurants',)
# ('American (Traditional)', 'Bars', 'Burgers', 'Restaurants', 'Sandwiches') ---> ('Nightlife',)
# ('American (Traditional)', 'Burgers', 'Nightlife', 'Restaurants', 'Sandwiches') ---> ('Bars',)
# ('American (New)', 'Burgers', 'Sandwiches') ---> ('Restaurants',)
# ('American (New)', 'American (Traditional)', 'Burgers', 'Sandwiches') ---> ('Restaurants',)
# ('American (Traditional)', 'Burgers', 'Sandwiches') ---> ('Restaurants',)
# ('American (New)', 'American (Traditional)', 'Burgers') ---> ('Restaurants',)
# ('American (New)', 'American (Traditional)', 'Bars', 'Burgers') ---> ('Nightlife', 'Restaurants')
# ('American (New)', 'American (Traditional)', 'Burgers', 'Nightlife') ---> ('Bars', 'Restaurants')
# ('American (New)', 'American (Traditional)', 'Bars', 'Burgers', 'Nightlife') ---> ('Restaurants',)
# ('American (New)', 'American (Traditional)', 'Bars', 'Burgers', 'Restaurants') ---> ('Nightlife',)
# ('American (New)', 'American (Traditional)', 'Burgers', 'Nightlife', 'Restaurants') ---> ('Bars',)
# ('American (New)', 'Burgers', 'Nightlife') ---> ('Bars', 'Restaurants')
# ('American (New)', 'Bars', 'Burgers') ---> ('Nightlife', 'Restaurants')
# ('American (New)', 'Bars', 'Burgers', 'Nightlife') ---> ('Restaurants',)
# ('American (New)', 'Bars', 'Burgers', 'Restaurants') ---> ('Nightlife',)
# ('American (New)', 'Burgers', 'Nightlife', 'Restaurants') ---> ('Bars',)
# ('American (Traditional)', 'Burgers', 'Nightlife') ---> ('Bars', 'Restaurants')
# ('American (Traditional)', 'Bars', 'Burgers') ---> ('Nightlife', 'Restaurants')
# ('American (Traditional)', 'Bars', 'Burgers', 'Nightlife') ---> ('Restaurants',)
# ('American (Traditional)', 'Bars', 'Burgers', 'Restaurants') ---> ('Nightlife',)
# ('American (Traditional)', 'Burgers', 'Nightlife', 'Restaurants') ---> ('Bars',)
# ('Bars', 'Burgers', 'Nightlife') ---> ('Restaurants',)
# ('Bars', 'Burgers', 'Restaurants') ---> ('Nightlife',)
# ('Burgers', 'Nightlife', 'Restaurants') ---> ('Bars',)
# ('American (Traditional)', 'Bars', 'Breakfast & Brunch') ---> ('Nightlife', 'Restaurants')
# ('American (New)', 'American (Traditional)', 'Bars', 'Breakfast & Brunch') ---> ('Nightlife', 'Restaurants')
# ('American (New)', 'Bars', 'Breakfast & Brunch') ---> ('Nightlife', 'Restaurants')
# ('American (Traditional)', 'Breakfast & Brunch', 'Nightlife') ---> ('Bars', 'Restaurants')
# ('American (New)', 'American (Traditional)', 'Breakfast & Brunch', 'Nightlife') ---> ('Bars', 'Restaurants')
# ('American (Traditional)', 'Bars', 'Breakfast & Brunch', 'Nightlife') ---> ('Restaurants',)
# ('American (Traditional)', 'Bars', 'Breakfast & Brunch', 'Restaurants') ---> ('Nightlife',)
# ('American (Traditional)', 'Breakfast & Brunch', 'Nightlife', 'Restaurants') ---> ('Bars',)
# ('American (New)', 'American (Traditional)', 'Bars', 'Breakfast & Brunch', 'Nightlife') ---> ('Restaurants',)
# ('American (New)', 'American (Traditional)', 'Bars', 'Breakfast & Brunch', 'Restaurants') ---> ('Nightlife',)
# ('American (New)', 'American (Traditional)', 'Breakfast & Brunch', 'Nightlife', 'Restaurants') ---> ('Bars',)
# ('American (New)', 'Breakfast & Brunch', 'Nightlife') ---> ('Bars', 'Restaurants')
# ('American (New)', 'Bars', 'Breakfast & Brunch', 'Nightlife') ---> ('Restaurants',)
# ('American (New)', 'Bars', 'Breakfast & Brunch', 'Restaurants') ---> ('Nightlife',)
# ('American (New)', 'Breakfast & Brunch', 'Nightlife', 'Restaurants') ---> ('Bars',)
# ('Bars', 'Breakfast & Brunch', 'Nightlife') ---> ('Restaurants',)
# ('Bars', 'Breakfast & Brunch', 'Restaurants') ---> ('Nightlife',)
# ('Breakfast & Brunch', 'Nightlife', 'Restaurants') ---> ('Bars',)
# ('Breakfast & Brunch', 'Coffee & Tea', 'Food') ---> ('Restaurants',)
# ('Breakfast & Brunch', 'Coffee & Tea', 'Restaurants') ---> ('Food',)
# ('Breakfast & Brunch', 'Coffee & Tea', 'Sandwiches') ---> ('Food', 'Restaurants')
# ('Breakfast & Brunch', 'Coffee & Tea', 'Food', 'Sandwiches') ---> ('Restaurants',)
# ('Breakfast & Brunch', 'Coffee & Tea', 'Restaurants', 'Sandwiches') ---> ('Food',)
# ('American (New)', 'Breakfast & Brunch', 'Sandwiches') ---> ('Restaurants',)
# ('American (New)', 'American (Traditional)', 'Breakfast & Brunch') ---> ('Restaurants',)
# ('American (Traditional)', 'Breakfast & Brunch', 'Sandwiches') ---> ('Restaurants',)
# ('Breakfast & Brunch', 'Food', 'Sandwiches') ---> ('Restaurants',)
# ('Event Planning & Services', 'Italian', 'Pizza') ---> ('Restaurants',)
# ('Food', 'Italian', 'Sandwiches') ---> ('Pizza', 'Restaurants')
# ('Italian', 'Pizza', 'Sandwiches') ---> ('Restaurants',)
# ('Food', 'Italian', 'Pizza', 'Sandwiches') ---> ('Restaurants',)
# ('Food', 'Italian', 'Restaurants', 'Sandwiches') ---> ('Pizza',)
# ('Bars', 'Food', 'Italian') ---> ('Nightlife', 'Restaurants')
# ('Food', 'Italian', 'Nightlife') ---> ('Restaurants',)
# ('Bars', 'Food', 'Italian', 'Nightlife') ---> ('Restaurants',)
# ('Bars', 'Food', 'Italian', 'Restaurants') ---> ('Nightlife',)
# ('Food', 'Italian', 'Nightlife', 'Restaurants') ---> ('Bars',)
# ('Bars', 'Food', 'Italian', 'Pizza') ---> ('Nightlife', 'Restaurants')
# ('Food', 'Italian', 'Nightlife', 'Pizza') ---> ('Restaurants',)
# ('Bars', 'Food', 'Italian', 'Nightlife', 'Pizza') ---> ('Restaurants',)
# ('Bars', 'Food', 'Italian', 'Pizza', 'Restaurants') ---> ('Nightlife',)
# ('Food', 'Italian', 'Nightlife', 'Pizza', 'Restaurants') ---> ('Bars',)
# ('Bars', 'Italian', 'Pizza') ---> ('Nightlife', 'Restaurants')
# ('Italian', 'Nightlife', 'Pizza') ---> ('Restaurants',)
# ('Bars', 'Italian', 'Nightlife', 'Pizza') ---> ('Restaurants',)
# ('Bars', 'Italian', 'Pizza', 'Restaurants') ---> ('Nightlife',)
# ('Italian', 'Nightlife', 'Pizza', 'Restaurants') ---> ('Bars',)
# ('Bars', 'Italian', 'Nightlife') ---> ('Restaurants',)
# ('Bars', 'Italian', 'Restaurants') ---> ('Nightlife',)
# ('Italian', 'Nightlife', 'Restaurants') ---> ('Bars',)
# ('Food', 'Italian', 'Pizza') ---> ('Restaurants',)
# ('Arts & Entertainment', 'Bars', 'Food') ---> ('Nightlife',)
# ('Arts & Entertainment', 'Bars', 'Restaurants') ---> ('Nightlife',)
# ('Arts & Entertainment', 'Nightlife', 'Restaurants') ---> ('Bars',)
# ('Arts & Entertainment', 'Bars', 'Event Planning & Services') ---> ('Nightlife',)
# ('Coffee & Tea', 'Event Planning & Services', 'Restaurants') ---> ('Food',)
# ('American (New)', 'Coffee & Tea', 'Food') ---> ('Restaurants',)
# ('American (New)', 'Coffee & Tea', 'Restaurants') ---> ('Food',)
# ('Bars', 'Coffee & Tea', 'Restaurants') ---> ('Food', 'Nightlife')
# ('Coffee & Tea', 'Nightlife', 'Restaurants') ---> ('Food',)
# ('Bars', 'Coffee & Tea', 'Food') ---> ('Nightlife',)
# ('Bars', 'Coffee & Tea', 'Nightlife') ---> ('Food',)
# ('Coffee & Tea', 'Food', 'Nightlife') ---> ('Bars',)
# ('Bars', 'Coffee & Tea', 'Food', 'Restaurants') ---> ('Nightlife',)
# ('Bars', 'Coffee & Tea', 'Nightlife', 'Restaurants') ---> ('Food',)
# ('Coffee & Tea', 'Food', 'Nightlife', 'Restaurants') ---> ('Bars',)
# ('Coffee & Tea', 'Food', 'Sandwiches') ---> ('Restaurants',)
# ('Coffee & Tea', 'Restaurants', 'Sandwiches') ---> ('Food',)
# ('American (New)', 'Event Planning & Services', 'Food') ---> ('Restaurants',)
# ('American (New)', 'American (Traditional)', 'Event Planning & Services') ---> ('Bars', 'Nightlife', 'Restaurants')
# ('American (New)', 'American (Traditional)', 'Bars', 'Event Planning & Services') ---> ('Nightlife', 'Restaurants')
# ('American (New)', 'American (Traditional)', 'Event Planning & Services', 'Nightlife') ---> ('Bars', 'Restaurants')
# ('American (New)', 'American (Traditional)', 'Event Planning & Services', 'Restaurants') ---> ('Bars', 'Nightlife')
# ('American (New)', 'American (Traditional)', 'Bars', 'Event Planning & Services', 'Nightlife') ---> ('Restaurants',)
# ('American (New)', 'American (Traditional)', 'Bars', 'Event Planning & Services', 'Restaurants') ---> ('Nightlife',)
# ('American (New)', 'American (Traditional)', 'Event Planning & Services', 'Nightlife', 'Restaurants') ---> ('Bars',)
# ('American (New)', 'Bars', 'Event Planning & Services') ---> ('Nightlife', 'Restaurants')
# ('American (New)', 'Event Planning & Services', 'Nightlife') ---> ('Bars', 'Restaurants')
# ('American (New)', 'Bars', 'Event Planning & Services', 'Nightlife') ---> ('Restaurants',)
# ('American (New)', 'Bars', 'Event Planning & Services', 'Restaurants') ---> ('Nightlife',)
# ('American (New)', 'Event Planning & Services', 'Nightlife', 'Restaurants') ---> ('Bars',)
# ('American (New)', 'Food', 'Sandwiches') ---> ('Restaurants',)
# ('American (New)', 'American (Traditional)', 'Sandwiches') ---> ('Restaurants',)
# ('American (New)', 'American (Traditional)', 'Nightlife', 'Sandwiches') ---> ('Bars', 'Restaurants')
# ('American (New)', 'American (Traditional)', 'Bars', 'Sandwiches') ---> ('Nightlife', 'Restaurants')
# ('American (New)', 'American (Traditional)', 'Bars', 'Nightlife', 'Sandwiches') ---> ('Restaurants',)
# ('American (New)', 'American (Traditional)', 'Bars', 'Restaurants', 'Sandwiches') ---> ('Nightlife',)
# ('American (New)', 'American (Traditional)', 'Nightlife', 'Restaurants', 'Sandwiches') ---> ('Bars',)
# ('American (New)', 'Bars', 'Sandwiches') ---> ('Nightlife', 'Restaurants')
# ('American (New)', 'Nightlife', 'Sandwiches') ---> ('Bars', 'Restaurants')
# ('American (New)', 'Bars', 'Nightlife', 'Sandwiches') ---> ('Restaurants',)
# ('American (New)', 'Bars', 'Restaurants', 'Sandwiches') ---> ('Nightlife',)
# ('American (New)', 'Nightlife', 'Restaurants', 'Sandwiches') ---> ('Bars',)
# ('American (New)', 'American (Traditional)', 'Food') ---> ('Restaurants',)
# ('American (New)', 'Bars', 'Food') ---> ('Nightlife', 'Restaurants')
# ('American (New)', 'Food', 'Nightlife') ---> ('Bars', 'Restaurants')
# ('American (New)', 'Bars', 'Food', 'Nightlife') ---> ('Restaurants',)
# ('American (New)', 'Bars', 'Food', 'Restaurants') ---> ('Nightlife',)
# ('American (New)', 'Food', 'Nightlife', 'Restaurants') ---> ('Bars',)
# ('American (New)', 'American (Traditional)', 'Bars') ---> ('Nightlife', 'Restaurants')
# ('American (New)', 'American (Traditional)', 'Nightlife') ---> ('Bars', 'Restaurants')
# ('American (New)', 'American (Traditional)', 'Bars', 'Nightlife') ---> ('Restaurants',)
# ('American (New)', 'American (Traditional)', 'Bars', 'Restaurants') ---> ('Nightlife',)
# ('American (New)', 'American (Traditional)', 'Nightlife', 'Restaurants') ---> ('Bars',)
# ('American (New)', 'Bars', 'Nightlife') ---> ('Restaurants',)
# ('American (New)', 'Bars', 'Restaurants') ---> ('Nightlife',)
# ('American (New)', 'Nightlife', 'Restaurants') ---> ('Bars',)
# ('Bars', 'Food', 'Sandwiches') ---> ('Nightlife', 'Restaurants')
# ('American (Traditional)', 'Bars', 'Sandwiches') ---> ('Nightlife', 'Restaurants')
# ('Food', 'Nightlife', 'Sandwiches') ---> ('Bars', 'Restaurants')
# ('Bars', 'Food', 'Nightlife', 'Sandwiches') ---> ('Restaurants',)
# ('Bars', 'Food', 'Restaurants', 'Sandwiches') ---> ('Nightlife',)
# ('Food', 'Nightlife', 'Restaurants', 'Sandwiches') ---> ('Bars',)
# ('American (Traditional)', 'Nightlife', 'Sandwiches') ---> ('Bars', 'Restaurants')
# ('American (Traditional)', 'Bars', 'Nightlife', 'Sandwiches') ---> ('Restaurants',)
# ('American (Traditional)', 'Bars', 'Restaurants', 'Sandwiches') ---> ('Nightlife',)
# ('American (Traditional)', 'Nightlife', 'Restaurants', 'Sandwiches') ---> ('Bars',)
# ('Bars', 'Nightlife', 'Sandwiches') ---> ('Restaurants',)
# ('Bars', 'Restaurants', 'Sandwiches') ---> ('Nightlife',)
# ('Nightlife', 'Restaurants', 'Sandwiches') ---> ('Bars',)
# ('Food', 'Pizza', 'Sandwiches') ---> ('Restaurants',)
# ('American (Traditional)', 'Event Planning & Services', 'Nightlife') ---> ('Bars', 'Restaurants')
# ('American (Traditional)', 'Bars', 'Event Planning & Services') ---> ('Nightlife', 'Restaurants')
# ('American (Traditional)', 'Bars', 'Event Planning & Services', 'Nightlife') ---> ('Restaurants',)
# ('American (Traditional)', 'Bars', 'Event Planning & Services', 'Restaurants') ---> ('Nightlife',)
# ('American (Traditional)', 'Event Planning & Services', 'Nightlife', 'Restaurants') ---> ('Bars',)
# ('American (Traditional)', 'Food', 'Nightlife') ---> ('Bars', 'Restaurants')
# ('American (Traditional)', 'Bars', 'Food') ---> ('Nightlife', 'Restaurants')
# ('American (Traditional)', 'Bars', 'Food', 'Nightlife') ---> ('Restaurants',)
# ('American (Traditional)', 'Bars', 'Food', 'Restaurants') ---> ('Nightlife',)
# ('American (Traditional)', 'Food', 'Nightlife', 'Restaurants') ---> ('Bars',)
# ('American (Traditional)', 'Bars', 'Nightlife') ---> ('Restaurants',)
# ('American (Traditional)', 'Bars', 'Restaurants') ---> ('Nightlife',)
# ('American (Traditional)', 'Nightlife', 'Restaurants') ---> ('Bars',)
# ('Bars', 'Event Planning & Services', 'Pizza') ---> ('Nightlife', 'Restaurants')
# ('Event Planning & Services', 'Nightlife', 'Pizza') ---> ('Bars', 'Restaurants')
# ('Bars', 'Event Planning & Services', 'Nightlife', 'Pizza') ---> ('Restaurants',)
# ('Bars', 'Event Planning & Services', 'Pizza', 'Restaurants') ---> ('Nightlife',)
# ('Event Planning & Services', 'Nightlife', 'Pizza', 'Restaurants') ---> ('Bars',)
# ('Event Planning & Services', 'Food', 'Pizza') ---> ('Restaurants',)
# ('Bars', 'Event Planning & Services', 'Food') ---> ('Nightlife',)
# ('Event Planning & Services', 'Food', 'Nightlife') ---> ('Bars',)
# ('Bars', 'Event Planning & Services', 'Food', 'Restaurants') ---> ('Nightlife',)
# ('Event Planning & Services', 'Food', 'Nightlife', 'Restaurants') ---> ('Bars',)
# ('Bars', 'Event Planning & Services', 'Restaurants') ---> ('Nightlife',)
# ('Event Planning & Services', 'Nightlife', 'Restaurants') ---> ('Bars',)
# ('Bars', 'Food', 'Pizza') ---> ('Nightlife', 'Restaurants')
# ('Bars', 'Nightlife', 'Pizza') ---> ('Restaurants',)
# ('Bars', 'Pizza', 'Restaurants') ---> ('Nightlife',)
# ('Nightlife', 'Pizza', 'Restaurants') ---> ('Bars',)
# ('Food', 'Nightlife', 'Pizza') ---> ('Bars', 'Restaurants')
# ('Bars', 'Food', 'Nightlife', 'Pizza') ---> ('Restaurants',)
# ('Bars', 'Food', 'Pizza', 'Restaurants') ---> ('Nightlife',)
# ('Food', 'Nightlife', 'Pizza', 'Restaurants') ---> ('Bars',)
# ('Bars', 'Food', 'Restaurants') ---> ('Nightlife',)
# ('Food', 'Nightlife', 'Restaurants') ---> ('Bars',)
