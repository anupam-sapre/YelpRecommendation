# %% [markdown]
# # Implementation of user locations inference

# %%
# install geopy and folium which are not contained by jupyter notebook

import pip

def install(package):
   pip.main(['install', package])

install('geopy') 
install('folium')

# %%
# import needed packages

from pymongo import MongoClient
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
from geopy.geocoders import Nominatim
import folium


client = MongoClient()
db = client.testYelp

# %%
# predict users' city/geo-location based on business they have reviewed

def location_prediction(userId_cities, user_geos):
    locations = {}
    geos = {}
    for user, cities in userId_cities.items():
        if not cities:
            continue
        city = Counter(cities).most_common(1)
        locations[user] = city[0][0]
    for user, geo in user_geos.items():
        if not geo:
            continue
        geo = Counter(geo).most_common(1)
        geos[user] = geo[0][0]
    return locations, geos

# %%
# parse all reviews from database and get userId and list of businessId respectively
# default filter users with less than 5 reviews and get 10 most recent reviews for each user

def getReviews(minLength=5,topNum=0):
    userId_businessId = {}
    user_reviews = db.review.find({},{"user_id":1,"business_id":1,"date":1})
    
    # get all reviews from database
    for user_review in user_reviews:
        if user_review['user_id'] not in userId_businessId:
            userId_businessId[user_review['user_id']] = []
        date = ''.join(user_review['date'].split('-'))
        userId_businessId[user_review['user_id']].append((user_review['business_id'],date))
        
    # filter the users with reviews number less than minLength and extract topNum recent reviews
    result={}
    for key,value in userId_businessId.items():
        if len(value)<minLength:
            continue
        if len(value)>topNum and topNum!=0:
            value = value[:topNum-1]
        # sort values by dates of reviews
        value = sorted(value, key=lambda x:x[1],reverse=True)
        result[key]=value
    # return merely the user and its corresponding list of businessId
    return {k:[val[0] for val in v] for k, v in result.items()}

# %%
# parse business and get its city and geo-location respectively

def business_loc():
    business_loc = {}
    business_geo = {}
    cities = db.business.find({}, {"business_id":1,"city":1,"latitude":1,"longitude":1})
    for city in cities:
        business_loc[city["business_id"]] = city['city']
        business_geo[city["business_id"]] = (city['latitude'],city['longitude'])
    return business_loc, business_geo

# %%
# connect users with lists of cities via business

def getCities(user_business, business_cities, business_geo):
    user_cities = {}
    user_geo = {}
    for user, business in user_business.items():
        user_cities[user] = [business_cities[b] for b in business]
        user_geo[user] = [business_geo[b] for b in business]
    return user_cities, user_geo

# %%
# get business cities and geo-locations
business_locations, business_geos = business_loc()

# predict user cities by all their reviews
userId_businessId = getReviews()
user_geo, user_cities = getCities(userId_businessId, business_locations, business_geos)
user_predict_geos, user_predict_locations = location_prediction(user_cities, user_geo)
user_locations = user_predict_locations.values()
user_geos = user_predict_geos.values()

print('half is done')

# predict user cities by their 5 most reviews with 3 as minimum required number of reviews
userId_businessId_recent = getReviews(5,5)
user_geo_recent, user_cities_recent = getCities(userId_businessId_recent, business_locations, business_geos)
user_predict_geos_recent, user_predict_locations_recent = location_prediction(user_cities_recent, user_geo_recent)
user_locations_recent = user_predict_locations_recent.values()
user_geos_recent = user_predict_geos_recent.values()
# Out:
# half is done

# %%
user_predict_locations
# Out:
# {'bjTcT8Ty4cJZhEOEo01FGA': 'Edinburgh',
#  'yx8vNXUL0D0HS8rUIC7AFA': 'Montréal',
#  'oU2SSOmsp_A8JYI7Z2JJ5w': 'Edinburgh',
#  'zXnH6W74FAJQ7q7b-NuBsA': 'Edinburgh',
#  'c5yp5hxwC1N98MjbV2LyWQ': 'Edinburgh',
#  'AXgRULmWcME7J6Ix3I--ww': 'Edinburgh',
#  'tgV6tsYQ66DZ3LQKvtC6cw': 'Las Vegas',
#  'Q-3YCVywc03w56wYtGlKvg': 'Edinburgh',
#  'eqWEgMH-DCP74i82BEAZzw': 'Toronto',
#  'd0DGZRp6lHXGECJSc_nn-A': 'Edinburgh',
#  'WZXp9-V2dqRRJqhGgRqueA': 'Mentor',
#  'XylT12exfdLiI_3uDLVIpw': 'Glendale',
#  'IpLZ7RevQrFPJWYc9Gxymg': 'Edinburgh',
#  'E56sVQT5-OWfSejJrma8_w': 'Phoenix',
#  'TLIWzAJPrET0zX4_vgvLhg': 'Surprise',
#  'Ji9PeffxjwqPLO7pEfSpKQ': 'Surprise',
#  'P8mVj7AZwJTFFH5FXbbmUg': 'Surprise',
#  'JZEiTNWBwmv6MOOXYCAaMQ': 'Surprise',
#  'vgZqQqe8cj6SBMH0EqDliw': 'Scottsdale',
#  'O7G_c6wFXSygr82qs0GAcA': 'Peoria',
#  'UG4EKu13JRwzRix6ESINdg': 'Surprise',
#  '1YorWW0Z-YDuYC5GplNabw': 'Surprise',
#  'R6vb0FtmClhfwajs_AuusQ': 'Phoenix',
#  'CPuUagT2rfUJm6hRgxn3JQ': 'Phoenix',
#  'OYRBjBWy1uOm12N3cokS_Q': 'Surprise',
#  'PKZLwAGgBtQCjJtGhyPETA': 'Phoenix',
#  'tbAQMMVlhxvXhe6KifrZ-A': 'Surprise',
#  '9bJ6j0zrV1XSiSnzQWM5Tw': 'Surprise',
#  '-0kiduTUToVYFqN_NEqMSw': 'Surprise',
#  '8nCmV4RMwf4GpaN-A_2Tfw': 'Surprise',
#  'xlkjaJUu2fVojeaaVgQPOw': 'Surprise',
#  'alTlRb9qMBX11pARX05Big': 'Surprise',
#  'e--whH51bx5mDaMo3aJ-hg': 'Phoenix',
#  'Ns0hZ0xDOuVRMpHk0Q-5Yw': 'Surprise',
#  '1s0Q1KwGpJIKvD-SRSpwjw': 'Surprise',
#  'R-kL1bocHgP4GW7Mgd-ZXA': 'Surprise',
#  'UXZDRVdx8eJqdqb13Bcfcg': 'Surprise',
#  'EKTCccgwn9MAIDNSsDwuIg': 'Phoenix',
#  'rHP3q9Ok1qu9_tJmIy4i9w': 'Phoenix',
#  'C38sl6tI_DVrpL5sg4Kmfw': 'Surprise',
#  'cs6biPoaG9SmtVB44hU9Sw': 'Surprise',
#  '1fMDrDfB3IHPCka9SeSHsA': 'Surprise',
#  '33h6CGtB9MSYHi0-kbXMhw': 'Surprise',
#  'zLt0Qu_98ZGObYBTcG7jRQ': 'Las Vegas',
#  '6jz_Yr6_AP2WWLbj9gGDpA': 'Phoenix',
#  'faaOI6hU64h6SSaF0f11eg': 'Surprise',
#  'ljGTQD_-yC4iXievtgCsbA': 'Surprise',
#  'd6om2E23bPoZFWzLss-rrA': 'Phoenix',
#  'O2U5kLpXDY-xjDppJ7d_Nw': 'Chandler',
#  '5zkRD7dv8GqysVCvwPr-Ew': 'Phoenix',
#  'Ov-0pRQxz5fTTElFE-WtTQ': 'Surprise',
#  'DAIpUGIsY71noX0wNuc27w': 'Sun City',
#  't9lwePmlZ7Sl_wiw9SFSrQ': 'Phoenix',
#  'p_azadim_uWFOXAhhKB3ag': 'Phoenix',
#  'e3S63222bmnlIYLi2DCeQg': 'Surprise',
#  'GjxM-LmQcta13_DiUniVgg': 'Phoenix',
#  'GG9tAoEC9sMa_DokSkkImA': 'Surprise',
#  'cPfnF9PAvVjamEdZM3wTzA': 'Surprise',
#  'hxhKA0q9jLxTfUdg1LM9Bg': 'Las Vegas',
#  'RhDwmkLWmC1SGF0VPV7xYQ': 'Peoria',
#  'kq0emTsKE2DcDOWbe1NYRg': 'Phoenix',
#  'CnSzFGho_Ofsda3DOg0cIA': 'Phoenix',
#  'unEY79t6hHECP9Yd58R1dg': 'Avon',
#  'kqsBiDRm1u34Q0RqN62QIA': 'Mentor',
#  'NtkMuGqcis30GjAkq91etA': 'Mentor',
#  'T5MGS0NHBCWgofZ6Q6Btng': 'Mentor',
#  'Rt1sD4KdPD6Uquf9BIsw2Q': 'Mentor',
#  'xU3FI_O1XrjGRzOiFWvjBw': 'Mentor',
#  'b7zWPM3MDi074PbSw9GSIA': 'Highland Heights',
#  'ciFYbNSdhRpHW0LofmmeEQ': 'Avon',
#  '8e2Khf95bZgBlkeMqh59fA': 'Mentor',
#  'mPfLvSeRYqdQxJQk5ANVUg': 'Mentor',
#  'fGgE1ASXCWfuw5edGCfCFA': 'Mentor',
#  '9Y_HfxjyZU7ltQ3VY3Wj-A': 'Mentor',
#  '9CiRp71NmS_AP74rW-1gdg': 'Middlefield',
#  'xlp2qzyxgBg31wFHSDhKww': 'Willoughby',
#  'vkOWrnWgPhgpqev9ZanAnw': 'Mentor',
#  'YBbNemmB8wWbKGr6V3bCAA': 'Cleveland',
#  '4pVwuNpFwn8nWrSkT0urvA': 'Painesville',
#  'CLHRQRNRrpj7Ht-oQSFf7g': 'Mentor',
#  'MGBv4e-Z6lfyUcSVwPXQPA': 'Mentor',
#  '5z587IBRnjCbo51IaHNPzQ': 'Cleveland',
#  'ludX46lEfeQ8TuHsK0D9zw': 'Mentor',
#  '-S1dz92Q3RPfHomiqEeP8Q': 'North Olmsted',
#  'XeOCjJwfLlKpkSd_oYxyGQ': 'Mentor',
#  'NvI6nkdKut_x5GommcngDw': 'Mentor',
#  '09jpZrKD_j0SG9WPBDSJQg': 'Mentor',
#  '2rIHr_3qznLHn73YfOwkWA': 'Mentor',
#  'Xxvz5g67eaCr3emnkY5M6w': 'Cleveland',
#  'rK2aGPWEU7UVwz_fqKE8mA': 'Mentor',
#  'djpMXOA1ic5wv3FPtubHNw': 'Toronto',
#  'PTj29rhujYETuFlAZaDi3w': 'Toronto',
#  'XCDxUzBSY8-JOvcp4jqpvg': 'Toronto',
#  'zZy5Jljx7rEvISiJ2isJpA': 'Toronto',
#  'bzKH1kadsxohV4UgNc1wTw': 'Toronto',
#  '-pXs08gJq9ExIk275YLvPg': 'Toronto',
#  'Kf10dTiGlcnyhj8DBoZn1A': 'Toronto',
#  'B7IvZ26ZUdL2jGbYsFVGxQ': 'Toronto',
#  'Ggl13LZFNdNO3z1fXj_1RQ': 'Toronto',
#  'm6GlY6JALeb0nGnE29FJ8Q': 'Toronto',
#  '1cb0oJc2pR2efodBQbXdvQ': 'Toronto',
#  'JUT0U3HTSB3kz9Wh7N0GqA': 'Madison',
#  'AhoxHm569hH_PRkoegDwcA': 'Toronto',
#  '9FhtC5gKQvUCQMMGlcXW3w': 'Toronto',
#  'gXQfe8T1UvMpmR5rcWpGWw': 'Toronto',
#  'A-zo2jSQDnTgIoJg0sFevg': 'Toronto',
#  'alUuOskFSl1bODjnce2PpQ': 'Toronto',
#  'nQuC_UE-TYI5Epb5KR4AWQ': 'Toronto',
#  '0HxInQ94hVHVlO1FGPWctA': 'Toronto',
#  'Jyi0WJt0UfGdEg0grR38ZA': 'Toronto',
#  'wnRv7PRPZ0jU_flnGJnYAg': 'Toronto',
#  'qt1b6zXExL-uoJGRRouQYw': 'Toronto',
#  'f-dzSIu2QURZ8Y_fxo7J-Q': 'Toronto',
#  'FYAkhIj29gyWD_Lte1v7SQ': 'Toronto',
#  'DuoBTfKNM67965BcrlYBYg': 'Toronto',
#  'wu-ijx0ZiBThoc9tRHf_Hw': 'Toronto',
#  'B0izwVcG6y-NbWvfNBVSAg': 'Toronto',
#  'a39kizwaoThU6uLIv_Ke2g': 'Toronto',
#  'bCPO7i-x5eZ41lLVOwuQwQ': 'Toronto',
#  'dvr-iz4B9eNzDZ-uvjvHPQ': 'Toronto',
#  'L3X_u_PWEglem1ETrPMjpg': 'Toronto',
#  'ncULBoGp-kRF3zExhbdDfw': 'Toronto',
#  'LRKmxCcf6ZkxyujPdmp5zQ': 'Montréal',
#  '2VKVhy1SwaixHCeiWglLUQ': 'Toronto',
#  'M5Ci03Ce9gab2jahundlRQ': 'Toronto',
#  'vMrnL8HA0OvnME8PC0Dg1A': 'Toronto',
#  'Yl7OYdHuYmr7K-IW9_ayng': 'Toronto',
#  'J3ucveGKKJDvtuCNnb_x0g': 'Toronto',
#  'XXxrsJ3KpTFybcBFpZLYiQ': 'Toronto',
#  'Oxe8DXjBOi6C-cR2w64zOg': 'Toronto',
#  'asPq38KJqzxeLotQCdxQgg': 'Toronto',
#  'iF3V9eqIVAjX8sj96hJ_sw': 'Toronto',
#  'RYP7YVMcYPfO78H1OTzt7A': 'Toronto',
#  'y3MNMa0SG_cHC1cwmmntpQ': 'Toronto',
#  'g5wYoa19wv1X0UOYVX1IlA': 'Toronto',
#  'SRSmzTPA2dX2Zpfa2uE4sA': 'Cleveland',
#  'TYiDRwfIUBEos45ERdzeAw': 'Toronto',
#  'TZelLnaGbHgaG7LBI6rfgg': 'Toronto',
#  'VVm-TFCpi9M1-k8ED0l1eA': 'Toronto',
#  'uyEIiUd0qGkZySz4kbA0uQ': 'Toronto',
#  'HFItzRohDHZvcKDrM6ABZg': 'Toronto',
#  'hrA2TKOiPrJ0Va3ceAgq9g': 'Toronto',
#  'gMfkWTxRVZtJAMm_adQKsQ': 'Toronto',
#  'tYk7mMGGFl3gLfmhST5L-A': 'Toronto',
#  '3Le78qZoyKE0Od0sGU8EBA': 'Toronto',
#  'zbSBmoujGgIPuNWQcny14g': 'Toronto',
#  'AlXx0P-OhUylep0jNi773g': 'Toronto',
#  '6X9PioodbNo5nnkZTFWhWQ': 'Toronto',
#  'gW4UsZSf81Xqc29eE2yqCg': 'Toronto',
#  'fCy0RLrVg6xyhaNRpZtBIA': 'Toronto',
#  'EhO5C7t3yfGFLvsTyK5PPw': 'Toronto',
#  'eV5usRjY2cDqNKVv8wXroA': 'Toronto',
#  'MC8wS2NGRMSfO5fFWU7b4Q': 'Toronto',
#  'Je9hP1439B3jp4y-nBgiMw': 'Toronto',
#  '7_RaCe5zzPBYWm9znlffUA': 'Toronto',
#  'f3HeJmAQYWbbuyVVzxstOQ': 'Mississauga',
#  '8xArUHrVys0dH17X36KyJQ': 'Toronto',
#  '3gw82ABfZVOD9Yg51wTmiA': 'Toronto',
#  'NL8ULDSd476vP3PtU4pvfw': 'Toronto',
#  'NFH6lgwwub14W-sR7m40hA': 'Toronto',
#  'OHfTeAhGpJtUMEOe7QLwgw': 'Toronto',
#  '2Ez3VPd47JGv_hv975J-Uw': 'Toronto',
#  '_t3BJzyGaqr9mcDazYiYAQ': 'Toronto',
#  'ZUsS5CjWh4YrPVi4Hi3Y6Q': 'Toronto',
#  'imPfhpAk61DqSW6K47D4QQ': 'Toronto',
#  'pQbLLV8uzry5S7EX114gUg': 'Toronto',
#  'p8rCTA139YIM6DQNq5s5XA': 'Phoenix',
#  'u04pbgaUuqqy0UnMI05p8A': 'Toronto',
#  'dRlA0iymGFcNzsfWA7P-Jg': 'Toronto',
#  'Uwu72w77MPox942_GnCS7g': 'Toronto',
#  'hWJdT09U7oHcSoc_pYr0Tw': 'Toronto',
#  'FTNaQZ3t0dsVWw1WZUQGFg': 'Oakville',
#  'uHZr3XbjKvRTwdXLXrFuvg': 'Toronto',
#  'TbhyP24zYZqZ2VJZgu1wrg': 'Toronto',
#  'sfKwAw0FD8KuWp4Hjv0cxQ': 'Toronto',
#  'CxDOIDnH8gp9KXzpBHJYXw': 'Toronto',
#  'NNOLEPL8DidbqMCH3Qkecw': 'Toronto',
#  'U_6JkfbEYRG-lb4pbbtlLA': 'Toronto',
#  'JyLTAZZZB9L40Q3S9b1jlw': 'Toronto',
#  'mb_8jXannipO5T5V5kGXiQ': 'Toronto',
#  'Jt1zgNmwz_jheOSmEsljPQ': 'Toronto',
#  'OFawbcy1lqVOeRtDTOnSpg': 'Toronto',
#  '8lL-554wLEOxCrroFa4aeg': 'Chandler',
#  'E0rM7jeEOZXUObgLG9Ixgw': 'Phoenix',
#  's19c8t_yAmFrby90LjDk8g': 'Montréal',
#  'fuUmrxv-SzxXQ5ilT03V1A': 'Phoenix',
#  '9df8KToLljo-v--Wke2W1w': 'Las Vegas',
#  '-vjSUjoYYROCHImyLenDNA': 'Las Vegas',
#  '5aNrWttH8JiZU9RQ--Fzcg': 'Las Vegas',
#  '6mMk9hO_RAbdGMEGeg3oWQ': 'Las Vegas',
#  'zF10BKjK4Lz9U_8Yqw28ww': 'Las Vegas',
#  '3Vd_ATdvvuVVgn_YCpz8fw': 'Las Vegas',
#  'PKEzKWv_FktMm2mGPjwd0Q': 'Las Vegas',
#  '4TDeDywE3LL-jI8lQ1uRTw': 'Phoenix',
#  'siiwiW2CwUJrEdmLytsPKw': 'Las Vegas',
#  'ibvH1Y7Rh_tstiWgH0OFTA': 'Las Vegas',
#  'QJI9OSEn6ujRCtrX06vs1w': 'Las Vegas',
#  'm9N3bBRLAxRJU_7F6aWOmA': 'Las Vegas',
#  'UY3x_8KhKlrqVSDE0QKV8A': 'Las Vegas',
#  'mXRg6SXgyQO_nsPr3toIUQ': 'Las Vegas',
#  'w3dRT20CwQSNJ6GLGbM4SA': 'Las Vegas',
#  'aT_AzbpcsbodNNtFzPqRVg': 'Las Vegas',
#  'Kp5KHBSmV-Htc9NeSjJfPA': 'Las Vegas',
#  '7dnh9OrD8LekBwvachGH5Q': 'Las Vegas',
#  'ntlvfPzc8eglqvk92iDIAw': 'Las Vegas',
#  'EiwxlbR8fb68lMgEXhcWKA': 'Las Vegas',
#  'y3FcL4bLy0eLlkb0SDPnBQ': 'Las Vegas',
#  'll75pLg0owsEoo1jCMdRyg': 'Las Vegas',
#  'SJu5NWsA_DrPXu9ibN9y5A': 'Toronto',
#  'uf95iifC_TQ-DtDs0rtiXg': 'Toronto',
#  '2jbu_xi_FEghI37kPG5LzA': 'Las Vegas',
#  '1LcId4o9Ge0F0KXrUXhuyw': 'Toronto',
#  'W6CrBiuPNADGDIH_m39_aw': 'Toronto',
#  'CGjRewYS0p_WEm6ocQJFrw': 'Toronto',
#  'N9PQbJqnmVAK-wjgiaaGnw': 'Toronto',
#  '3KkT6SmPFLGvBS1pnDBr8g': 'Pittsburgh',
#  'TsBUWbhRhuiEMXb56kL0Cg': 'Pittsburgh',
#  'bJTKxBIvb_AR8d4SuLPV8g': 'Toronto',
#  'Um2iec4NKMXVpJEME3PfKg': 'Pittsburgh',
#  'scnvdFMXTQ4o2DBJpHLbaw': 'Pittsburgh',
#  '3ew6BEeK14K6x6Omt5gbig': 'Pittsburgh',
#  'g0EQGDEVFl4DMN6jfarJFg': 'Pittsburgh',
#  'hcZqq-a16ZTjaM2p2MljTg': 'Las Vegas',
#  '135DbbQnr3BEkQbBzZ9T1A': 'Pittsburgh',
#  'ZLS7cwa1UplSB8nRrwrHIQ': 'Pittsburgh',
#  '9tIjFbmboV3ioyng_G2Pgg': 'Pittsburgh',
#  'HoM645ouLZA0grMBtj4w2w': 'Pittsburgh',
#  'YCZA7dlc3Rdj80Egh3__JA': 'Pittsburgh',
#  'SqVUNVeYJblyoUz4e-Fiqw': 'Pittsburgh',
#  'BoUGdFkiU6EVsHGSvt-Uwg': 'Pittsburgh',
#  '7sAkIM47_LE99Hyg5lwdrg': 'Pittsburgh',
#  'ySq-gVgm0gxmllf0ZFz-mA': 'Pittsburgh',
#  'A4SLfGedOniAWjjIwC5iOw': 'Pittsburgh',
#  '32M_2x0IzeIxcJucQp6BOw': 'Pittsburgh',
#  'lPeHcLi-6y4nIEdPmDedtQ': 'Pittsburgh',
#  'Ic6-gs1_FjrWGx6JIr95Mw': 'Pittsburgh',
#  '4YwesZEX8VPPJOKLfPD7lg': 'Pittsburgh',
#  '6CoMpwA8D2s00RfzpKDuOg': 'Pittsburgh',
#  'GvYzuy5nwG9QWC7Mp11dHg': 'Pittsburgh',
#  'A8_ovU0s8KGipI8DPPzXzA': 'Pittsburgh',
#  'knDrH7HggUkpMSO92bzJLQ': 'Pittsburgh',
#  '9iNyv-Kf4B748GsL0d4QxQ': 'Pittsburgh',
#  'MoFYvOoufOMyVTmUFAhRxQ': 'Pittsburgh',
#  'nLXCAodRN6Z6O4-CjshgPQ': 'Pittsburgh',
#  'k6Y8yT_EJtL5hhwnYPDUfg': 'Pittsburgh',
#  'UcwzDDDK4dElIwBLTH4UwQ': 'Pittsburgh',
#  '3EN4rQgpR8cR1NxuJNzi9Q': 'Pittsburgh',
#  'cQpTkatAqnOBCarVNwixPQ': 'Pittsburgh',
#  'yKFeQD-gcsPKj1BIs813oQ': 'Pittsburgh',
#  't3FKu7xMv6UkyGegAewWCw': 'Pittsburgh',
#  '8DclOINSPldMTgiEbuCdoA': 'Pittsburgh',
#  '6lu-nRaojUcVdP4nhi3Asg': 'Pittsburgh',
#  'zh8-XfjqlwAxf--RS4azzg': 'Pittsburgh',
#  '0zwj4cI7rhhQM9Ck8ZnIGg': 'Pittsburgh',
#  'VwAhjZPN7zJuyG03P8mp_w': 'Pittsburgh',
#  'CMjjwZ43THQpVS9VwbpWOw': 'Pittsburgh',
#  'JVJOfFqPmZEvkRznzF8w-w': 'Pittsburgh',
#  'QNps8E2YEMweAnWdqPZxhQ': 'Pittsburgh',
#  'qpnrU31DaVDjxO8gxkrQGg': 'Pittsburgh',
#  'sV3xGQ-mFG48hzJcArlLZw': 'Pittsburgh',
#  'mit8WLpdSlOrRZD71SOgjw': 'Monroeville',
#  'OKUs_ZvoDYkgg-bFRfmHCg': 'Pittsburgh',
#  'bryAPtwnnMYjbzoOWHzbWg': 'Pittsburgh',
#  '3H5Ty7TV7SZvZLa1oTUGDg': 'Montréal',
#  '3zdB0SSrXIDIgsrOmhdUtQ': 'Montréal',
#  'KcFMI-hsr2Em7whfI4OM5g': 'Montréal',
#  'hHhUIFHQucto-L3GDY8XxA': 'Pittsburgh',
#  '5JOP01e-jC-N3OrnevM7bA': 'Madison',
#  '4RptW32AaMcCzEArZjjitw': 'Madison',
#  'tlQ2MDwfE1TBCNmsofeGfg': 'Madison',
#  '6uLqCFKpK7nav7Zp_3TfRA': 'Madison',
#  'VvwrCpL2_uMrRumFWo7nLQ': 'Madison',
#  'BcLEkxjjYX-L3jKdUKtWnw': 'Madison',
#  'uzojZqd-h289ibuB6wPZ9g': 'Madison',
#  'reN-Y7lIjv3VW21I4Z8WHQ': 'Madison',
#  'QDzMM2YcB0LDLJVHDqrz3g': 'Madison',
#  'O7Wru5nlVMwXzuI1-CNG4Q': 'Madison',
#  'YJInht2-Z0Pj9CH3ML1R3g': 'Madison',
#  'd5WLqmTMvmL7-RmUDVKqqQ': 'Madison',
#  'fzWuWObdqMv-81BUk6Z8hA': 'Scottsdale',
#  'VtLdzz_1olnpRU6AuSsEVg': 'Las Vegas',
#  '6hi7gWjaIYC51ZlmrXmevA': 'Las Vegas',
#  '9HGer_DiSPF3xJVXIcQM4Q': 'Phoenix',
#  'pwpQncGpmxgJ01r2KI67qw': 'Phoenix',
#  'h7J6pJrLCzUu-LLpuQpxGg': 'Phoenix',
#  'GKcIOfDnPSrveGRi4BLMmA': 'Mesa',
#  '9bs-jvAayiWN1Hq2iDLiXw': 'Las Vegas',
#  '6ai3vG2vlcQXTINdbO5H3w': 'Phoenix',
#  'P7Bwn2qljq8qqKoZEXbsGQ': 'Scottsdale',
#  'IoLMXv6wzfKaisN60u5iyg': 'Phoenix',
#  'ni9ClI2mhAeAJUSaSY58jQ': 'Phoenix',
#  '6IrzPt91rwVgH52o8_ytNg': 'Phoenix',
#  'B0ASQntm8Sy4aV1CXJi_rQ': 'Mesa',
#  'Gq8OwMLyRRdL71NWp6VM9A': 'Pittsburgh',
#  'JM18LKd3By6gL3WOFXhaMA': 'Scottsdale',
#  'Aw9YiasaOs9zikh1XsbI9g': 'Phoenix',
#  '02Z0sSGvQRm2rgQwUmNAJQ': 'Tempe',
#  'SR9KgvoaxcBsSd4Gds8LnQ': 'Glendale',
#  'cwAxa2L4T0t5Hu1zgb5YVQ': 'Scottsdale',
#  'k-p5RfLnAPEherauN4CxUQ': 'Phoenix',
#  'CQ7tEwDL_5jpEJzDKKYv4Q': 'Phoenix',
#  'xodu7YZipff5EW5QbpT0aQ': 'Scottsdale',
#  '9EBTKHoCH1sl3X0MX8txjg': 'Phoenix',
#  'sOCuf-jZo43DUzWTDKiR9w': 'Phoenix',
#  'aemN874BzsJo6NBEIbygfA': 'Tempe',
#  'APnNt9CdoZ3n3EAIB2nMog': 'Las Vegas',
#  'Ru2NSw1CzoGAsXYvDGf0Uw': 'Phoenix',
#  'zTK1nPD2Hpa-ksSXsE-JzQ': 'Phoenix',
#  '_k3o_AKj-S9JD0q6AhSXdw': 'Phoenix',
#  'e0TeYGOQRM2PrYCAdho7lg': 'Phoenix',
#  'YcmNpPM0ag94g4T0zAtdcg': 'Phoenix',
#  'LZdMLoFIpW8X0QdIZOVGbQ': 'Phoenix',
#  'U_FfJTKoLsutJf-r98H9EA': 'Gilbert',
#  'OW0PZxoGFGSOthAmN_cSUg': 'Phoenix',
#  '7aHlhpJFiAdFHVhs6OHP6w': 'Phoenix',
#  'XQfRpQv5q0uiP95QzIynug': 'Tempe',
#  'FggHd5cqx65Eu2bT1eHtEQ': 'Phoenix',
#  'XpuNfndl5pRh1XQWSFvvQA': 'Phoenix',
#  'jV-MHT6BbWw_Lfh-hlfa6g': 'Gilbert',
#  'Cqn_766h_JpQoV6fwizJhg': 'Charlotte',
#  'DDFAI_WROA_J8FF8dWe_6Q': 'Charlotte',
#  'zSblIQYZhN0gauAhIx46Tg': 'Charlotte',
#  'QQ7sxRNs0A4uFK6pQE4AYw': 'Charlotte',
#  '9khBWjeKA9rHjT9Wo63WrA': 'Charlotte',
#  '9IRuYmy5YmhtNQ6ei1p-uQ': 'Charlotte',
#  'HS3y3GltOH_pJ37-EJwOng': 'Charlotte',
#  '7IZQ06zkYSCLQM4JU9kFvg': 'Charlotte',
#  'w3ReHv4j5f-gnzHIz4Krbg': 'Charlotte',
#  '17TiV5o3EsIIbyFgSpBmXg': 'Charlotte',
#  '-8mGZ-pJi-NcjZckuz1M7A': 'Charlotte',
#  'FSJDnMPHNOpZrqR1wHp53A': 'Charlotte',
#  'E1szdQHhFDwO115pGDh_Xg': 'Charlotte',
#  'wsCRhiX1UpakSeDvo9DHQg': 'Charlotte',
#  'bm2tUuhog7tMu7EqfN7BNw': 'Charlotte',
#  '7U3H1iJZ04FbadJtt2Npjg': 'Charlotte',
#  'uaeU6FBaY5by7V1Cj_2RpQ': 'Charlotte',
#  'TqoxE8B0r4CUWpGYAHXoOg': 'Charlotte',
#  'iN5kL0PrH0lb_69fZ6difQ': 'Charlotte',
#  'SBi0TYUSIrct8WSTyK6DFg': 'Charlotte',
#  'sbtSsIQKYRPmS4KJ6jdYnw': 'Charlotte',
#  'ifZh_oEWxd05Ci_RQVoL9Q': 'Charlotte',
#  'UKFgwgNM1a7Gmr0UIGPzpw': 'Las Vegas',
#  'hhQUVO2AqBdSeQcPo19Bsw': 'Charlotte',
#  'LnGDsxHFPhoCKT8sFGaViA': 'Las Vegas',
#  'Fv0e9RIV9jw5TX3ctA1WbA': 'Las Vegas',
#  'JoATwObKNywEmAduyKdm6w': 'North Las Vegas',
#  'E1b2_YD1uwufHmCsrKteCw': 'Las Vegas',
#  'uT-yzDkY79szXYNWk7zDzQ': 'Charlotte',
#  'Jl-0N4zQ6VCbvk7DFpNfJg': 'Las Vegas',
#  'OVFCRSZ_yFEc1rAlye_Z5g': 'Las Vegas',
#  'C6ezDVKNyQz-aKr4OOjC4w': 'Las Vegas',
#  'Rh2YtAmvRxDonUqZlxJDIw': 'Las Vegas',
#  'cQzo2WX1TyPEmS5jPzOUoA': 'Las Vegas',
#  '5IgLVsxowG4gcIJK8ovSzQ': 'North Las Vegas',
#  'vb9UuBS_qwUR-EGsJKlSFw': 'Las Vegas',
#  'IeVYKQZObeFnKTa04oB5Gg': 'Las Vegas',
#  'Nym1l6I0gMFrr9WCAcMO0w': 'Las Vegas',
#  '6pzA8EDhHgW3A5-rBObhBA': 'Las Vegas',
#  'WRWvu_McOkXguooZftZJmw': 'Las Vegas',
#  'zc6cucEAy6Qxkxr9ZUkqbw': 'Las Vegas',
#  'u5o_QDwRPQW8gjgFudu9bg': 'Stuttgart',
#  '0Fhcuf1rKxSZOWQ4J56udw': 'Las Vegas',
#  'VDjzt6N--TMXH4E7Y6ialQ': 'Las Vegas',
#  'FEwPxhjdVKxSPVQQAHX2gg': 'Las Vegas',
#  'yvWZJA-h-UEC_Xf51eE0OQ': 'Las Vegas',
#  'w7Q-WMxPuznP-P2Y79ICng': 'Las Vegas',
#  'vlcsGHaSPAS_Bb59EW6E8g': 'Las Vegas',
#  'ynaNvoqkUEm0Uoh06EltZQ': 'Las Vegas',
#  'DgrIg1OR7arL8tVRiZ-psA': 'Toronto',
#  'Vc4QSYKAOf8NXriGXo919Q': 'Toronto',
#  '8q711of5XKzLGJ400PI09Q': 'Mississauga',
#  'QEt3srla7bfPICwlXqRsyQ': 'Ajax',
#  'P5f5Dx3_rL0znuE4wy77xQ': 'Mississauga',
#  'IL1-dyCe_zSqhmt0ExL_Jg': 'Toronto',
#  'CXwHjHxwGDzRTgvU_NdLIQ': 'Mississauga',
#  'mT_0RP1y9qYyfU4Kd2SRTg': 'Mississauga',
#  '348o9qgR_hiNe25Rs-CDsw': 'Toronto',
#  'h3q-Y8pf1-_0jKgdEj29Uw': 'Mississauga',
#  'cW1v5mgoC8KAZsHanDLAUw': 'Mississauga',
#  '0CSlu7ZhK0SfEmo_1WkcnA': 'Toronto',
#  'QgiR84sGGz1jpGLMs-ZGSA': 'Mississauga',
#  'K-q7oE90OWNZ8IOXQqXsAQ': 'Toronto',
#  'mOVyk3O18VY5nrUMTZgM1w': 'Toronto',
#  'w2C0_M6WCfxYuY7ZvoSLvA': 'Mississauga',
#  'PbuXIB-7MRXcf1Ueg_g2lA': 'Mississauga',
#  'XcO7fb0q-LukfudaBMNPIA': 'Mississauga',
#  'itI6CqeR92ikei1n86N5sg': 'Mississauga',
#  'BCjsgRFDCxGQHr0hVlwqvg': 'Toronto',
#  '39VYc2nWSdvdTCldsDJ7qw': 'Mississauga',
#  'gPK2AKr-UA_7hZus80SSng': 'Toronto',
#  'Rk_O89vyLCcEa3Xq6RYftQ': 'Mississauga',
#  'ff_rH18q-V_VhrKSzZZ16Q': 'Mississauga',
#  'ieLHSYDzCnLbX1IjZBUdRA': 'Toronto',
#  'wkqy2o_qF0S_Z4vyG6pdIQ': 'Toronto',
#  '3bCDpygbXAkRDWxQ6_Nf6w': 'Mississauga',
#  'eOTzkS-by4pVwwCVrifmqg': 'Toronto',
#  'B4Rwp0SUYwO8lgSHVT9w5g': 'Toronto',
#  '_cj4j6-FUBda7AvWrclHTw': 'Mississauga',
#  't21OyjIVoBMRmCIaElwuEQ': 'Toronto',
#  'hFefNv6jWn3_cSjN_UwXNg': 'Mississauga',
#  '-9RU4LuI_TfYgv9rBijJoQ': 'Toronto',
#  '1mie5crWiX4eMNEhmd5LDA': 'Mississauga',
#  'z-9-XZdrmRrOFpMKAQ2rvQ': 'Mississauga',
#  'L6HGM8pmm2xCC8RTFqv0og': 'Toronto',
#  'm0uVfBkFiTbzg1GedPmBug': 'Mississauga',
#  'p-6RZe5JAtxB17AS4wOaXg': 'Oakville',
#  'Hg1EF9PjGfcKBSNMjvWBeQ': 'Toronto',
#  'Aqtnyl-rhUZF_zxDXlf0sw': 'Toronto',
#  'RgJ_nkjVYUKzCr47qJgSSw': 'Toronto',
#  'kD9Gr2IxZQv0CNp5D-Bsjw': 'Mississauga',
#  '0SNb69rzZWY0OQtBCNoqDg': 'Brampton',
#  'TCf3Qt9yyaU6kYERVTcBWw': 'Montréal',
#  '9YAcyOPntf2HJszcWgkLow': 'Mississauga',
#  'zcBBHrItGGRHMEOEt1sT_Q': 'Las Vegas',
#  'Mxw0lh2sAXrnidgvA9QG4g': 'Mississauga',
#  'R5_K6l9rSyYABGK9Bw2iEQ': 'Toronto',
#  'jll5IjpfWOknurqUYxtsiA': 'Mississauga',
#  'QWzMD9MDZH2RgnvOpoKTgA': 'Oakville',
#  'E1hLHq6LZ6AoSJzW-oT4FQ': 'Toronto',
#  'jnB_saJqNfOmVoCWquhAzg': 'Mississauga',
#  'QAkz4WcqCjVmq6UGuZD49Q': 'Toronto',
#  'AsiS6Ho8XR3OjEh2XLnauA': 'Mississauga',
#  'icqY1lAj3NvhLXkMEjdeRg': 'Mississauga',
#  '-yqTLzfd-L9war_Mm2s8Eg': 'Toronto',
#  'kwyIPeGyXFpYVTJ5SoAuGQ': 'Charlotte',
#  'cx4-WfPgm1Jxurtd83I83g': 'Charlotte',
#  'KLVRBakCWcDdUTcb3UMsZA': 'Charlotte',
#  'cmCNYsCybXczlSL9O7uiRQ': 'Charlotte',
#  'tuEmVbQfHXG5BmD7edTLNA': 'Mississauga',
#  '0Ilv9MMRxIJwKko8henjbg': 'Toronto',
#  '0YSRhsxw1ca0EKJBpi90Uw': 'Toronto',
#  'l6WKaOQra85pIy1L7rxY2Q': 'Toronto',
#  '02AOwJB1g9ETIDGZznyuAw': 'Toronto',
#  'BxCgM2bsV0AUvOpT42_klA': 'Toronto',
#  'H9bbrN-ZCCkLIYJo7-D1gw': 'Phoenix',
#  'sOudRDE_R3VYni0rEYFkSA': 'Phoenix',
#  'NlMGxLkQOYsJ2u7lCA9dvw': 'Mesa',
#  'rtmRMQQ8M2VMhZYjvBmbFw': 'Tempe',
#  'HUN33bP2LofcZctrpOyKZQ': 'Phoenix',
#  'W41iFVGdDatFi-C84gBFJA': 'Cave Creek',
#  'uE590yKd81Dye9XgKFK7MQ': 'Scottsdale',
#  '7fHmEe2V87xvN6MAEhFHJA': 'Phoenix',
#  'siVtjO8xrSxbrK-zqXCGew': 'Phoenix',
#  'gScmsSCqBeFPp6q9yG5nmw': 'Phoenix',
#  'MdGnY6eLxy82nEZhCc6rnQ': 'Tempe',
#  'MHiZ9Hbb6EIwRVGPFC46tg': 'Tempe',
#  '1bCRapFkVMwaGjbkzR5AmQ': 'Tempe',
#  'RqT8iYp-hp6pffWp0wX3Bg': 'Tempe',
#  '7UVOk0zGatVhfUfrhRA8jA': 'Phoenix',
#  'PdCR2ElSc0cVym5dCN3Zsw': 'Gilbert',
#  'hoALQHHI73AgzNycC2HcYQ': 'Chandler',
#  'WxScj0nzEvncQ7ZTY9HZXw': 'Phoenix',
#  'S9Jw00eZHVj5_0sOM_C5Rg': 'Scottsdale',
#  '5Hj7YNszxRa1TmbA9L0rAQ': 'Tempe',
#  'd303YCqPUawYNErFfFlQGg': 'Phoenix',
#  'LV8uSpYJVaYZ1goMwk8xYA': 'Tempe',
#  '60_lsQJ8JEGfZeXcTgKn8Q': 'Phoenix',
#  'mBjfiKkyz8pZ3N97uG1cGg': 'Tempe',
#  'jdWEXRH_DaXe-BsXeVfTuQ': 'Mesa',
#  'KcEa4h8xvyHOWSbbU52bkw': 'Phoenix',
#  'ktm2YMsb65tRnePcYpVlqg': 'Tempe',
#  'TQ9A1LVp6z-fIc494RsLDQ': 'Phoenix',
#  '3xORNxbKdd08LUf0tclx3A': 'Tempe',
#  'Ld59_S-w2gXtCsoX5Vuktw': 'Tempe',
#  'HniT7WZjedXOqzaBo_gf3w': 'Tempe',
#  'LrwvXGiGPAg7mEAppVW-dQ': 'Gilbert',
#  'KhWYMiyz6_46SIZLMCogVg': 'Tempe',
#  'jwzo_uLsB-4njvL2q0aUMA': 'Phoenix',
#  'DZOA0yCbH4kDS0s-dHXWFg': 'Las Vegas',
#  'HGN7VARRSkm_M0G6OW1FGA': 'Tempe',
#  '2ObGypunasuj3SbvSMcT8Q': 'Tempe',
#  '7GU-Hm6meue4fwUfDX2miw': 'Scottsdale',
#  '1vdMqzJrKjZXRFMAiiUGzw': 'Las Vegas',
#  'd_WNWUTOxJtdBlt5c_Ex1w': 'Tempe',
#  'dK1-RZPuUXSHYMWE09zxbg': 'Phoenix',
#  'nkCQg16DbT_1P3NqVPjoig': 'Madison',
#  'CbwqJgXyoPFHCGkRFWt5Fg': 'Madison',
#  'lzf7NsjgMOIecyzKD9eRSA': 'Phoenix',
#  'itmb9uAolzQnmEBDlV24qQ': 'Madison',
#  '-N1rDtpUIHpjrEujRyzVKA': 'Madison',
#  'fJ_qSZH_akvWzHUPMqab1g': 'Madison',
#  'seAX967Wk8qiVXOYjbregg': 'Madison',
#  'Kx9x_dAOMcQYiUu5-uUTdA': 'Madison',
#  'lV0TGQufw-draFAWiawdSQ': 'Madison',
#  '5oM7gXmeX7s6T1_KlL30yQ': 'Madison',
#  'BnLFYUzUnPYgDhazfQua-w': 'Madison',
#  'JWgti_adPZywG9SKUbnB-w': 'Madison',
#  'HLaSqQMDVvlcFPGJL_kGCA': 'Madison',
#  'fuoYjsuU7qy1RlCMEZ0xfA': 'Madison',
#  'gh_RvEPwTMj5OXp8j9uePw': 'Madison',
#  'esaDbON8NXJC4PWt_CheUg': 'Madison',
#  'jtD2TF2Pr-bwT6RwPCAE4g': 'Madison',
#  'q91tQNboB-0HWtM8cXRjdg': 'Madison',
#  '6vlB2FYf2dGVWte9cViVcg': 'Madison',
#  '66e_wFUf4GsDT2DTZ3u-Xg': 'Madison',
#  '38V9LFE9gbmqdxACJ98F8g': 'Madison',
#  '5Kbn1FjXmS7Jypz3_ybt_Q': 'Madison',
#  '237EL2sEpc-ZUEbo0HUYGQ': 'Madison',
#  'WG8V2B6DAT4lEA79Eraxkg': 'Tempe',
#  'MPozTU7MRVKYISO5prvzdg': 'Madison',
#  'h-aavgzksw9z-Rlwn9qZ8w': 'Tempe',
#  'PxtbSDlYndCx2-KWpx49Wg': 'Tempe',
#  'hI7LDDh6GIgh9Y_T73hDwA': 'Scottsdale',
#  'O3kOhTvb0kaysusMl0MSBA': 'Scottsdale',
#  '2yLD3esBneRzDI4Uh26q-A': 'Madison',
#  'zhQ8XCCvvhLAIRaNIcth0g': 'Phoenix',
#  '6eukXWU7RbgXOr-U9-veHw': 'Phoenix',
#  'jYHrgDDz-mx5nsF-M6RdGA': 'Phoenix',
#  'oTJW_1bmoa_KQ55ERtC3sQ': 'Phoenix',
#  '5CsexqnkjNdon7M6okJ-tg': 'Phoenix',
#  'jzs7JvXvLS8LAC8Vqayccg': 'Phoenix',
#  'UdY2po4EWqYIYCUCNUjK4g': 'Phoenix',
#  'iJfnk3trvpModWj2V-zpnA': 'Cave Creek',
#  'qyQdqgoSW-inYUdmvQfJzA': 'Phoenix',
#  '2vqLKLVcsKD1AdIDbJcc3A': 'Scottsdale',
#  'tJVDBw8cj92qfVCkXwEkRg': 'Phoenix',
#  'tZYVHdCKznlcM5tiEIE2aA': 'Phoenix',
#  'y3FNK-UpHuXmNucC_6slrA': 'Phoenix',
#  'ALK9WBaokEtmotik0RepTQ': 'Phoenix',
#  'jY6G9fiCM-Vo9z1uK1dQDQ': 'Phoenix',
#  'm8TocXqEEPsxjmz1ql7_3g': 'Phoenix',
#  'IZV6t4l-YivWsc8cEytEHw': 'Phoenix',
#  'EkvFZ7vHwEpkKGY5-WeaUQ': 'Cave Creek',
#  'seXjsuewdnh8-y8Ruow-Kg': 'Chandler',
#  'riaO_Lw2qfLBu22FpdMA_w': 'Phoenix',
#  'U0PtdIN508sn8RVJ4Mcs6w': 'Phoenix',
#  'HEobaj3QfS15reMJdhv3Rg': 'Phoenix',
#  'SbMSN-N7WGW3W8ayZYru0w': 'Phoenix',
#  'VBSCDqyBRltgvBxLNOR4Uw': 'Phoenix',
#  'tsXlmhcm5I43HrWvzrH9ew': 'Phoenix',
#  'q7MRk6FBmx0H2xrZ10QUpQ': 'Phoenix',
#  'XdLf7dZH-6kEcZMzo-lG8A': 'Scottsdale',
#  '9R19VOuHHzdsZUrE0eecgw': 'Scottsdale',
#  'jVkOyGV7CybBfqk6vF3Q-A': 'Chandler',
#  '4jN7gnDv9GJrNx_fPUziZg': 'Phoenix',
#  'TK7208ZMWAERUUY2dEtD6w': 'Phoenix',
#  '_labePetwAjwgWBUgV4wUg': 'Phoenix',
#  'NGkwcw5RWqDjSJOkfewgZg': 'Phoenix',
#  'wQbhmTsxwIyuPIIyyIHb0w': 'Peoria',
#  'PB1bOiWSUMipc2km17q4uw': 'Phoenix',
#  'Z4uvXYqvOfVR32VGvNsLWw': 'Oakville',
#  'Cm1oxY-7c3lgiLDME21wfA': 'Toronto',
#  'ON7__MUlZbxNn0a4T_09uw': 'Oakville',
#  'TUu4SppnJ1S3lQ_jTxMpOw': 'Toronto',
#  'V8ym34P-oibsEMVQWj-evg': 'Phoenix',
#  'KWY0QyEXEMGh6xCB5oMUzg': 'Scottsdale',
#  'uy1yiRgtV_8dJGlWL7IW3A': 'Phoenix',
#  'JP14p-CIOd-4jgVbsXRsAA': 'Phoenix',
#  'wqrXw4Vs-oW2WNZhWh3KKQ': 'Pittsburgh',
#  'Wyciy32b2y-8XDwM_mSCcA': 'Scottsdale',
#  'GYNnVehQeXjty0xH7-6Fhw': 'Pittsburgh',
#  'g94Ml1oo2qQe_iGBJL8nAA': 'Pittsburgh',
#  'Lq6VdEsdhqKwR0ouqlxpMg': 'Pittsburgh',
#  '5JVY32_bmTBfIGpCCsnAfw': 'Pittsburgh',
#  'q3ycagiLqUaRkOgEPf_gbw': 'Pittsburgh',
#  'ng647hYAjWC4XANaACiPXA': 'Pittsburgh',
#  'MCsNB80uwohCMB16vc0mTg': 'Pittsburgh',
#  'ZnIaEvJwrxlBUjimIpx2Qw': 'Pittsburgh',
#  'HRP5zLOrhXgLYAlaBt-HgA': 'Las Vegas',
#  '1o8vB0WKHfV7omrYWB_OLg': 'Las Vegas',
#  'kmC8nIGdQeLUOBCgRDzS8g': 'Las Vegas',
#  '00Z-tCcJVe9LVP3GakkqDQ': 'Las Vegas',
#  'TyepNPbEnMCy1_IhsT0YAg': 'Las Vegas',
#  'n9zwrWp8EeB9ODTitKZYsw': 'Las Vegas',
#  'bLbSNkLggFnqwNNzzq-Ijw': 'Las Vegas',
#  '4vl8Drja0PETBmlNCFZbvQ': 'Edinburgh',
#  'JCG7J-NmLxgmJK1c4ZRKmQ': 'Edinburgh',
#  'BnIY7cXbUfnrEqoQdQc9Pg': 'Charlotte',
#  'qePB-HLOeim-BDMG0QkfuA': 'Edinburgh',
#  'h7kFt1px7Z5A5e92X6aMvQ': 'Edinburgh',
#  'SfY0jEFqBkrqq9bVi6P31Q': 'Las Vegas',
#  'eN2pCfT17EGokP9UWnoZUA': 'Edinburgh',
#  'h_yuvACgAPnBL2FXiCF4Yg': 'Edinburgh',
#  'Dqji5fRROkLc3eNMMQOI_Q': 'Edinburgh',
#  'nhVvcPyRGLw466qHVbUjrA': 'Edinburgh',
#  'A_dC3FJOqvlsDEiDyMrzlA': 'Edinburgh',
#  'vbq-811-_beGtp-SSQhC5Q': 'Edinburgh',
#  'SxV1Jq7UANuSYpn42JXvOA': 'Edinburgh',
#  '7-ahDxB3qUg6nf3tvfG5Nw': 'Edinburgh',
#  '3jjiY5D7oIlKeiCIZGHQew': 'Las Vegas',
#  'R9UNH0rb3a_glQlk4ylKCw': 'Edinburgh',
#  'wTJhR3NdvpCB2ZAx_qRiqQ': 'Edinburgh',
#  'mdc0aTVned3fPyRb77a0bA': 'Scottsdale',
#  'Q1NOOUUhY-jQc2y5MZgdhw': 'Edinburgh',
#  'WEO4AW75i86EiMEfH0mRfw': 'Madison',
#  'vQnR9L9HILjw4PgWB8q1cQ': 'Edinburgh',
#  'QyP254XCNlI7DvPsze5LQw': 'Edinburgh',
#  'qKzcpJh5CAXgXzfwC5NMhg': 'Edinburgh',
#  'fcMTpwfLS9F5DWTqlp8ktQ': 'Edinburgh',
#  'yaBIVHDxaUBN2YHQ8-YiuQ': 'Pittsburgh',
#  'Lcjx46gQSDvFEGb-XJMZyQ': 'Toronto',
#  'WeVkkF5L39888IPPlRhNpg': 'Toronto',
#  'CaaGjAM1yL_t4yhNLD3f_g': 'Pickering',
#  'qnoXQsDOTOFwJEYXSCnHEQ': 'Las Vegas',
#  'dLk0_ttzMKap0fv3nxtRFg': 'Las Vegas',
#  'C3htqYqHwV-anAySpONSdw': 'Las Vegas',
#  'YDXHsLuMrlJ4yDr4na0eOQ': 'Las Vegas',
#  'h8DCmxMLBSUR4ZCH5bu0Hw': 'Las Vegas',
#  '53p6VeOCuYidZ4xH0vo__g': 'Las Vegas',
#  'r0nq49A5OuqXtUwEmWoymg': 'Las Vegas',
#  'slm_RlNeC1nh_PZbdbOKcQ': 'Las Vegas',
#  'G_AgCfpYj4pBHauR4fwYJg': 'Las Vegas',
#  'owrNd439iiqvh9POeJQ_Ig': 'Las Vegas',
#  'd4Y666iWUyf5L7EqUwzu3g': 'Las Vegas',
#  'ayAI9D_AGSjLM1ysduF8-Q': 'Las Vegas',
#  'zW3PaTqR8fN-mnoYWk6Ymg': 'Las Vegas',
#  '_qama-rZ0SaAqhhJBf9L4g': 'Las Vegas',
#  'HMWzlSqQsEq8Yxehm_sMRQ': 'Las Vegas',
#  'AYESvJ2yiikh6pMmfv3qIA': 'Las Vegas',
#  'fnIItxznQHlG1s_HoJzEQg': 'Las Vegas',
#  'zNOmTv1RlweHG8B7_TDDvA': 'Las Vegas',
#  'NcwMPuYMaslw_2pnJRRK1A': 'Las Vegas',
#  'OtoCNQSiG-xHf35lUsolNw': 'Las Vegas',
#  'XysBRG1pvBXnj35pAJ1zdA': 'Las Vegas',
#  'Rj1iz-j0y0YfnUWogk3v9g': 'Las Vegas',
#  'h6P9yWlrVnDY6xk5vfCAjw': 'Las Vegas',
#  '3__vXgIxGc1i_t6Dk3jSBg': 'Las Vegas',
#  'BwKruOoLESefcSEYJXLf2w': 'Las Vegas',
#  'IEdf1Fjtwi1eVkU4-65QoQ': 'Las Vegas',
#  'zoR7WPfqc287yjYx5iD8sg': 'Phoenix',
#  'kyIrmeTVS0afkTmjZ3B5Mg': 'Las Vegas',
#  'L6-_EsiHFy3a1K2kGOdm1g': 'Las Vegas',
#  'gj4tQ7TvK_qHKvNgIljqNg': 'Las Vegas',
#  'wOPx3CP-3bkZiewMU7Y3gA': 'Las Vegas',
#  'XIJ1LrlsZmqy2i2_bG2WSw': 'Las Vegas',
#  'S-9IHFuFvads0LWMUOItMA': 'Phoenix',
#  'Bpy7R6rpWCNb1alj6Fd2mg': 'Las Vegas',
#  'Pa7O0ZFwiqZlwVyCoX416g': 'Las Vegas',
#  '4Iwu57GSychxpqa4w4HAMQ': 'Las Vegas',
#  'vPqCe2zg_lNrvzBDT9MpLw': 'Las Vegas',
#  'dqKGX-Zz61Cz62S86mHNmg': 'Toronto',
#  '8EwEZj85tAZBBW2pXof3YQ': 'Las Vegas',
#  'ugRjXKkMj-4kRsoojto9QA': 'Toronto',
#  'xLkQEb6nzAQMaHhNzFYvlQ': 'Toronto',
#  'E3iyr48gSK-dZEwoj7Z-hw': 'Toronto',
#  'Duhy1-3YL7SOrThDh0vI7g': 'Toronto',
#  'dk8-B6hKb1XOmYJKC4Ig3Q': 'Parma',
#  'j5yfS1QjGwNLQ0h4_wDyxg': 'Cleveland',
#  '9RG87QSBaTmcbDu3ydQJ2g': 'Cleveland',
#  'y6IogOYLjAs8Mksx62vnDQ': 'Cleveland',
#  'VKwI11qTXOxHmlh2yr_2TQ': 'Cleveland',
#  '11gZ-oAPtbVo8xpld5axIQ': 'Toronto',
#  'YqMpcRUA0OMw1WNLDGoj-A': 'Toronto',
#  'QKFyP1U5cPdtMHIKJrzbCA': 'Toronto',
#  '1Sl_w3Reyrirhxp4wpW4lQ': 'Phoenix',
#  'ABPnzKPWAoYzuoNn9bHq-w': 'Scottsdale',
#  '5Zh6lmoXF2S9SYYsq0W3bA': 'Mesa',
#  'bWh4k_cCuVt5GLVd33xIxg': 'Cleveland',
#  'nQ4e81UdfczimYcIUtO3HA': 'Cleveland',
#  'bAwfPH4lXNzgcYp9JFy6ow': 'Cleveland',
#  'BjtJ3VkMOxV2Lan037AFuw': 'Pittsburgh',
#  'J50BanBFNY4naDYAJRAZAA': 'Berea',
#  'GKXrTZecEsqWuACpRNyuxw': 'Phoenix',
#  'gSwBZSw7lem2IEB8jId4Gw': 'Cleveland Heights',
#  't8gR8NCD56bF1XcAjwgkEw': 'Cleveland',
#  'nNtI1xRXcZs5R3sBEa8xqw': 'Kent',
#  'kEEx6yEf81i9Wk5Ww1q6GA': 'Westlake',
#  'igcnVpgAYC2EMP0sXZmuTQ': 'Cleveland',
#  '3AC_liBwORA9w18CIrGxcQ': 'Lakewood',
#  'FDFJk0feR-RAGHkxRr_3Nw': 'Cleveland',
#  'II7eBcZJRLwnFtuS6BtVRg': 'Pittsburgh',
#  'C1TC9xbL-rbN8UspYPgXZw': 'Cleveland',
#  'ZpiAtR4WReIbMy54vXNqtw': 'Cleveland',
#  'T1XUUXIEU5uj3NmdWAdIlA': 'Las Vegas',
#  'eO7Wam6CD5-2xE4tfqFFkw': 'Cleveland',
#  'jHX2qMpRIg-W32vJgi50lw': 'Cleveland',
#  'ZJCWUrxd2YzEj5yLshYn8A': 'Las Vegas',
#  'ZEwpJOG8PFlHiFRdAZZ0iA': 'Las Vegas',
#  '9BeV9g26iBVMkDPRWjW3AQ': 'Cleveland',
#  'VOUnXOlll52vwQcJK1tm8A': 'Cleveland',
#  'GefiDYsb2U_-3ujGnheSpQ': 'Cleveland',
#  '79Vv70bMS1JC9ASCg4dWqg': 'Cleveland',
#  'SaSXRzjHx3SMTNnW90PetA': 'Cleveland',
#  '8RegOEQ0s89jMHGqs12RYg': 'Cleveland',
#  'G5reVMkdwUc-souSaLdm_Q': 'Cleveland',
#  'hWGZN0cma0MtPk0PpDHnhw': 'Kent',
#  'zEil7zukF_Xtxq7sqIbyfA': 'Cleveland',
#  'I1Jhth-yxtz4mty6C2sWqg': 'Cleveland',
#  'RSAHZjr2yPZHZ-HhrgCrXQ': 'Cleveland',
#  '_YkzpKm4TAUfx8vckSTDgA': 'Cleveland',
#  'GBo2RbrSn9vdOrlQV8N8Sw': 'Cleveland',
#  'OKe55-f2tvTWDDPHV5cZtA': 'Mentor',
#  'FKZG5e-1CoMZ6kLUUVrqcQ': 'Cleveland',
#  '2n03U1y-9Lr3gl0CcMrHPA': 'Cleveland',
#  '07TtxrRM0b9qUBTWM5wNiA': 'Cleveland',
#  'DK57YibC5ShBmqQl97CKog': 'Tempe',
#  'IpReaQYuXO_nB07xnkHuNw': 'Cleveland',
#  'JdYkvy8lIodJ0vwJ4jzYYA': 'Bedford',
#  'x9g-i1DsB-VjSDGVOdRonA': 'Las Vegas',
#  'S6TvDZGLWHXjjCbGufE1QQ': 'Las Vegas',
#  '9dYJu74tHGBXrqi1cwvpUA': 'Las Vegas',
#  'Omgam9HDsT1BABnQBZepnw': 'Las Vegas',
#  'GnfXMcbFNEtE5oMUHINdnw': 'Las Vegas',
#  '2-XLTj0Cfd81_XlmHo02Aw': 'Phoenix',
#  'o3Zv4AolGeRr-xX7QhESUg': 'Las Vegas',
#  '9Rq-HzDMgiMvKo1wxRL-vg': 'Las Vegas',
#  'HuWEj615KvxRmjJq8JY7Ng': 'Las Vegas',
#  'IyU01Jx7GF3BcJ8w-_T2EQ': 'Las Vegas',
#  'Q4HP58l-YwqN4zryiZfZLw': 'Las Vegas',
#  'sfopdViM5iWt3UHeJENCrQ': 'Las Vegas',
#  '8yJwzY5kRfRTqg5UdoMAsA': 'Las Vegas',
#  'C6LV0p8L6IfBfh1YFRkWzQ': 'Las Vegas',
#  '2Fu4xzc4Z4SvRGDcfC0qfA': 'Las Vegas',
#  'ycVIThPWpZa2TfTlonf4fQ': 'Las Vegas',
#  'abMIw41Injf2rIMzMRUm7g': 'Las Vegas',
#  'MF6hGVEnsWqhoPLB0g0wTA': 'Las Vegas',
#  'A2N4y0VeZ-3TtmBVCSVVnQ': 'Las Vegas',
#  'qewG3X2O4X6JKskxyyqFwQ': 'Las Vegas',
#  'p4UcEYTLJyh96o1R8wrJaQ': 'Las Vegas',
#  'jH4i-q5cyHdLKDTJER0oew': 'Las Vegas',
#  'DiPRm3FaydnIidnzpvdmeA': 'Las Vegas',
#  'A0wA5x2BMj-5l2sWn1hxYQ': 'Las Vegas',
#  'DecPgdMdR5GPJIjkhRkWdw': 'Las Vegas',
#  'W9MPolPlUiUEXYfGnYiHEQ': 'Gilbert',
#  'pnrG47iwW26dDyHCwEr8UQ': 'Las Vegas',
#  'cyFYb0DSjZLlaVUp7dsD3w': 'Las Vegas',
#  'Z4cmKIau4Ie5ABXmj8wtwA': 'Las Vegas',
#  'OXWEpw02Yq52_lFJ6c2Lbg': 'Las Vegas',
#  '7k5I6nL-4ywRFEjrvr8FBQ': 'Las Vegas',
#  '3fuphUdxapoi7ags9kAZ6Q': 'Peoria',
#  '-IbGzbx2qsGjJHm78fbj8w': 'Stuttgart',
#  'bVkNsrA6W0LwEIVIKhiV-w': 'Stuttgart',
#  '4xqaWaXGO0el_jmTkm3c0A': 'Stuttgart',
#  '-c9G-JHNqrPY0_UU9j7BJA': 'Las Vegas',
#  'natSObJ4-jEev6rJRta7jA': 'Stuttgart',
#  'fp6wXrr5r3poOg6YhL4yvQ': 'Pittsburgh',
#  'Nc6Ng7WWY0sZHkDco9xcdw': 'Pittsburgh',
#  'qr12XETNuzne_rbpf0rmug': 'Pittsburgh',
#  '47f21XiNtNr2lRjCTbDPvA': 'Pittsburgh',
#  'tb7q_TIKu_pha2UFyneMmA': 'Cleveland',
#  '6-RXoqxa9L3FfBwkPLrtbw': 'Lakewood',
#  'Ty8k7Wj3kXMcCvOHsu-ptQ': 'Pittsburgh',
#  'J9mHpteG5XVio6NqcwHPCg': 'Montréal',
#  '5ZrFDFPJe8Qq3Zgue315oA': 'Cleveland',
#  'EEI1wjfuZIFshDl1ue9N8w': 'Cleveland',
#  'TjXqTqYOXAs8VKo_otj3lw': 'Cleveland',
#  'w1CYD3yWvajHzAbyNEjKuQ': 'Cleveland',
#  'wQSS08uB5vwIFS-ZM4BkdQ': 'Cleveland',
#  '_tHSAp8CgI14if0rnD2aHw': 'Las Vegas',
#  'jWUJsIt9FPwNYsl3ckJSoA': 'Cleveland',
#  'yK4njGSBfFpZhDuTxNpnLg': 'Edinburgh',
#  'LBcuPALypeSiLalEZa5JbA': 'Cleveland',
#  'J2ypbaPCF34BJ9IY7W0PLA': 'Cleveland',
#  'NkYR1Ejn4nQ1Mm5zwZYIPw': 'Cleveland',
#  'uO21Oi5nmXCeEQJOm28lQA': 'Cleveland',
#  'M_qwexE6ciWB4tJ_T1S6hQ': 'Cleveland',
#  'Kw5RHGNWA3ByBPzMv5oaRg': 'Pittsburgh',
#  'jpdigJmHkSdTy6QzB74wdw': 'Cleveland',
#  'cA7hAhlsXIotA4wRLdAZBQ': 'Twinsburg',
#  '5NAdHDoMQ63PYn3CVFC5BQ': 'Cuyahoga Falls',
#  'UCnk2nOq6cvtjboMWkhO9A': 'Etobicoke',
#  'yT1A5dsWOfkOb2-H76JQIQ': 'Hudson',
#  'MBf09zdFcOEnYA84aENzXA': 'Fairlawn',
#  '9PmUzfxz3vamMaTzGSesyg': 'Cleveland',
#  'R_43l6k5NWPy7eRv6cjYEQ': 'Cuyahoga Falls',
#  'wRzcrtxZj7MfzQnxrsqqfg': 'Mentor',
#  '3W-1dd1S6FylTU4QIFv-_Q': 'Cuyahoga Falls',
#  'yDirjgppPDkY2Bv60ok6bA': 'Cuyahoga Falls',
#  'RNUV7k_Ng4KdasXQMsOo6w': 'Hudson',
#  'aRzBh8fCzIRpMwijyN4sLw': 'Strongsville',
#  '93cD5Ev-PhA1Hut7wU0ctw': 'Cuyahoga Falls',
#  'oDoZe4gYUCb7ylHuhWFUow': 'Hudson',
#  '_MjgqPR1pvDnZZ6wCwabBQ': 'Kent',
#  'jLpQhFMglWJVqOQmAeDVRw': 'Cleveland',
#  'zypGaZmq7QhyV6TZfQrayg': 'Hudson',
#  'JMe2ZbikZVxRr6zEMIys1A': 'Kent',
#  'IkLWlkJek2e4It8Xt6vIwQ': 'Stow',
#  '51munej7rdZuB7KfPofhaA': 'Stow',
#  'NJqmAzerpbAIC0-VBclwgA': 'Cuyahoga Falls',
#  'jVx2YOXofzQJFL1pXVlVjg': 'Cuyahoga Falls',
#  'IL_vLMXtXw7RvzMB2N5h3w': 'Tallmadge',
#  '0GxKcZqhtzBbhHsTpcv1cg': 'Kent',
#  'S6gAeiubzQ7FJOdMvipsog': 'Macedonia',
#  'dD5vTDPzv_79m8_zZhc9hA': 'Cleveland',
#  'MZVSvbnghsV8uDM-TnPTKA': 'Fairlawn',
#  'zrEx0FVoPnk23Ny-uiOQSw': 'Cuyahoga Falls',
#  'JwQUSRWaxQjsXqTCKjkmbQ': 'Fairlawn',
#  'oV7mgTSAg1l26ieQ82yyVQ': 'Kent',
#  'gpV4qU5swBe2Eo7rRDEzjQ': 'Cleveland',
#  '7YqIOPRpr_ldE9xwfMZvDw': 'Cleveland',
#  'iNUH_vfvhzF7qxg9k0ofsQ': 'Aurora',
#  'hDSeawZ10uiqU8lZk6knUg': 'Stow',
#  'WoKCLSctS7G2547xKcED-Q': 'Pittsburgh',
#  'mDfSB8UtFoKxHkrtBcikhg': 'Las Vegas',
#  'RN0r5vFDP0DcmL7rmKD45Q': 'Cleveland',
#  'EQGF7Eyt65qhcCMxExDDNA': 'Kent',
#  '0GVyC7DxFsgnG8SeMPHPIA': 'Stow',
#  'Q2xIT2AWVPDnoknkghaDhg': 'Cuyahoga Falls',
#  'T9yWXszhzEKDVaNH09aa_w': 'Cleveland',
#  'gTE9uptqKvCDP9EZ8o7CmA': 'Cuyahoga Falls',
#  'DZChyIi8X3LMVLi86793VQ': 'Las Vegas',
#  'Q_QsCiaeQ5T_CfmidxEM7Q': 'Macedonia',
#  'bxtUw-buCnWybRbjc8cYYw': 'Rocky River',
#  'Y9oXy1NMExRpK3ac1mYCIw': 'Cleveland',
#  'PmgqNO0-5Y3e3UoR61TD7w': 'Brecksville',
#  'jBEOFvUNNGrG3AE0GmR-lg': 'Concord',
#  'H4_YPiEqsGYiUWWHx63h9Q': 'Stow',
#  'sreN9pXwVsTu1RMY9WnLpQ': 'Las Vegas',
#  'yV1PN-KG7vMKV9xyM4JToQ': 'Las Vegas',
#  '8a0GHVSVs3rSRtNIIR4rlw': 'Las Vegas',
#  '6ZC-0LfOAGwaFc5XPke74w': 'Las Vegas',
#  'p30VbeNZC6mzRUTL6lg69w': 'Las Vegas',
#  'D3GeQgpvMLwZCCHHdvyqaA': 'Phoenix',
#  'WM7MFrRP-7YFuGBAJ6quRQ': 'Las Vegas',
#  'UcXu-RZbJdjRhgFbfV-gXw': 'Las Vegas',
#  'zrqxV5G0bUIKvGObnMSNcA': 'Las Vegas',
#  'INNbJHteG02dS4VqoXoqKw': 'Las Vegas',
#  'EK4B8i9FJfw539XnWGAV0g': 'Las Vegas',
#  'eO1ZCFWJCZcETr9dfSydRg': 'Las Vegas',
#  '1wz1YTNiw9FJye3FRhj1AQ': 'Las Vegas',
#  'X1Cy1xsDawDiH0o9dmDIXA': 'Las Vegas',
#  'ee9YcVVzAuRLeQnY8ctDUg': 'Las Vegas',
#  'KqTnIUfwUto4Ka74JnzE8A': 'Las Vegas',
#  'IxrkMwtW1emHp7cifyq40A': 'Las Vegas',
#  'g_4zySOI_HisK5rG_2dw6Q': 'Las Vegas',
#  '4kM0hJIETOdBa2lQOnO8tQ': 'Las Vegas',
#  '43WiflwfTbmjizIfxvQ_jw': 'Las Vegas',
#  'm4e2fs8BObN0Cd69stfo9A': 'Chandler',
#  '23cjtl3AWJtxKL3O78-Djw': 'Las Vegas',
#  'G6Ni0mCoEaZ18ql5Sc2DZA': 'Las Vegas',
#  'U3sCAJc4_E3MGC1jGi19gQ': 'Las Vegas',
#  'LBnjYRrpTKgtGkW0ea7Ecg': 'Las Vegas',
#  'pxzs-Dy2hXTis-PuNCV37Q': 'Las Vegas',
#  'mdmdnlHLlZUvAE3-J5omCg': 'Las Vegas',
#  'FH3GgmOeAgXST37jG1-uWg': 'Las Vegas',
#  'hFFB48ybb4uSmh_CCeTljg': 'Las Vegas',
#  '0LgC7YzAQXBdbQZl0wgUnQ': 'Las Vegas',
#  'WoE8rLUh8Pu76lWw8soohQ': 'Las Vegas',
#  'J2ZTcQhg6_RJzOIiF_F3-A': 'Las Vegas',
#  '5elDILcQojTsX7GtU_N1Og': 'Las Vegas',
#  'vqoKrj-g8gcgpNMWZTZ0pg': 'Las Vegas',
#  'DuKiq3MPeLXESTZXRhJPHw': 'Las Vegas',
#  'ziiMYejVJAjbkRjSeAzrbQ': 'Las Vegas',
#  'tlTuLJOkeWga6vV3H6wnIg': 'Las Vegas',
#  'H-hgpOaBKD6JNfDCfqfBRw': 'Las Vegas',
#  '1cb8lvA4fluHn2j4Y5k45g': 'Las Vegas',
#  'aT_uTTaEJtWoJcqnSspUNg': 'Las Vegas',
#  'xsTc0-jryDgAE_HuOUA2Ng': 'Las Vegas',
#  'ywEB0MB_2U11NIGPs35pew': 'Las Vegas',
#  'TPKUUkAOlklihNGSOLSYGw': 'Las Vegas',
#  '5950WejSl2xLIa1bY1Du3Q': 'Las Vegas',
#  '6u49z3pjNVKs1O4rBmKXvA': 'Las Vegas',
#  'kRaJ_RuZqje3j5wOJe7R4w': 'Las Vegas',
#  'tJTv3DUwksO8FKYi48wmqQ': 'Las Vegas',
#  'ZtSzW0n2gSqWRAmQ_stkXQ': 'Las Vegas',
#  '_d74r_wGLwE4E8MxRKk-FQ': 'Las Vegas',
#  'EMqsN7DTFnR_VywY1SEc5w': 'Las Vegas',
#  'okwnuHs_LG62gq-QC0rpMw': 'Las Vegas',
#  'dY6GK465j-kLlrXalgdsNA': 'Las Vegas',
#  'knoQSph_vnj9SiugRB1BpA': 'Las Vegas',
#  'rvkVh-FNvg2fYSgHjG4mkQ': 'Las Vegas',
#  'Ktd04SKOw89dE2DPOCj2wQ': 'Las Vegas',
#  'U2f_VCU5GrfOZlZHsJjetg': 'Las Vegas',
#  'SvwD0zPT9So6cqgEsAhmWg': 'Las Vegas',
#  'KCD6daAp293FoOUoTjT_YA': 'Las Vegas',
#  'BNKWo55_3v5WNUgj-hsDZg': 'Toronto',
#  'UEhKQKMXGm-eOMvM-QD-AQ': 'Toronto',
#  'BGzavA_ddMr-jGmhArv7fg': 'Toronto',
#  'm-zwmnax4uMi8Fdy5iZlBA': 'Toronto',
#  '6UPWBTOfNoaGRahqTX14Ag': 'Toronto',
#  '-RCD8F7qbsLfzT3k1HtMxg': 'Toronto',
#  'uJ_gB_KrVeHbO82BiHc3mw': 'Toronto',
#  'HFECrzYDpgbS5EmTBtj2zQ': 'Las Vegas',
#  'eZZyuJDouIg4p-GYB3PV_A': 'Las Vegas',
#  'pngNlr9t4HObDgecGH_jaw': 'Las Vegas',
#  'kJOkmWQoL0Jy8iTea_V6og': 'Las Vegas',
#  'f81Y2EzuRqefayCrL1Ra3Q': 'Las Vegas',
#  'tH0uKD-vNwMoEc3Xk3Cbdg': 'Las Vegas',
#  'KL65Qt5OJzCt8LhioBw4Pg': 'Las Vegas',
#  'IDl8QswIXwI6Fr6KW3TbRw': 'Las Vegas',
#  'P62V2QfGKaubelwcdFbquA': 'Las Vegas',
#  'H3wPBzQCKCKiHcV7GZK4kg': 'Las Vegas',
#  'tL4NRC4uraCxjF8ZQ6GTTw': 'Las Vegas',
#  'MjdQiKzPs_JXizd0cRVFFw': 'Las Vegas',
#  'QEpNF4Hag6_W9Stc-1Frvg': 'Las Vegas',
#  'ELfzWgdf64VBLi5z1ECItw': 'Las Vegas',
#  'T3p9EIkwmsdlcX5Voi9XFQ': 'Las Vegas',
#  '6B9ICWLdY9C7gGPkRX93ZQ': 'Las Vegas',
#  'owbC7FP8SNAlwv6f9S5Stw': 'Las Vegas',
#  'Xsuv6bKcPUVDWih0DtEBbA': 'Las Vegas',
#  'cMts4uQI_MvF6Smk2erBLA': 'Las Vegas',
#  'BQkC6RneYfvfG6wRe0hsvQ': 'Las Vegas',
#  '0uo7LHVMFaDf1PkcGZprNg': 'Las Vegas',
#  'TEjjF9HcoR1hH017gWChjg': 'Las Vegas',
#  '8bn_HfSMq93mnd_ARHbvPg': 'Las Vegas',
#  'MSXlz6s0zOLsoXNg6pTXmQ': 'Las Vegas',
#  'UIdX_cI1awxvPH7kIFKpXw': 'Las Vegas',
#  'pohMK1VbTn9pod91xr1O9g': 'Las Vegas',
#  'Thew2366O9v9n8fKcQUYxQ': 'Las Vegas',
#  'S6cz25GMphB3QdpfCqOopQ': 'Las Vegas',
#  '9kEi_TTQSIgP52D7bto7EA': 'Las Vegas',
#  't_9U_94WuP_HUSEXnBgL1A': 'Las Vegas',
#  'yDbtyjFQKhqLhCFjfqQ08A': 'Las Vegas',
#  'IYk2DG_yBByVXxrVTo-BOg': 'Las Vegas',
#  'JADdo9NEeO5Az9aOYbyvZA': 'Las Vegas',
#  '-gO-X4lMH1eKnic4Z-bdCQ': 'Las Vegas',
#  'Kw6qblhrjvnZWfxMbUZokQ': 'Las Vegas',
#  'oNeyHF8MKilKZOUENpTk3Q': 'Las Vegas',
#  '5n-q5h4xYeJVSNk1TKMMeQ': 'Las Vegas',
#  'Zn8tgekH0oCfyk4SUtygoA': 'Las Vegas',
#  'cQC1gobqlD7FqR7MnQ5vug': 'Las Vegas',
#  'epkRB3J_oBEiyiwahvdmGg': 'Las Vegas',
#  'vivFH2_uIcOyqel-cHmxLA': 'Las Vegas',
#  'QNSL8oCbpiukOFIiX4cwmQ': 'Las Vegas',
#  'MNwZmi-SnicA5FNYVohMuw': 'Henderson',
#  '3yP6ieJBXvee4IpCZP3Jvw': 'Las Vegas',
#  'cpz2a48-fkOrnogYU3B3qQ': 'Las Vegas',
#  'opPpHVIp8SKHMJg3_y5Lew': 'Las Vegas',
#  '3Apvsrrf4wJuG4NdwIfXwA': 'Las Vegas',
#  'PYRIiQilTl1rkx83hm8ttA': 'Las Vegas',
#  '7KsXJ8MvU9VIG78W10s0SQ': 'Las Vegas',
#  'lml6FykyqAxURGJaGA8tdQ': 'Las Vegas',
#  'VD8Ox-akHloK3-QV3FxY-g': 'Las Vegas',
#  'AXuHgGQoNPkiSXTxHlQc0A': 'Las Vegas',
#  '0MtvvszO23F_GQGpaycwPA': 'Las Vegas',
#  'L8P5OWO1Jh4B2HLa1Fnbng': 'Las Vegas',
#  '8YaRW6wCKTm12Y87vdOp6g': 'Las Vegas',
#  'Ovmw7wC78-PD8BUDS3xM5Q': 'Las Vegas',
#  'OLn8EvPsu4hNug8V5PF2jA': 'Las Vegas',
#  'PePWIBvMyZ529fhrJLzgJQ': 'Las Vegas',
#  'ID7ccpPgEZ-BdqO0lSFqnQ': 'Las Vegas',
#  '1IAuZhwpbGl8jwN2DTkh-w': 'Las Vegas',
#  'o_cyGX4KjLPAraYn9yR4sA': 'Las Vegas',
#  'VUHoKtYxwzjF-PHk3LBn6Q': 'Las Vegas',
#  '7taWMcaCMQ1F2qVP1W3jCw': 'Las Vegas',
#  '1PQYGqxBCMpAIkmFJi9orw': 'Las Vegas',
#  'fxcyt4lx9XDgTPoAwW7roQ': 'Las Vegas',
#  'mAynnMvVJVdHLOFkmLyftg': 'Las Vegas',
#  'B1829_hxXSEpDPEDJtYeIw': 'Las Vegas',
#  'n0r_0HkCFaC175vXtIVcaQ': 'Henderson',
#  'IsR8VRaHhY9u3baj9m8SbQ': 'Las Vegas',
#  'J-MhhFKS_QFCjbIWJZGMQg': 'Las Vegas',
#  'lnMz0MZIAmCbclLJf7W9zQ': 'Las Vegas',
#  'KJ5gfIAWhE-IZ2DEqgS1nQ': 'Las Vegas',
#  'WSJJF_FyRz0osgBQgndlDg': 'Las Vegas',
#  'O-m_9oMnS45NrnxQ6JlNEA': 'Las Vegas',
#  'Ot-ODtUth8kGGujm_AscdQ': 'Las Vegas',
#  'os-sDQoh-hCt2Lg76z6ZUA': 'Las Vegas',
#  'O9pMFJSPg80YVzpMfNikxw': 'Las Vegas',
#  'MMXwhTMpy9W7rvpltcZglg': 'Las Vegas',
#  'EBveE4oDk6AYWNUEs937mg': 'Las Vegas',
#  'nS36RRnJJH-tZRJJ0Ovqzg': 'Las Vegas',
#  'K3aR8F0EVHULAcv6Pfkohw': 'Las Vegas',
#  'YApG_XpSXamn_itlOXQCBw': 'Las Vegas',
#  'LBD7yJez6snerKLrfJ8zcw': 'Las Vegas',
#  '4aRespr3mEIxRRoW9tio2A': 'Las Vegas',
#  'BT4KVJ28kfC_SRjS7SEIDQ': 'Las Vegas',
#  'xo0Mz2XOJL_mgIfSXagLXg': 'Las Vegas',
#  'hq5en1N5_OKK3Wx6RU2MTw': 'Las Vegas',
#  'w8N0kRTYwhmny3w2rO-pgA': 'Las Vegas',
#  'SD1zZNbpvlPntS2ykQYhOQ': 'Las Vegas',
#  'AIOKETfl1yvdRpI3dLFEYw': 'Las Vegas',
#  'BBEzfl86lYQjjsRa4JIn-g': 'Las Vegas',
#  'osvdz1TnYj50QcaV10_40Q': 'Las Vegas',
#  'VupFODj-mzL4wwipJKN9aw': 'Las Vegas',
#  'yU3Fjjta3OYMuK2YHQaGsA': 'Las Vegas',
#  'sFZjAfSAJ2hZ1CHLsJscxA': 'Las Vegas',
#  '_4fVJIqou00rrhU9OOJm2w': 'Las Vegas',
#  'iqsUoSxTpzAxt8AX8OgSZA': 'Las Vegas',
#  'oe5hzmFkN8bk0AzUEVGAqw': 'Las Vegas',
#  'q0N61z8h2dj3NxdU2_uwWA': 'Las Vegas',
#  'aK_IdNCJUdk2haKC3GuM_Q': 'Las Vegas',
#  'uERlyO-ASZag6XXouCrkhg': 'Las Vegas',
#  '9Ngo1ITdph18GePHuY-cRA': 'Las Vegas',
#  'jULSmuImPcuPjAEV84IBPQ': 'Las Vegas',
#  't9MtHB_hwKfwkW0Ie1yEoQ': 'Las Vegas',
#  'q6xgj7izoqXoTOWE2QyS1w': 'Las Vegas',
#  'acoVn9Vbp0fnuc3n-1M2EA': 'Las Vegas',
#  '7QLwWlojfQP0KUZrRRJwlw': 'Las Vegas',
#  'Cq0XdCjGFhzWMnVx8cb4Og': 'Las Vegas',
#  'o9D90Dr6z27JL6AlivsoFw': 'Las Vegas',
#  'DWpDDBJvO_fLqhwEwY2joQ': 'Las Vegas',
#  'ZuWAof5l6yKeft-F1QCWSQ': 'Las Vegas',
#  'p_6-Q9uAqn3i8NLjudkJ1A': 'Las Vegas',
#  'Yj9TXFf1qNuIyVFT3EHzDA': 'Las Vegas',
#  'lXZ7aziyUJyA6V0FlIR1Wg': 'Las Vegas',
#  '53PjYuZ4KJgiYNUnrG75hQ': 'Las Vegas',
#  '0k2UHwH241QP3f_QzvLmQw': 'Las Vegas',
#  'IWyLfneOLl37s1cW0Y85jg': 'Las Vegas',
#  '2B5r4nspOc_cLbg_l2n5tg': 'Las Vegas',
#  'O8G7YD1ohYIiqpq6e67nVA': 'Las Vegas',
#  'NZj2NbJTjWCZSyALTUyerA': 'Las Vegas',
#  'Wj0tIFlWz_1Uam1VDWYG5g': 'Las Vegas',
#  'sJYLKDza9ixc2kbGE3yHUw': 'Tempe',
#  'QHX3NxFAlda3I32taYzI8w': 'Las Vegas',
#  'isIgfxN4EezltNageG2Tzw': 'Las Vegas',
#  'E60LiRK4LHg7jquMZj6AOw': 'Las Vegas',
#  'WPe2n-x6xBNy2GIC5LcpdA': 'Las Vegas',
#  '4CCtrA2Db1utNAwIO1-aBQ': 'Las Vegas',
#  'Gab1_sLsjJLAJojoFd-d-g': 'Las Vegas',
#  'hOUXgXGHEBbleF01CTULIg': 'Las Vegas',
#  'pDW59eBTeawgV16s4731xQ': 'Las Vegas',
#  'EIx86LrVLyO4xoCF1bezVg': 'Las Vegas',
#  '6kR2tbwocCtgha0uFL4E7A': 'Las Vegas',
#  'n4HGMhXSTrM4j-ZX6UJjvQ': 'Henderson',
#  'f2c0zHEZf64GPxAcjP6pzw': 'Las Vegas',
#  'UDe9DmQMv5UV1a3O1DMZaw': 'Las Vegas',
#  'ag2TbtKPO9HTyLqxgBP3kQ': 'Las Vegas',
#  'DN-GanvndaTAAuVYCJ9f3Q': 'Henderson',
#  '4vbY4Iq8aqfuEcLuBPGvAA': 'Las Vegas',
#  ...}

# %%
# show the distribution of business

counter_user_locs = Counter(user_locations)
counter_business_loc = Counter(business_locations.values())
counter_user_locs_recent = Counter(user_locations_recent)
plt.plot(range(len(counter_user_locs)),sorted(counter_user_locs.values(),reverse=True))
plt.title('Distribution of business in cities')
plt.xlabel('cities')
plt.ylabel('Number of business')
plt.show()

# %%
# find cities with most users

def top_cities_with_most_user(locs, text, num=10):
    plt.figure(figsize=(10,5))
    counter = Counter(locs)
    most_locations = counter.most_common(num)
    plt.bar(range(10),[a[1] for a in most_locations])
    for i,v in enumerate([a[1] for a in most_locations]):
        plt.text(i - .3, v + .7, str(v))
    plt.xticks(range(10), [a[0] for a in most_locations])
    plt.title(text)
    plt.show()    

top_cities_with_most_user(business_locations.values(), 'Top 10 cities with most business')
top_cities_with_most_user(user_locations, 'Top 10 cities with most predicted users')
top_cities_with_most_user(user_locations_recent, 'Top 10 cities with most predicted users by most recent reviews')

# %%
# draw the geo-location of cities and predicted cities

def map_plot(counter,topn = 10):
    geolocator = Nominatim()
    m = folium.Map(location=[40.5236, -100.6750], zoom_start = 4)
    time = 0
    sorted(counter.items(), key=lambda x:x[1], reverse=True)
    for city, count in counter.items():
        if time > topn:
            break
        lo = geolocator.geocode(city)
        if lo is None:
            continue
        folium.Marker(location=[lo.latitude,lo.longitude], popup="{}, {} businesses here".format(city, count)).add_to(m)
        time += 1
    return m

# draw the geo-location of cities with most business
map_plot(counter_user_locs,15)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# draw the geo-location of cities with most predicted users
map_plot(counter_user_locs,15)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# draw the geo-location of cities with most predicted users by recent reviews
map_plot(counter_user_locs_recent,15)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# generate the network of each users
def user_friends():
    user_friends_loc={}
    user_friends = db.user.find({}, {"user_id":1,"friends":1})
    for uf in user_friends:
        if uf['user_id'] not in user_friends_loc.keys():
            user_friends_loc[uf['user_id']] = []
            for f in uf['friends']:
                user_friends_loc[uf['user_id']].append(user_predict_locations[f])
    return user_friends_loc

# one more prediction based on users' network
_, user_predict_locations_friends = location_prediction(user_friends(), user_geo)
user_locations_friends = user_predict_locations_friends.values()
top_cities_with_most_user(user_locations_friends, 'Top 10 predicted cities with most users by network')

# %%
user_predict_locations_friends
# Out:
# {'bjTcT8Ty4cJZhEOEo01FGA': 'Edinburgh',
#  'yx8vNXUL0D0HS8rUIC7AFA': 'Montréal',
#  'oU2SSOmsp_A8JYI7Z2JJ5w': 'Edinburgh',
#  'zXnH6W74FAJQ7q7b-NuBsA': 'Edinburgh',
#  'c5yp5hxwC1N98MjbV2LyWQ': 'Edinburgh',
#  'AXgRULmWcME7J6Ix3I--ww': 'Edinburgh',
#  'tgV6tsYQ66DZ3LQKvtC6cw': 'Las Vegas',
#  'Q-3YCVywc03w56wYtGlKvg': 'Edinburgh',
#  'eqWEgMH-DCP74i82BEAZzw': 'Toronto',
#  'd0DGZRp6lHXGECJSc_nn-A': 'Edinburgh',
#  'WZXp9-V2dqRRJqhGgRqueA': 'Mentor',
#  'XylT12exfdLiI_3uDLVIpw': 'Glendale',
#  'IpLZ7RevQrFPJWYc9Gxymg': 'Edinburgh',
#  'E56sVQT5-OWfSejJrma8_w': 'Phoenix',
#  'TLIWzAJPrET0zX4_vgvLhg': 'Surprise',
#  'Ji9PeffxjwqPLO7pEfSpKQ': 'Surprise',
#  'P8mVj7AZwJTFFH5FXbbmUg': 'Surprise',
#  'JZEiTNWBwmv6MOOXYCAaMQ': 'Surprise',
#  'vgZqQqe8cj6SBMH0EqDliw': 'Scottsdale',
#  'O7G_c6wFXSygr82qs0GAcA': 'Peoria',
#  'UG4EKu13JRwzRix6ESINdg': 'Surprise',
#  '1YorWW0Z-YDuYC5GplNabw': 'Surprise',
#  'R6vb0FtmClhfwajs_AuusQ': 'Phoenix',
#  'CPuUagT2rfUJm6hRgxn3JQ': 'Phoenix',
#  'OYRBjBWy1uOm12N3cokS_Q': 'Surprise',
#  'PKZLwAGgBtQCjJtGhyPETA': 'Phoenix',
#  'tbAQMMVlhxvXhe6KifrZ-A': 'Surprise',
#  '9bJ6j0zrV1XSiSnzQWM5Tw': 'Surprise',
#  '-0kiduTUToVYFqN_NEqMSw': 'Surprise',
#  '8nCmV4RMwf4GpaN-A_2Tfw': 'Surprise',
#  'xlkjaJUu2fVojeaaVgQPOw': 'Surprise',
#  'alTlRb9qMBX11pARX05Big': 'Surprise',
#  'e--whH51bx5mDaMo3aJ-hg': 'Phoenix',
#  'Ns0hZ0xDOuVRMpHk0Q-5Yw': 'Surprise',
#  '1s0Q1KwGpJIKvD-SRSpwjw': 'Surprise',
#  'R-kL1bocHgP4GW7Mgd-ZXA': 'Surprise',
#  'UXZDRVdx8eJqdqb13Bcfcg': 'Surprise',
#  'EKTCccgwn9MAIDNSsDwuIg': 'Phoenix',
#  'rHP3q9Ok1qu9_tJmIy4i9w': 'Phoenix',
#  'C38sl6tI_DVrpL5sg4Kmfw': 'Surprise',
#  'cs6biPoaG9SmtVB44hU9Sw': 'Surprise',
#  '1fMDrDfB3IHPCka9SeSHsA': 'Surprise',
#  '33h6CGtB9MSYHi0-kbXMhw': 'Surprise',
#  'zLt0Qu_98ZGObYBTcG7jRQ': 'Las Vegas',
#  '6jz_Yr6_AP2WWLbj9gGDpA': 'Phoenix',
#  'faaOI6hU64h6SSaF0f11eg': 'Surprise',
#  'ljGTQD_-yC4iXievtgCsbA': 'Surprise',
#  'd6om2E23bPoZFWzLss-rrA': 'Phoenix',
#  'O2U5kLpXDY-xjDppJ7d_Nw': 'Chandler',
#  '5zkRD7dv8GqysVCvwPr-Ew': 'Phoenix',
#  'Ov-0pRQxz5fTTElFE-WtTQ': 'Surprise',
#  'DAIpUGIsY71noX0wNuc27w': 'Sun City',
#  't9lwePmlZ7Sl_wiw9SFSrQ': 'Phoenix',
#  'p_azadim_uWFOXAhhKB3ag': 'Phoenix',
#  'e3S63222bmnlIYLi2DCeQg': 'Surprise',
#  'GjxM-LmQcta13_DiUniVgg': 'Phoenix',
#  'GG9tAoEC9sMa_DokSkkImA': 'Surprise',
#  'cPfnF9PAvVjamEdZM3wTzA': 'Surprise',
#  'hxhKA0q9jLxTfUdg1LM9Bg': 'Las Vegas',
#  'RhDwmkLWmC1SGF0VPV7xYQ': 'Peoria',
#  'kq0emTsKE2DcDOWbe1NYRg': 'Phoenix',
#  'CnSzFGho_Ofsda3DOg0cIA': 'Phoenix',
#  'unEY79t6hHECP9Yd58R1dg': 'Avon',
#  'kqsBiDRm1u34Q0RqN62QIA': 'Mentor',
#  'NtkMuGqcis30GjAkq91etA': 'Mentor',
#  'T5MGS0NHBCWgofZ6Q6Btng': 'Mentor',
#  'Rt1sD4KdPD6Uquf9BIsw2Q': 'Mentor',
#  'xU3FI_O1XrjGRzOiFWvjBw': 'Mentor',
#  'b7zWPM3MDi074PbSw9GSIA': 'Highland Heights',
#  'ciFYbNSdhRpHW0LofmmeEQ': 'Avon',
#  '8e2Khf95bZgBlkeMqh59fA': 'Mentor',
#  'mPfLvSeRYqdQxJQk5ANVUg': 'Mentor',
#  'fGgE1ASXCWfuw5edGCfCFA': 'Mentor',
#  '9Y_HfxjyZU7ltQ3VY3Wj-A': 'Mentor',
#  '9CiRp71NmS_AP74rW-1gdg': 'Middlefield',
#  'xlp2qzyxgBg31wFHSDhKww': 'Willoughby',
#  'vkOWrnWgPhgpqev9ZanAnw': 'Mentor',
#  'YBbNemmB8wWbKGr6V3bCAA': 'Cleveland',
#  '4pVwuNpFwn8nWrSkT0urvA': 'Painesville',
#  'CLHRQRNRrpj7Ht-oQSFf7g': 'Mentor',
#  'MGBv4e-Z6lfyUcSVwPXQPA': 'Mentor',
#  '5z587IBRnjCbo51IaHNPzQ': 'Cleveland',
#  'ludX46lEfeQ8TuHsK0D9zw': 'Mentor',
#  '-S1dz92Q3RPfHomiqEeP8Q': 'North Olmsted',
#  'XeOCjJwfLlKpkSd_oYxyGQ': 'Mentor',
#  'NvI6nkdKut_x5GommcngDw': 'Mentor',
#  '09jpZrKD_j0SG9WPBDSJQg': 'Mentor',
#  '2rIHr_3qznLHn73YfOwkWA': 'Mentor',
#  'Xxvz5g67eaCr3emnkY5M6w': 'Cleveland',
#  'rK2aGPWEU7UVwz_fqKE8mA': 'Mentor',
#  'djpMXOA1ic5wv3FPtubHNw': 'Toronto',
#  'PTj29rhujYETuFlAZaDi3w': 'Toronto',
#  'XCDxUzBSY8-JOvcp4jqpvg': 'Toronto',
#  'zZy5Jljx7rEvISiJ2isJpA': 'Toronto',
#  'bzKH1kadsxohV4UgNc1wTw': 'Toronto',
#  '-pXs08gJq9ExIk275YLvPg': 'Toronto',
#  'Kf10dTiGlcnyhj8DBoZn1A': 'Toronto',
#  'B7IvZ26ZUdL2jGbYsFVGxQ': 'Toronto',
#  'Ggl13LZFNdNO3z1fXj_1RQ': 'Toronto',
#  'm6GlY6JALeb0nGnE29FJ8Q': 'Toronto',
#  '1cb0oJc2pR2efodBQbXdvQ': 'Toronto',
#  'JUT0U3HTSB3kz9Wh7N0GqA': 'Madison',
#  'AhoxHm569hH_PRkoegDwcA': 'Toronto',
#  '9FhtC5gKQvUCQMMGlcXW3w': 'Toronto',
#  'gXQfe8T1UvMpmR5rcWpGWw': 'Toronto',
#  'A-zo2jSQDnTgIoJg0sFevg': 'Toronto',
#  'alUuOskFSl1bODjnce2PpQ': 'Toronto',
#  'nQuC_UE-TYI5Epb5KR4AWQ': 'Toronto',
#  '0HxInQ94hVHVlO1FGPWctA': 'Toronto',
#  'Jyi0WJt0UfGdEg0grR38ZA': 'Toronto',
#  'wnRv7PRPZ0jU_flnGJnYAg': 'Toronto',
#  'qt1b6zXExL-uoJGRRouQYw': 'Toronto',
#  'f-dzSIu2QURZ8Y_fxo7J-Q': 'Toronto',
#  'FYAkhIj29gyWD_Lte1v7SQ': 'Toronto',
#  'DuoBTfKNM67965BcrlYBYg': 'Toronto',
#  'wu-ijx0ZiBThoc9tRHf_Hw': 'Toronto',
#  'B0izwVcG6y-NbWvfNBVSAg': 'Toronto',
#  'a39kizwaoThU6uLIv_Ke2g': 'Toronto',
#  'bCPO7i-x5eZ41lLVOwuQwQ': 'Toronto',
#  'dvr-iz4B9eNzDZ-uvjvHPQ': 'Toronto',
#  'L3X_u_PWEglem1ETrPMjpg': 'Toronto',
#  'ncULBoGp-kRF3zExhbdDfw': 'Toronto',
#  'LRKmxCcf6ZkxyujPdmp5zQ': 'Montréal',
#  '2VKVhy1SwaixHCeiWglLUQ': 'Toronto',
#  'M5Ci03Ce9gab2jahundlRQ': 'Toronto',
#  'vMrnL8HA0OvnME8PC0Dg1A': 'Toronto',
#  'Yl7OYdHuYmr7K-IW9_ayng': 'Toronto',
#  'J3ucveGKKJDvtuCNnb_x0g': 'Toronto',
#  'XXxrsJ3KpTFybcBFpZLYiQ': 'Toronto',
#  'Oxe8DXjBOi6C-cR2w64zOg': 'Toronto',
#  'asPq38KJqzxeLotQCdxQgg': 'Toronto',
#  'iF3V9eqIVAjX8sj96hJ_sw': 'Toronto',
#  'RYP7YVMcYPfO78H1OTzt7A': 'Toronto',
#  'y3MNMa0SG_cHC1cwmmntpQ': 'Toronto',
#  'g5wYoa19wv1X0UOYVX1IlA': 'Toronto',
#  'SRSmzTPA2dX2Zpfa2uE4sA': 'Cleveland',
#  'TYiDRwfIUBEos45ERdzeAw': 'Toronto',
#  'TZelLnaGbHgaG7LBI6rfgg': 'Toronto',
#  'VVm-TFCpi9M1-k8ED0l1eA': 'Toronto',
#  'uyEIiUd0qGkZySz4kbA0uQ': 'Toronto',
#  'HFItzRohDHZvcKDrM6ABZg': 'Toronto',
#  'hrA2TKOiPrJ0Va3ceAgq9g': 'Toronto',
#  'gMfkWTxRVZtJAMm_adQKsQ': 'Toronto',
#  'tYk7mMGGFl3gLfmhST5L-A': 'Toronto',
#  '3Le78qZoyKE0Od0sGU8EBA': 'Toronto',
#  'zbSBmoujGgIPuNWQcny14g': 'Toronto',
#  'AlXx0P-OhUylep0jNi773g': 'Toronto',
#  '6X9PioodbNo5nnkZTFWhWQ': 'Toronto',
#  'gW4UsZSf81Xqc29eE2yqCg': 'Toronto',
#  'fCy0RLrVg6xyhaNRpZtBIA': 'Toronto',
#  'EhO5C7t3yfGFLvsTyK5PPw': 'Toronto',
#  'eV5usRjY2cDqNKVv8wXroA': 'Toronto',
#  'MC8wS2NGRMSfO5fFWU7b4Q': 'Toronto',
#  'Je9hP1439B3jp4y-nBgiMw': 'Toronto',
#  '7_RaCe5zzPBYWm9znlffUA': 'Toronto',
#  'f3HeJmAQYWbbuyVVzxstOQ': 'Mississauga',
#  '8xArUHrVys0dH17X36KyJQ': 'Toronto',
#  '3gw82ABfZVOD9Yg51wTmiA': 'Toronto',
#  'NL8ULDSd476vP3PtU4pvfw': 'Toronto',
#  'NFH6lgwwub14W-sR7m40hA': 'Toronto',
#  'OHfTeAhGpJtUMEOe7QLwgw': 'Toronto',
#  '2Ez3VPd47JGv_hv975J-Uw': 'Toronto',
#  '_t3BJzyGaqr9mcDazYiYAQ': 'Toronto',
#  'ZUsS5CjWh4YrPVi4Hi3Y6Q': 'Toronto',
#  'imPfhpAk61DqSW6K47D4QQ': 'Toronto',
#  'pQbLLV8uzry5S7EX114gUg': 'Toronto',
#  'p8rCTA139YIM6DQNq5s5XA': 'Phoenix',
#  'u04pbgaUuqqy0UnMI05p8A': 'Toronto',
#  'dRlA0iymGFcNzsfWA7P-Jg': 'Toronto',
#  'Uwu72w77MPox942_GnCS7g': 'Toronto',
#  'hWJdT09U7oHcSoc_pYr0Tw': 'Toronto',
#  'FTNaQZ3t0dsVWw1WZUQGFg': 'Oakville',
#  'uHZr3XbjKvRTwdXLXrFuvg': 'Toronto',
#  'TbhyP24zYZqZ2VJZgu1wrg': 'Toronto',
#  'sfKwAw0FD8KuWp4Hjv0cxQ': 'Toronto',
#  'CxDOIDnH8gp9KXzpBHJYXw': 'Toronto',
#  'NNOLEPL8DidbqMCH3Qkecw': 'Toronto',
#  'U_6JkfbEYRG-lb4pbbtlLA': 'Toronto',
#  'JyLTAZZZB9L40Q3S9b1jlw': 'Toronto',
#  'mb_8jXannipO5T5V5kGXiQ': 'Toronto',
#  'Jt1zgNmwz_jheOSmEsljPQ': 'Toronto',
#  'OFawbcy1lqVOeRtDTOnSpg': 'Toronto',
#  '8lL-554wLEOxCrroFa4aeg': 'Chandler',
#  'E0rM7jeEOZXUObgLG9Ixgw': 'Phoenix',
#  's19c8t_yAmFrby90LjDk8g': 'Montréal',
#  'fuUmrxv-SzxXQ5ilT03V1A': 'Phoenix',
#  '9df8KToLljo-v--Wke2W1w': 'Las Vegas',
#  '-vjSUjoYYROCHImyLenDNA': 'Las Vegas',
#  '5aNrWttH8JiZU9RQ--Fzcg': 'Las Vegas',
#  '6mMk9hO_RAbdGMEGeg3oWQ': 'Las Vegas',
#  'zF10BKjK4Lz9U_8Yqw28ww': 'Las Vegas',
#  '3Vd_ATdvvuVVgn_YCpz8fw': 'Las Vegas',
#  'PKEzKWv_FktMm2mGPjwd0Q': 'Las Vegas',
#  '4TDeDywE3LL-jI8lQ1uRTw': 'Phoenix',
#  'siiwiW2CwUJrEdmLytsPKw': 'Las Vegas',
#  'ibvH1Y7Rh_tstiWgH0OFTA': 'Las Vegas',
#  'QJI9OSEn6ujRCtrX06vs1w': 'Las Vegas',
#  'm9N3bBRLAxRJU_7F6aWOmA': 'Las Vegas',
#  'UY3x_8KhKlrqVSDE0QKV8A': 'Las Vegas',
#  'mXRg6SXgyQO_nsPr3toIUQ': 'Las Vegas',
#  'w3dRT20CwQSNJ6GLGbM4SA': 'Las Vegas',
#  'aT_AzbpcsbodNNtFzPqRVg': 'Las Vegas',
#  'Kp5KHBSmV-Htc9NeSjJfPA': 'Las Vegas',
#  '7dnh9OrD8LekBwvachGH5Q': 'Las Vegas',
#  'ntlvfPzc8eglqvk92iDIAw': 'Las Vegas',
#  'EiwxlbR8fb68lMgEXhcWKA': 'Las Vegas',
#  'y3FcL4bLy0eLlkb0SDPnBQ': 'Las Vegas',
#  'll75pLg0owsEoo1jCMdRyg': 'Las Vegas',
#  'SJu5NWsA_DrPXu9ibN9y5A': 'Toronto',
#  'uf95iifC_TQ-DtDs0rtiXg': 'Toronto',
#  '2jbu_xi_FEghI37kPG5LzA': 'Las Vegas',
#  '1LcId4o9Ge0F0KXrUXhuyw': 'Toronto',
#  'W6CrBiuPNADGDIH_m39_aw': 'Toronto',
#  'CGjRewYS0p_WEm6ocQJFrw': 'Toronto',
#  'N9PQbJqnmVAK-wjgiaaGnw': 'Toronto',
#  '3KkT6SmPFLGvBS1pnDBr8g': 'Pittsburgh',
#  'TsBUWbhRhuiEMXb56kL0Cg': 'Pittsburgh',
#  'bJTKxBIvb_AR8d4SuLPV8g': 'Toronto',
#  'Um2iec4NKMXVpJEME3PfKg': 'Pittsburgh',
#  'scnvdFMXTQ4o2DBJpHLbaw': 'Pittsburgh',
#  '3ew6BEeK14K6x6Omt5gbig': 'Pittsburgh',
#  'g0EQGDEVFl4DMN6jfarJFg': 'Pittsburgh',
#  'hcZqq-a16ZTjaM2p2MljTg': 'Las Vegas',
#  '135DbbQnr3BEkQbBzZ9T1A': 'Pittsburgh',
#  'ZLS7cwa1UplSB8nRrwrHIQ': 'Pittsburgh',
#  '9tIjFbmboV3ioyng_G2Pgg': 'Pittsburgh',
#  'HoM645ouLZA0grMBtj4w2w': 'Pittsburgh',
#  'YCZA7dlc3Rdj80Egh3__JA': 'Pittsburgh',
#  'SqVUNVeYJblyoUz4e-Fiqw': 'Pittsburgh',
#  'BoUGdFkiU6EVsHGSvt-Uwg': 'Pittsburgh',
#  '7sAkIM47_LE99Hyg5lwdrg': 'Pittsburgh',
#  'ySq-gVgm0gxmllf0ZFz-mA': 'Pittsburgh',
#  'A4SLfGedOniAWjjIwC5iOw': 'Pittsburgh',
#  '32M_2x0IzeIxcJucQp6BOw': 'Pittsburgh',
#  'lPeHcLi-6y4nIEdPmDedtQ': 'Pittsburgh',
#  'Ic6-gs1_FjrWGx6JIr95Mw': 'Pittsburgh',
#  '4YwesZEX8VPPJOKLfPD7lg': 'Pittsburgh',
#  '6CoMpwA8D2s00RfzpKDuOg': 'Pittsburgh',
#  'GvYzuy5nwG9QWC7Mp11dHg': 'Pittsburgh',
#  'A8_ovU0s8KGipI8DPPzXzA': 'Pittsburgh',
#  'knDrH7HggUkpMSO92bzJLQ': 'Pittsburgh',
#  '9iNyv-Kf4B748GsL0d4QxQ': 'Pittsburgh',
#  'MoFYvOoufOMyVTmUFAhRxQ': 'Pittsburgh',
#  'nLXCAodRN6Z6O4-CjshgPQ': 'Pittsburgh',
#  'k6Y8yT_EJtL5hhwnYPDUfg': 'Pittsburgh',
#  'UcwzDDDK4dElIwBLTH4UwQ': 'Pittsburgh',
#  '3EN4rQgpR8cR1NxuJNzi9Q': 'Pittsburgh',
#  'cQpTkatAqnOBCarVNwixPQ': 'Pittsburgh',
#  'yKFeQD-gcsPKj1BIs813oQ': 'Pittsburgh',
#  't3FKu7xMv6UkyGegAewWCw': 'Pittsburgh',
#  '8DclOINSPldMTgiEbuCdoA': 'Pittsburgh',
#  '6lu-nRaojUcVdP4nhi3Asg': 'Pittsburgh',
#  'zh8-XfjqlwAxf--RS4azzg': 'Pittsburgh',
#  '0zwj4cI7rhhQM9Ck8ZnIGg': 'Pittsburgh',
#  'VwAhjZPN7zJuyG03P8mp_w': 'Pittsburgh',
#  'CMjjwZ43THQpVS9VwbpWOw': 'Pittsburgh',
#  'JVJOfFqPmZEvkRznzF8w-w': 'Pittsburgh',
#  'QNps8E2YEMweAnWdqPZxhQ': 'Pittsburgh',
#  'qpnrU31DaVDjxO8gxkrQGg': 'Pittsburgh',
#  'sV3xGQ-mFG48hzJcArlLZw': 'Pittsburgh',
#  'mit8WLpdSlOrRZD71SOgjw': 'Monroeville',
#  'OKUs_ZvoDYkgg-bFRfmHCg': 'Pittsburgh',
#  'bryAPtwnnMYjbzoOWHzbWg': 'Pittsburgh',
#  '3H5Ty7TV7SZvZLa1oTUGDg': 'Montréal',
#  '3zdB0SSrXIDIgsrOmhdUtQ': 'Montréal',
#  'KcFMI-hsr2Em7whfI4OM5g': 'Montréal',
#  'hHhUIFHQucto-L3GDY8XxA': 'Pittsburgh',
#  '5JOP01e-jC-N3OrnevM7bA': 'Madison',
#  '4RptW32AaMcCzEArZjjitw': 'Madison',
#  'tlQ2MDwfE1TBCNmsofeGfg': 'Madison',
#  '6uLqCFKpK7nav7Zp_3TfRA': 'Madison',
#  'VvwrCpL2_uMrRumFWo7nLQ': 'Madison',
#  'BcLEkxjjYX-L3jKdUKtWnw': 'Madison',
#  'uzojZqd-h289ibuB6wPZ9g': 'Madison',
#  'reN-Y7lIjv3VW21I4Z8WHQ': 'Madison',
#  'QDzMM2YcB0LDLJVHDqrz3g': 'Madison',
#  'O7Wru5nlVMwXzuI1-CNG4Q': 'Madison',
#  'YJInht2-Z0Pj9CH3ML1R3g': 'Madison',
#  'd5WLqmTMvmL7-RmUDVKqqQ': 'Madison',
#  'fzWuWObdqMv-81BUk6Z8hA': 'Scottsdale',
#  'VtLdzz_1olnpRU6AuSsEVg': 'Las Vegas',
#  '6hi7gWjaIYC51ZlmrXmevA': 'Las Vegas',
#  '9HGer_DiSPF3xJVXIcQM4Q': 'Phoenix',
#  'pwpQncGpmxgJ01r2KI67qw': 'Phoenix',
#  'h7J6pJrLCzUu-LLpuQpxGg': 'Phoenix',
#  'GKcIOfDnPSrveGRi4BLMmA': 'Mesa',
#  '9bs-jvAayiWN1Hq2iDLiXw': 'Las Vegas',
#  '6ai3vG2vlcQXTINdbO5H3w': 'Phoenix',
#  'P7Bwn2qljq8qqKoZEXbsGQ': 'Scottsdale',
#  'IoLMXv6wzfKaisN60u5iyg': 'Phoenix',
#  'ni9ClI2mhAeAJUSaSY58jQ': 'Phoenix',
#  '6IrzPt91rwVgH52o8_ytNg': 'Phoenix',
#  'B0ASQntm8Sy4aV1CXJi_rQ': 'Mesa',
#  'Gq8OwMLyRRdL71NWp6VM9A': 'Pittsburgh',
#  'JM18LKd3By6gL3WOFXhaMA': 'Scottsdale',
#  'Aw9YiasaOs9zikh1XsbI9g': 'Phoenix',
#  '02Z0sSGvQRm2rgQwUmNAJQ': 'Tempe',
#  'SR9KgvoaxcBsSd4Gds8LnQ': 'Glendale',
#  'cwAxa2L4T0t5Hu1zgb5YVQ': 'Scottsdale',
#  'k-p5RfLnAPEherauN4CxUQ': 'Phoenix',
#  'CQ7tEwDL_5jpEJzDKKYv4Q': 'Phoenix',
#  'xodu7YZipff5EW5QbpT0aQ': 'Scottsdale',
#  '9EBTKHoCH1sl3X0MX8txjg': 'Phoenix',
#  'sOCuf-jZo43DUzWTDKiR9w': 'Phoenix',
#  'aemN874BzsJo6NBEIbygfA': 'Tempe',
#  'APnNt9CdoZ3n3EAIB2nMog': 'Las Vegas',
#  'Ru2NSw1CzoGAsXYvDGf0Uw': 'Phoenix',
#  'zTK1nPD2Hpa-ksSXsE-JzQ': 'Phoenix',
#  '_k3o_AKj-S9JD0q6AhSXdw': 'Phoenix',
#  'e0TeYGOQRM2PrYCAdho7lg': 'Phoenix',
#  'YcmNpPM0ag94g4T0zAtdcg': 'Phoenix',
#  'LZdMLoFIpW8X0QdIZOVGbQ': 'Phoenix',
#  'U_FfJTKoLsutJf-r98H9EA': 'Gilbert',
#  'OW0PZxoGFGSOthAmN_cSUg': 'Phoenix',
#  '7aHlhpJFiAdFHVhs6OHP6w': 'Phoenix',
#  'XQfRpQv5q0uiP95QzIynug': 'Tempe',
#  'FggHd5cqx65Eu2bT1eHtEQ': 'Phoenix',
#  'XpuNfndl5pRh1XQWSFvvQA': 'Phoenix',
#  'jV-MHT6BbWw_Lfh-hlfa6g': 'Gilbert',
#  'Cqn_766h_JpQoV6fwizJhg': 'Charlotte',
#  'DDFAI_WROA_J8FF8dWe_6Q': 'Charlotte',
#  'zSblIQYZhN0gauAhIx46Tg': 'Charlotte',
#  'QQ7sxRNs0A4uFK6pQE4AYw': 'Charlotte',
#  '9khBWjeKA9rHjT9Wo63WrA': 'Charlotte',
#  '9IRuYmy5YmhtNQ6ei1p-uQ': 'Charlotte',
#  'HS3y3GltOH_pJ37-EJwOng': 'Charlotte',
#  '7IZQ06zkYSCLQM4JU9kFvg': 'Charlotte',
#  'w3ReHv4j5f-gnzHIz4Krbg': 'Charlotte',
#  '17TiV5o3EsIIbyFgSpBmXg': 'Charlotte',
#  '-8mGZ-pJi-NcjZckuz1M7A': 'Charlotte',
#  'FSJDnMPHNOpZrqR1wHp53A': 'Charlotte',
#  'E1szdQHhFDwO115pGDh_Xg': 'Charlotte',
#  'wsCRhiX1UpakSeDvo9DHQg': 'Charlotte',
#  'bm2tUuhog7tMu7EqfN7BNw': 'Charlotte',
#  '7U3H1iJZ04FbadJtt2Npjg': 'Charlotte',
#  'uaeU6FBaY5by7V1Cj_2RpQ': 'Charlotte',
#  'TqoxE8B0r4CUWpGYAHXoOg': 'Charlotte',
#  'iN5kL0PrH0lb_69fZ6difQ': 'Charlotte',
#  'SBi0TYUSIrct8WSTyK6DFg': 'Charlotte',
#  'sbtSsIQKYRPmS4KJ6jdYnw': 'Charlotte',
#  'ifZh_oEWxd05Ci_RQVoL9Q': 'Charlotte',
#  'UKFgwgNM1a7Gmr0UIGPzpw': 'Las Vegas',
#  'hhQUVO2AqBdSeQcPo19Bsw': 'Charlotte',
#  'LnGDsxHFPhoCKT8sFGaViA': 'Las Vegas',
#  'Fv0e9RIV9jw5TX3ctA1WbA': 'Las Vegas',
#  'JoATwObKNywEmAduyKdm6w': 'North Las Vegas',
#  'E1b2_YD1uwufHmCsrKteCw': 'Las Vegas',
#  'uT-yzDkY79szXYNWk7zDzQ': 'Charlotte',
#  'Jl-0N4zQ6VCbvk7DFpNfJg': 'Las Vegas',
#  'OVFCRSZ_yFEc1rAlye_Z5g': 'Las Vegas',
#  'C6ezDVKNyQz-aKr4OOjC4w': 'Las Vegas',
#  'Rh2YtAmvRxDonUqZlxJDIw': 'Las Vegas',
#  'cQzo2WX1TyPEmS5jPzOUoA': 'Las Vegas',
#  '5IgLVsxowG4gcIJK8ovSzQ': 'North Las Vegas',
#  'vb9UuBS_qwUR-EGsJKlSFw': 'Las Vegas',
#  'IeVYKQZObeFnKTa04oB5Gg': 'Las Vegas',
#  'Nym1l6I0gMFrr9WCAcMO0w': 'Las Vegas',
#  '6pzA8EDhHgW3A5-rBObhBA': 'Las Vegas',
#  'WRWvu_McOkXguooZftZJmw': 'Las Vegas',
#  'zc6cucEAy6Qxkxr9ZUkqbw': 'Las Vegas',
#  'u5o_QDwRPQW8gjgFudu9bg': 'Stuttgart',
#  '0Fhcuf1rKxSZOWQ4J56udw': 'Las Vegas',
#  'VDjzt6N--TMXH4E7Y6ialQ': 'Las Vegas',
#  'FEwPxhjdVKxSPVQQAHX2gg': 'Las Vegas',
#  'yvWZJA-h-UEC_Xf51eE0OQ': 'Las Vegas',
#  'w7Q-WMxPuznP-P2Y79ICng': 'Las Vegas',
#  'vlcsGHaSPAS_Bb59EW6E8g': 'Las Vegas',
#  'ynaNvoqkUEm0Uoh06EltZQ': 'Las Vegas',
#  'DgrIg1OR7arL8tVRiZ-psA': 'Toronto',
#  'Vc4QSYKAOf8NXriGXo919Q': 'Toronto',
#  '8q711of5XKzLGJ400PI09Q': 'Mississauga',
#  'QEt3srla7bfPICwlXqRsyQ': 'Ajax',
#  'P5f5Dx3_rL0znuE4wy77xQ': 'Mississauga',
#  'IL1-dyCe_zSqhmt0ExL_Jg': 'Toronto',
#  'CXwHjHxwGDzRTgvU_NdLIQ': 'Mississauga',
#  'mT_0RP1y9qYyfU4Kd2SRTg': 'Mississauga',
#  '348o9qgR_hiNe25Rs-CDsw': 'Toronto',
#  'h3q-Y8pf1-_0jKgdEj29Uw': 'Mississauga',
#  'cW1v5mgoC8KAZsHanDLAUw': 'Mississauga',
#  '0CSlu7ZhK0SfEmo_1WkcnA': 'Toronto',
#  'QgiR84sGGz1jpGLMs-ZGSA': 'Mississauga',
#  'K-q7oE90OWNZ8IOXQqXsAQ': 'Toronto',
#  'mOVyk3O18VY5nrUMTZgM1w': 'Toronto',
#  'w2C0_M6WCfxYuY7ZvoSLvA': 'Mississauga',
#  'PbuXIB-7MRXcf1Ueg_g2lA': 'Mississauga',
#  'XcO7fb0q-LukfudaBMNPIA': 'Mississauga',
#  'itI6CqeR92ikei1n86N5sg': 'Mississauga',
#  'BCjsgRFDCxGQHr0hVlwqvg': 'Toronto',
#  '39VYc2nWSdvdTCldsDJ7qw': 'Mississauga',
#  'gPK2AKr-UA_7hZus80SSng': 'Toronto',
#  'Rk_O89vyLCcEa3Xq6RYftQ': 'Mississauga',
#  'ff_rH18q-V_VhrKSzZZ16Q': 'Mississauga',
#  'ieLHSYDzCnLbX1IjZBUdRA': 'Toronto',
#  'wkqy2o_qF0S_Z4vyG6pdIQ': 'Toronto',
#  '3bCDpygbXAkRDWxQ6_Nf6w': 'Mississauga',
#  'eOTzkS-by4pVwwCVrifmqg': 'Toronto',
#  'B4Rwp0SUYwO8lgSHVT9w5g': 'Toronto',
#  '_cj4j6-FUBda7AvWrclHTw': 'Mississauga',
#  't21OyjIVoBMRmCIaElwuEQ': 'Toronto',
#  'hFefNv6jWn3_cSjN_UwXNg': 'Mississauga',
#  '-9RU4LuI_TfYgv9rBijJoQ': 'Toronto',
#  '1mie5crWiX4eMNEhmd5LDA': 'Mississauga',
#  'z-9-XZdrmRrOFpMKAQ2rvQ': 'Mississauga',
#  'L6HGM8pmm2xCC8RTFqv0og': 'Toronto',
#  'm0uVfBkFiTbzg1GedPmBug': 'Mississauga',
#  'p-6RZe5JAtxB17AS4wOaXg': 'Oakville',
#  'Hg1EF9PjGfcKBSNMjvWBeQ': 'Toronto',
#  'Aqtnyl-rhUZF_zxDXlf0sw': 'Toronto',
#  'RgJ_nkjVYUKzCr47qJgSSw': 'Toronto',
#  'kD9Gr2IxZQv0CNp5D-Bsjw': 'Mississauga',
#  '0SNb69rzZWY0OQtBCNoqDg': 'Brampton',
#  'TCf3Qt9yyaU6kYERVTcBWw': 'Montréal',
#  '9YAcyOPntf2HJszcWgkLow': 'Mississauga',
#  'zcBBHrItGGRHMEOEt1sT_Q': 'Las Vegas',
#  'Mxw0lh2sAXrnidgvA9QG4g': 'Mississauga',
#  'R5_K6l9rSyYABGK9Bw2iEQ': 'Toronto',
#  'jll5IjpfWOknurqUYxtsiA': 'Mississauga',
#  'QWzMD9MDZH2RgnvOpoKTgA': 'Oakville',
#  'E1hLHq6LZ6AoSJzW-oT4FQ': 'Toronto',
#  'jnB_saJqNfOmVoCWquhAzg': 'Mississauga',
#  'QAkz4WcqCjVmq6UGuZD49Q': 'Toronto',
#  'AsiS6Ho8XR3OjEh2XLnauA': 'Mississauga',
#  'icqY1lAj3NvhLXkMEjdeRg': 'Mississauga',
#  '-yqTLzfd-L9war_Mm2s8Eg': 'Toronto',
#  'kwyIPeGyXFpYVTJ5SoAuGQ': 'Charlotte',
#  'cx4-WfPgm1Jxurtd83I83g': 'Charlotte',
#  'KLVRBakCWcDdUTcb3UMsZA': 'Charlotte',
#  'cmCNYsCybXczlSL9O7uiRQ': 'Charlotte',
#  'tuEmVbQfHXG5BmD7edTLNA': 'Mississauga',
#  '0Ilv9MMRxIJwKko8henjbg': 'Toronto',
#  '0YSRhsxw1ca0EKJBpi90Uw': 'Toronto',
#  'l6WKaOQra85pIy1L7rxY2Q': 'Toronto',
#  '02AOwJB1g9ETIDGZznyuAw': 'Toronto',
#  'BxCgM2bsV0AUvOpT42_klA': 'Toronto',
#  'H9bbrN-ZCCkLIYJo7-D1gw': 'Phoenix',
#  'sOudRDE_R3VYni0rEYFkSA': 'Phoenix',
#  'NlMGxLkQOYsJ2u7lCA9dvw': 'Mesa',
#  'rtmRMQQ8M2VMhZYjvBmbFw': 'Tempe',
#  'HUN33bP2LofcZctrpOyKZQ': 'Phoenix',
#  'W41iFVGdDatFi-C84gBFJA': 'Cave Creek',
#  'uE590yKd81Dye9XgKFK7MQ': 'Scottsdale',
#  '7fHmEe2V87xvN6MAEhFHJA': 'Phoenix',
#  'siVtjO8xrSxbrK-zqXCGew': 'Phoenix',
#  'gScmsSCqBeFPp6q9yG5nmw': 'Phoenix',
#  'MdGnY6eLxy82nEZhCc6rnQ': 'Tempe',
#  'MHiZ9Hbb6EIwRVGPFC46tg': 'Tempe',
#  '1bCRapFkVMwaGjbkzR5AmQ': 'Tempe',
#  'RqT8iYp-hp6pffWp0wX3Bg': 'Tempe',
#  '7UVOk0zGatVhfUfrhRA8jA': 'Phoenix',
#  'PdCR2ElSc0cVym5dCN3Zsw': 'Gilbert',
#  'hoALQHHI73AgzNycC2HcYQ': 'Chandler',
#  'WxScj0nzEvncQ7ZTY9HZXw': 'Phoenix',
#  'S9Jw00eZHVj5_0sOM_C5Rg': 'Scottsdale',
#  '5Hj7YNszxRa1TmbA9L0rAQ': 'Tempe',
#  'd303YCqPUawYNErFfFlQGg': 'Phoenix',
#  'LV8uSpYJVaYZ1goMwk8xYA': 'Tempe',
#  '60_lsQJ8JEGfZeXcTgKn8Q': 'Phoenix',
#  'mBjfiKkyz8pZ3N97uG1cGg': 'Tempe',
#  'jdWEXRH_DaXe-BsXeVfTuQ': 'Mesa',
#  'KcEa4h8xvyHOWSbbU52bkw': 'Phoenix',
#  'ktm2YMsb65tRnePcYpVlqg': 'Tempe',
#  'TQ9A1LVp6z-fIc494RsLDQ': 'Phoenix',
#  '3xORNxbKdd08LUf0tclx3A': 'Tempe',
#  'Ld59_S-w2gXtCsoX5Vuktw': 'Tempe',
#  'HniT7WZjedXOqzaBo_gf3w': 'Tempe',
#  'LrwvXGiGPAg7mEAppVW-dQ': 'Gilbert',
#  'KhWYMiyz6_46SIZLMCogVg': 'Tempe',
#  'jwzo_uLsB-4njvL2q0aUMA': 'Phoenix',
#  'DZOA0yCbH4kDS0s-dHXWFg': 'Las Vegas',
#  'HGN7VARRSkm_M0G6OW1FGA': 'Tempe',
#  '2ObGypunasuj3SbvSMcT8Q': 'Tempe',
#  '7GU-Hm6meue4fwUfDX2miw': 'Scottsdale',
#  '1vdMqzJrKjZXRFMAiiUGzw': 'Las Vegas',
#  'd_WNWUTOxJtdBlt5c_Ex1w': 'Tempe',
#  'dK1-RZPuUXSHYMWE09zxbg': 'Phoenix',
#  'nkCQg16DbT_1P3NqVPjoig': 'Madison',
#  'CbwqJgXyoPFHCGkRFWt5Fg': 'Madison',
#  'lzf7NsjgMOIecyzKD9eRSA': 'Phoenix',
#  'itmb9uAolzQnmEBDlV24qQ': 'Madison',
#  '-N1rDtpUIHpjrEujRyzVKA': 'Madison',
#  'fJ_qSZH_akvWzHUPMqab1g': 'Madison',
#  'seAX967Wk8qiVXOYjbregg': 'Madison',
#  'Kx9x_dAOMcQYiUu5-uUTdA': 'Madison',
#  'lV0TGQufw-draFAWiawdSQ': 'Madison',
#  '5oM7gXmeX7s6T1_KlL30yQ': 'Madison',
#  'BnLFYUzUnPYgDhazfQua-w': 'Madison',
#  'JWgti_adPZywG9SKUbnB-w': 'Madison',
#  'HLaSqQMDVvlcFPGJL_kGCA': 'Madison',
#  'fuoYjsuU7qy1RlCMEZ0xfA': 'Madison',
#  'gh_RvEPwTMj5OXp8j9uePw': 'Madison',
#  'esaDbON8NXJC4PWt_CheUg': 'Madison',
#  'jtD2TF2Pr-bwT6RwPCAE4g': 'Madison',
#  'q91tQNboB-0HWtM8cXRjdg': 'Madison',
#  '6vlB2FYf2dGVWte9cViVcg': 'Madison',
#  '66e_wFUf4GsDT2DTZ3u-Xg': 'Madison',
#  '38V9LFE9gbmqdxACJ98F8g': 'Madison',
#  '5Kbn1FjXmS7Jypz3_ybt_Q': 'Madison',
#  '237EL2sEpc-ZUEbo0HUYGQ': 'Madison',
#  'WG8V2B6DAT4lEA79Eraxkg': 'Tempe',
#  'MPozTU7MRVKYISO5prvzdg': 'Madison',
#  'h-aavgzksw9z-Rlwn9qZ8w': 'Tempe',
#  'PxtbSDlYndCx2-KWpx49Wg': 'Tempe',
#  'hI7LDDh6GIgh9Y_T73hDwA': 'Scottsdale',
#  'O3kOhTvb0kaysusMl0MSBA': 'Scottsdale',
#  '2yLD3esBneRzDI4Uh26q-A': 'Madison',
#  'zhQ8XCCvvhLAIRaNIcth0g': 'Phoenix',
#  '6eukXWU7RbgXOr-U9-veHw': 'Phoenix',
#  'jYHrgDDz-mx5nsF-M6RdGA': 'Phoenix',
#  'oTJW_1bmoa_KQ55ERtC3sQ': 'Phoenix',
#  '5CsexqnkjNdon7M6okJ-tg': 'Phoenix',
#  'jzs7JvXvLS8LAC8Vqayccg': 'Phoenix',
#  'UdY2po4EWqYIYCUCNUjK4g': 'Phoenix',
#  'iJfnk3trvpModWj2V-zpnA': 'Cave Creek',
#  'qyQdqgoSW-inYUdmvQfJzA': 'Phoenix',
#  '2vqLKLVcsKD1AdIDbJcc3A': 'Scottsdale',
#  'tJVDBw8cj92qfVCkXwEkRg': 'Phoenix',
#  'tZYVHdCKznlcM5tiEIE2aA': 'Phoenix',
#  'y3FNK-UpHuXmNucC_6slrA': 'Phoenix',
#  'ALK9WBaokEtmotik0RepTQ': 'Phoenix',
#  'jY6G9fiCM-Vo9z1uK1dQDQ': 'Phoenix',
#  'm8TocXqEEPsxjmz1ql7_3g': 'Phoenix',
#  'IZV6t4l-YivWsc8cEytEHw': 'Phoenix',
#  'EkvFZ7vHwEpkKGY5-WeaUQ': 'Cave Creek',
#  'seXjsuewdnh8-y8Ruow-Kg': 'Chandler',
#  'riaO_Lw2qfLBu22FpdMA_w': 'Phoenix',
#  'U0PtdIN508sn8RVJ4Mcs6w': 'Phoenix',
#  'HEobaj3QfS15reMJdhv3Rg': 'Phoenix',
#  'SbMSN-N7WGW3W8ayZYru0w': 'Phoenix',
#  'VBSCDqyBRltgvBxLNOR4Uw': 'Phoenix',
#  'tsXlmhcm5I43HrWvzrH9ew': 'Phoenix',
#  'q7MRk6FBmx0H2xrZ10QUpQ': 'Phoenix',
#  'XdLf7dZH-6kEcZMzo-lG8A': 'Scottsdale',
#  '9R19VOuHHzdsZUrE0eecgw': 'Scottsdale',
#  'jVkOyGV7CybBfqk6vF3Q-A': 'Chandler',
#  '4jN7gnDv9GJrNx_fPUziZg': 'Phoenix',
#  'TK7208ZMWAERUUY2dEtD6w': 'Phoenix',
#  '_labePetwAjwgWBUgV4wUg': 'Phoenix',
#  'NGkwcw5RWqDjSJOkfewgZg': 'Phoenix',
#  'wQbhmTsxwIyuPIIyyIHb0w': 'Peoria',
#  'PB1bOiWSUMipc2km17q4uw': 'Phoenix',
#  'Z4uvXYqvOfVR32VGvNsLWw': 'Oakville',
#  'Cm1oxY-7c3lgiLDME21wfA': 'Toronto',
#  'ON7__MUlZbxNn0a4T_09uw': 'Oakville',
#  'TUu4SppnJ1S3lQ_jTxMpOw': 'Toronto',
#  'V8ym34P-oibsEMVQWj-evg': 'Phoenix',
#  'KWY0QyEXEMGh6xCB5oMUzg': 'Scottsdale',
#  'uy1yiRgtV_8dJGlWL7IW3A': 'Phoenix',
#  'JP14p-CIOd-4jgVbsXRsAA': 'Phoenix',
#  'wqrXw4Vs-oW2WNZhWh3KKQ': 'Pittsburgh',
#  'Wyciy32b2y-8XDwM_mSCcA': 'Scottsdale',
#  'GYNnVehQeXjty0xH7-6Fhw': 'Pittsburgh',
#  'g94Ml1oo2qQe_iGBJL8nAA': 'Pittsburgh',
#  'Lq6VdEsdhqKwR0ouqlxpMg': 'Pittsburgh',
#  '5JVY32_bmTBfIGpCCsnAfw': 'Pittsburgh',
#  'q3ycagiLqUaRkOgEPf_gbw': 'Pittsburgh',
#  'ng647hYAjWC4XANaACiPXA': 'Pittsburgh',
#  'MCsNB80uwohCMB16vc0mTg': 'Pittsburgh',
#  'ZnIaEvJwrxlBUjimIpx2Qw': 'Pittsburgh',
#  'HRP5zLOrhXgLYAlaBt-HgA': 'Las Vegas',
#  '1o8vB0WKHfV7omrYWB_OLg': 'Las Vegas',
#  'kmC8nIGdQeLUOBCgRDzS8g': 'Las Vegas',
#  '00Z-tCcJVe9LVP3GakkqDQ': 'Las Vegas',
#  'TyepNPbEnMCy1_IhsT0YAg': 'Las Vegas',
#  'n9zwrWp8EeB9ODTitKZYsw': 'Las Vegas',
#  'bLbSNkLggFnqwNNzzq-Ijw': 'Las Vegas',
#  '4vl8Drja0PETBmlNCFZbvQ': 'Edinburgh',
#  'JCG7J-NmLxgmJK1c4ZRKmQ': 'Edinburgh',
#  'BnIY7cXbUfnrEqoQdQc9Pg': 'Charlotte',
#  'qePB-HLOeim-BDMG0QkfuA': 'Edinburgh',
#  'h7kFt1px7Z5A5e92X6aMvQ': 'Edinburgh',
#  'SfY0jEFqBkrqq9bVi6P31Q': 'Las Vegas',
#  'eN2pCfT17EGokP9UWnoZUA': 'Edinburgh',
#  'h_yuvACgAPnBL2FXiCF4Yg': 'Edinburgh',
#  'Dqji5fRROkLc3eNMMQOI_Q': 'Edinburgh',
#  'nhVvcPyRGLw466qHVbUjrA': 'Edinburgh',
#  'A_dC3FJOqvlsDEiDyMrzlA': 'Edinburgh',
#  'vbq-811-_beGtp-SSQhC5Q': 'Edinburgh',
#  'SxV1Jq7UANuSYpn42JXvOA': 'Edinburgh',
#  '7-ahDxB3qUg6nf3tvfG5Nw': 'Edinburgh',
#  '3jjiY5D7oIlKeiCIZGHQew': 'Las Vegas',
#  'R9UNH0rb3a_glQlk4ylKCw': 'Edinburgh',
#  'wTJhR3NdvpCB2ZAx_qRiqQ': 'Edinburgh',
#  'mdc0aTVned3fPyRb77a0bA': 'Scottsdale',
#  'Q1NOOUUhY-jQc2y5MZgdhw': 'Edinburgh',
#  'WEO4AW75i86EiMEfH0mRfw': 'Madison',
#  'vQnR9L9HILjw4PgWB8q1cQ': 'Edinburgh',
#  'QyP254XCNlI7DvPsze5LQw': 'Edinburgh',
#  'qKzcpJh5CAXgXzfwC5NMhg': 'Edinburgh',
#  'fcMTpwfLS9F5DWTqlp8ktQ': 'Edinburgh',
#  'yaBIVHDxaUBN2YHQ8-YiuQ': 'Pittsburgh',
#  'Lcjx46gQSDvFEGb-XJMZyQ': 'Toronto',
#  'WeVkkF5L39888IPPlRhNpg': 'Toronto',
#  'CaaGjAM1yL_t4yhNLD3f_g': 'Pickering',
#  'qnoXQsDOTOFwJEYXSCnHEQ': 'Las Vegas',
#  'dLk0_ttzMKap0fv3nxtRFg': 'Las Vegas',
#  'C3htqYqHwV-anAySpONSdw': 'Las Vegas',
#  'YDXHsLuMrlJ4yDr4na0eOQ': 'Las Vegas',
#  'h8DCmxMLBSUR4ZCH5bu0Hw': 'Las Vegas',
#  '53p6VeOCuYidZ4xH0vo__g': 'Las Vegas',
#  'r0nq49A5OuqXtUwEmWoymg': 'Las Vegas',
#  'slm_RlNeC1nh_PZbdbOKcQ': 'Las Vegas',
#  'G_AgCfpYj4pBHauR4fwYJg': 'Las Vegas',
#  'owrNd439iiqvh9POeJQ_Ig': 'Las Vegas',
#  'd4Y666iWUyf5L7EqUwzu3g': 'Las Vegas',
#  'ayAI9D_AGSjLM1ysduF8-Q': 'Las Vegas',
#  'zW3PaTqR8fN-mnoYWk6Ymg': 'Las Vegas',
#  '_qama-rZ0SaAqhhJBf9L4g': 'Las Vegas',
#  'HMWzlSqQsEq8Yxehm_sMRQ': 'Las Vegas',
#  'AYESvJ2yiikh6pMmfv3qIA': 'Las Vegas',
#  'fnIItxznQHlG1s_HoJzEQg': 'Las Vegas',
#  'zNOmTv1RlweHG8B7_TDDvA': 'Las Vegas',
#  'NcwMPuYMaslw_2pnJRRK1A': 'Las Vegas',
#  'OtoCNQSiG-xHf35lUsolNw': 'Las Vegas',
#  'XysBRG1pvBXnj35pAJ1zdA': 'Las Vegas',
#  'Rj1iz-j0y0YfnUWogk3v9g': 'Las Vegas',
#  'h6P9yWlrVnDY6xk5vfCAjw': 'Las Vegas',
#  '3__vXgIxGc1i_t6Dk3jSBg': 'Las Vegas',
#  'BwKruOoLESefcSEYJXLf2w': 'Las Vegas',
#  'IEdf1Fjtwi1eVkU4-65QoQ': 'Las Vegas',
#  'zoR7WPfqc287yjYx5iD8sg': 'Phoenix',
#  'kyIrmeTVS0afkTmjZ3B5Mg': 'Las Vegas',
#  'L6-_EsiHFy3a1K2kGOdm1g': 'Las Vegas',
#  'gj4tQ7TvK_qHKvNgIljqNg': 'Las Vegas',
#  'wOPx3CP-3bkZiewMU7Y3gA': 'Las Vegas',
#  'XIJ1LrlsZmqy2i2_bG2WSw': 'Las Vegas',
#  'S-9IHFuFvads0LWMUOItMA': 'Phoenix',
#  'Bpy7R6rpWCNb1alj6Fd2mg': 'Las Vegas',
#  'Pa7O0ZFwiqZlwVyCoX416g': 'Las Vegas',
#  '4Iwu57GSychxpqa4w4HAMQ': 'Las Vegas',
#  'vPqCe2zg_lNrvzBDT9MpLw': 'Las Vegas',
#  'dqKGX-Zz61Cz62S86mHNmg': 'Toronto',
#  '8EwEZj85tAZBBW2pXof3YQ': 'Las Vegas',
#  'ugRjXKkMj-4kRsoojto9QA': 'Toronto',
#  'xLkQEb6nzAQMaHhNzFYvlQ': 'Toronto',
#  'E3iyr48gSK-dZEwoj7Z-hw': 'Toronto',
#  'Duhy1-3YL7SOrThDh0vI7g': 'Toronto',
#  'dk8-B6hKb1XOmYJKC4Ig3Q': 'Parma',
#  'j5yfS1QjGwNLQ0h4_wDyxg': 'Cleveland',
#  '9RG87QSBaTmcbDu3ydQJ2g': 'Cleveland',
#  'y6IogOYLjAs8Mksx62vnDQ': 'Cleveland',
#  'VKwI11qTXOxHmlh2yr_2TQ': 'Cleveland',
#  '11gZ-oAPtbVo8xpld5axIQ': 'Toronto',
#  'YqMpcRUA0OMw1WNLDGoj-A': 'Toronto',
#  'QKFyP1U5cPdtMHIKJrzbCA': 'Toronto',
#  '1Sl_w3Reyrirhxp4wpW4lQ': 'Phoenix',
#  'ABPnzKPWAoYzuoNn9bHq-w': 'Scottsdale',
#  '5Zh6lmoXF2S9SYYsq0W3bA': 'Mesa',
#  'bWh4k_cCuVt5GLVd33xIxg': 'Cleveland',
#  'nQ4e81UdfczimYcIUtO3HA': 'Cleveland',
#  'bAwfPH4lXNzgcYp9JFy6ow': 'Cleveland',
#  'BjtJ3VkMOxV2Lan037AFuw': 'Pittsburgh',
#  'J50BanBFNY4naDYAJRAZAA': 'Berea',
#  'GKXrTZecEsqWuACpRNyuxw': 'Phoenix',
#  'gSwBZSw7lem2IEB8jId4Gw': 'Cleveland Heights',
#  't8gR8NCD56bF1XcAjwgkEw': 'Cleveland',
#  'nNtI1xRXcZs5R3sBEa8xqw': 'Kent',
#  'kEEx6yEf81i9Wk5Ww1q6GA': 'Westlake',
#  'igcnVpgAYC2EMP0sXZmuTQ': 'Cleveland',
#  '3AC_liBwORA9w18CIrGxcQ': 'Lakewood',
#  'FDFJk0feR-RAGHkxRr_3Nw': 'Cleveland',
#  'II7eBcZJRLwnFtuS6BtVRg': 'Pittsburgh',
#  'C1TC9xbL-rbN8UspYPgXZw': 'Cleveland',
#  'ZpiAtR4WReIbMy54vXNqtw': 'Cleveland',
#  'T1XUUXIEU5uj3NmdWAdIlA': 'Las Vegas',
#  'eO7Wam6CD5-2xE4tfqFFkw': 'Cleveland',
#  'jHX2qMpRIg-W32vJgi50lw': 'Cleveland',
#  'ZJCWUrxd2YzEj5yLshYn8A': 'Las Vegas',
#  'ZEwpJOG8PFlHiFRdAZZ0iA': 'Las Vegas',
#  '9BeV9g26iBVMkDPRWjW3AQ': 'Cleveland',
#  'VOUnXOlll52vwQcJK1tm8A': 'Cleveland',
#  'GefiDYsb2U_-3ujGnheSpQ': 'Cleveland',
#  '79Vv70bMS1JC9ASCg4dWqg': 'Cleveland',
#  'SaSXRzjHx3SMTNnW90PetA': 'Cleveland',
#  '8RegOEQ0s89jMHGqs12RYg': 'Cleveland',
#  'G5reVMkdwUc-souSaLdm_Q': 'Cleveland',
#  'hWGZN0cma0MtPk0PpDHnhw': 'Kent',
#  'zEil7zukF_Xtxq7sqIbyfA': 'Cleveland',
#  'I1Jhth-yxtz4mty6C2sWqg': 'Cleveland',
#  'RSAHZjr2yPZHZ-HhrgCrXQ': 'Cleveland',
#  '_YkzpKm4TAUfx8vckSTDgA': 'Cleveland',
#  'GBo2RbrSn9vdOrlQV8N8Sw': 'Cleveland',
#  'OKe55-f2tvTWDDPHV5cZtA': 'Mentor',
#  'FKZG5e-1CoMZ6kLUUVrqcQ': 'Cleveland',
#  '2n03U1y-9Lr3gl0CcMrHPA': 'Cleveland',
#  '07TtxrRM0b9qUBTWM5wNiA': 'Cleveland',
#  'DK57YibC5ShBmqQl97CKog': 'Tempe',
#  'IpReaQYuXO_nB07xnkHuNw': 'Cleveland',
#  'JdYkvy8lIodJ0vwJ4jzYYA': 'Bedford',
#  'x9g-i1DsB-VjSDGVOdRonA': 'Las Vegas',
#  'S6TvDZGLWHXjjCbGufE1QQ': 'Las Vegas',
#  '9dYJu74tHGBXrqi1cwvpUA': 'Las Vegas',
#  'Omgam9HDsT1BABnQBZepnw': 'Las Vegas',
#  'GnfXMcbFNEtE5oMUHINdnw': 'Las Vegas',
#  '2-XLTj0Cfd81_XlmHo02Aw': 'Phoenix',
#  'o3Zv4AolGeRr-xX7QhESUg': 'Las Vegas',
#  '9Rq-HzDMgiMvKo1wxRL-vg': 'Las Vegas',
#  'HuWEj615KvxRmjJq8JY7Ng': 'Las Vegas',
#  'IyU01Jx7GF3BcJ8w-_T2EQ': 'Las Vegas',
#  'Q4HP58l-YwqN4zryiZfZLw': 'Las Vegas',
#  'sfopdViM5iWt3UHeJENCrQ': 'Las Vegas',
#  '8yJwzY5kRfRTqg5UdoMAsA': 'Las Vegas',
#  'C6LV0p8L6IfBfh1YFRkWzQ': 'Las Vegas',
#  '2Fu4xzc4Z4SvRGDcfC0qfA': 'Las Vegas',
#  'ycVIThPWpZa2TfTlonf4fQ': 'Las Vegas',
#  'abMIw41Injf2rIMzMRUm7g': 'Las Vegas',
#  'MF6hGVEnsWqhoPLB0g0wTA': 'Las Vegas',
#  'A2N4y0VeZ-3TtmBVCSVVnQ': 'Las Vegas',
#  'qewG3X2O4X6JKskxyyqFwQ': 'Las Vegas',
#  'p4UcEYTLJyh96o1R8wrJaQ': 'Las Vegas',
#  'jH4i-q5cyHdLKDTJER0oew': 'Las Vegas',
#  'DiPRm3FaydnIidnzpvdmeA': 'Las Vegas',
#  'A0wA5x2BMj-5l2sWn1hxYQ': 'Las Vegas',
#  'DecPgdMdR5GPJIjkhRkWdw': 'Las Vegas',
#  'W9MPolPlUiUEXYfGnYiHEQ': 'Gilbert',
#  'pnrG47iwW26dDyHCwEr8UQ': 'Las Vegas',
#  'cyFYb0DSjZLlaVUp7dsD3w': 'Las Vegas',
#  'Z4cmKIau4Ie5ABXmj8wtwA': 'Las Vegas',
#  'OXWEpw02Yq52_lFJ6c2Lbg': 'Las Vegas',
#  '7k5I6nL-4ywRFEjrvr8FBQ': 'Las Vegas',
#  '3fuphUdxapoi7ags9kAZ6Q': 'Peoria',
#  '-IbGzbx2qsGjJHm78fbj8w': 'Stuttgart',
#  'bVkNsrA6W0LwEIVIKhiV-w': 'Stuttgart',
#  '4xqaWaXGO0el_jmTkm3c0A': 'Stuttgart',
#  '-c9G-JHNqrPY0_UU9j7BJA': 'Las Vegas',
#  'natSObJ4-jEev6rJRta7jA': 'Stuttgart',
#  'fp6wXrr5r3poOg6YhL4yvQ': 'Pittsburgh',
#  'Nc6Ng7WWY0sZHkDco9xcdw': 'Pittsburgh',
#  'qr12XETNuzne_rbpf0rmug': 'Pittsburgh',
#  '47f21XiNtNr2lRjCTbDPvA': 'Pittsburgh',
#  'tb7q_TIKu_pha2UFyneMmA': 'Cleveland',
#  '6-RXoqxa9L3FfBwkPLrtbw': 'Lakewood',
#  'Ty8k7Wj3kXMcCvOHsu-ptQ': 'Pittsburgh',
#  'J9mHpteG5XVio6NqcwHPCg': 'Montréal',
#  '5ZrFDFPJe8Qq3Zgue315oA': 'Cleveland',
#  'EEI1wjfuZIFshDl1ue9N8w': 'Cleveland',
#  'TjXqTqYOXAs8VKo_otj3lw': 'Cleveland',
#  'w1CYD3yWvajHzAbyNEjKuQ': 'Cleveland',
#  'wQSS08uB5vwIFS-ZM4BkdQ': 'Cleveland',
#  '_tHSAp8CgI14if0rnD2aHw': 'Las Vegas',
#  'jWUJsIt9FPwNYsl3ckJSoA': 'Cleveland',
#  'yK4njGSBfFpZhDuTxNpnLg': 'Edinburgh',
#  'LBcuPALypeSiLalEZa5JbA': 'Cleveland',
#  'J2ypbaPCF34BJ9IY7W0PLA': 'Cleveland',
#  'NkYR1Ejn4nQ1Mm5zwZYIPw': 'Cleveland',
#  'uO21Oi5nmXCeEQJOm28lQA': 'Cleveland',
#  'M_qwexE6ciWB4tJ_T1S6hQ': 'Cleveland',
#  'Kw5RHGNWA3ByBPzMv5oaRg': 'Pittsburgh',
#  'jpdigJmHkSdTy6QzB74wdw': 'Cleveland',
#  'cA7hAhlsXIotA4wRLdAZBQ': 'Twinsburg',
#  '5NAdHDoMQ63PYn3CVFC5BQ': 'Cuyahoga Falls',
#  'UCnk2nOq6cvtjboMWkhO9A': 'Etobicoke',
#  'yT1A5dsWOfkOb2-H76JQIQ': 'Hudson',
#  'MBf09zdFcOEnYA84aENzXA': 'Fairlawn',
#  '9PmUzfxz3vamMaTzGSesyg': 'Cleveland',
#  'R_43l6k5NWPy7eRv6cjYEQ': 'Cuyahoga Falls',
#  'wRzcrtxZj7MfzQnxrsqqfg': 'Mentor',
#  '3W-1dd1S6FylTU4QIFv-_Q': 'Cuyahoga Falls',
#  'yDirjgppPDkY2Bv60ok6bA': 'Cuyahoga Falls',
#  'RNUV7k_Ng4KdasXQMsOo6w': 'Hudson',
#  'aRzBh8fCzIRpMwijyN4sLw': 'Strongsville',
#  '93cD5Ev-PhA1Hut7wU0ctw': 'Cuyahoga Falls',
#  'oDoZe4gYUCb7ylHuhWFUow': 'Hudson',
#  '_MjgqPR1pvDnZZ6wCwabBQ': 'Kent',
#  'jLpQhFMglWJVqOQmAeDVRw': 'Cleveland',
#  'zypGaZmq7QhyV6TZfQrayg': 'Hudson',
#  'JMe2ZbikZVxRr6zEMIys1A': 'Kent',
#  'IkLWlkJek2e4It8Xt6vIwQ': 'Stow',
#  '51munej7rdZuB7KfPofhaA': 'Stow',
#  'NJqmAzerpbAIC0-VBclwgA': 'Cuyahoga Falls',
#  'jVx2YOXofzQJFL1pXVlVjg': 'Cuyahoga Falls',
#  'IL_vLMXtXw7RvzMB2N5h3w': 'Tallmadge',
#  '0GxKcZqhtzBbhHsTpcv1cg': 'Kent',
#  'S6gAeiubzQ7FJOdMvipsog': 'Macedonia',
#  'dD5vTDPzv_79m8_zZhc9hA': 'Cleveland',
#  'MZVSvbnghsV8uDM-TnPTKA': 'Fairlawn',
#  'zrEx0FVoPnk23Ny-uiOQSw': 'Cuyahoga Falls',
#  'JwQUSRWaxQjsXqTCKjkmbQ': 'Fairlawn',
#  'oV7mgTSAg1l26ieQ82yyVQ': 'Kent',
#  'gpV4qU5swBe2Eo7rRDEzjQ': 'Cleveland',
#  '7YqIOPRpr_ldE9xwfMZvDw': 'Cleveland',
#  'iNUH_vfvhzF7qxg9k0ofsQ': 'Aurora',
#  'hDSeawZ10uiqU8lZk6knUg': 'Stow',
#  'WoKCLSctS7G2547xKcED-Q': 'Pittsburgh',
#  'mDfSB8UtFoKxHkrtBcikhg': 'Las Vegas',
#  'RN0r5vFDP0DcmL7rmKD45Q': 'Cleveland',
#  'EQGF7Eyt65qhcCMxExDDNA': 'Kent',
#  '0GVyC7DxFsgnG8SeMPHPIA': 'Stow',
#  'Q2xIT2AWVPDnoknkghaDhg': 'Cuyahoga Falls',
#  'T9yWXszhzEKDVaNH09aa_w': 'Cleveland',
#  'gTE9uptqKvCDP9EZ8o7CmA': 'Cuyahoga Falls',
#  'DZChyIi8X3LMVLi86793VQ': 'Las Vegas',
#  'Q_QsCiaeQ5T_CfmidxEM7Q': 'Macedonia',
#  'bxtUw-buCnWybRbjc8cYYw': 'Rocky River',
#  'Y9oXy1NMExRpK3ac1mYCIw': 'Cleveland',
#  'PmgqNO0-5Y3e3UoR61TD7w': 'Brecksville',
#  'jBEOFvUNNGrG3AE0GmR-lg': 'Concord',
#  'H4_YPiEqsGYiUWWHx63h9Q': 'Stow',
#  'sreN9pXwVsTu1RMY9WnLpQ': 'Las Vegas',
#  'yV1PN-KG7vMKV9xyM4JToQ': 'Las Vegas',
#  '8a0GHVSVs3rSRtNIIR4rlw': 'Las Vegas',
#  '6ZC-0LfOAGwaFc5XPke74w': 'Las Vegas',
#  'p30VbeNZC6mzRUTL6lg69w': 'Las Vegas',
#  'D3GeQgpvMLwZCCHHdvyqaA': 'Phoenix',
#  'WM7MFrRP-7YFuGBAJ6quRQ': 'Las Vegas',
#  'UcXu-RZbJdjRhgFbfV-gXw': 'Las Vegas',
#  'zrqxV5G0bUIKvGObnMSNcA': 'Las Vegas',
#  'INNbJHteG02dS4VqoXoqKw': 'Las Vegas',
#  'EK4B8i9FJfw539XnWGAV0g': 'Las Vegas',
#  'eO1ZCFWJCZcETr9dfSydRg': 'Las Vegas',
#  '1wz1YTNiw9FJye3FRhj1AQ': 'Las Vegas',
#  'X1Cy1xsDawDiH0o9dmDIXA': 'Las Vegas',
#  'ee9YcVVzAuRLeQnY8ctDUg': 'Las Vegas',
#  'KqTnIUfwUto4Ka74JnzE8A': 'Las Vegas',
#  'IxrkMwtW1emHp7cifyq40A': 'Las Vegas',
#  'g_4zySOI_HisK5rG_2dw6Q': 'Las Vegas',
#  '4kM0hJIETOdBa2lQOnO8tQ': 'Las Vegas',
#  '43WiflwfTbmjizIfxvQ_jw': 'Las Vegas',
#  'm4e2fs8BObN0Cd69stfo9A': 'Chandler',
#  '23cjtl3AWJtxKL3O78-Djw': 'Las Vegas',
#  'G6Ni0mCoEaZ18ql5Sc2DZA': 'Las Vegas',
#  'U3sCAJc4_E3MGC1jGi19gQ': 'Las Vegas',
#  'LBnjYRrpTKgtGkW0ea7Ecg': 'Las Vegas',
#  'pxzs-Dy2hXTis-PuNCV37Q': 'Las Vegas',
#  'mdmdnlHLlZUvAE3-J5omCg': 'Las Vegas',
#  'FH3GgmOeAgXST37jG1-uWg': 'Las Vegas',
#  'hFFB48ybb4uSmh_CCeTljg': 'Las Vegas',
#  '0LgC7YzAQXBdbQZl0wgUnQ': 'Las Vegas',
#  'WoE8rLUh8Pu76lWw8soohQ': 'Las Vegas',
#  'J2ZTcQhg6_RJzOIiF_F3-A': 'Las Vegas',
#  '5elDILcQojTsX7GtU_N1Og': 'Las Vegas',
#  'vqoKrj-g8gcgpNMWZTZ0pg': 'Las Vegas',
#  'DuKiq3MPeLXESTZXRhJPHw': 'Las Vegas',
#  'ziiMYejVJAjbkRjSeAzrbQ': 'Las Vegas',
#  'tlTuLJOkeWga6vV3H6wnIg': 'Las Vegas',
#  'H-hgpOaBKD6JNfDCfqfBRw': 'Las Vegas',
#  '1cb8lvA4fluHn2j4Y5k45g': 'Las Vegas',
#  'aT_uTTaEJtWoJcqnSspUNg': 'Las Vegas',
#  'xsTc0-jryDgAE_HuOUA2Ng': 'Las Vegas',
#  'ywEB0MB_2U11NIGPs35pew': 'Las Vegas',
#  'TPKUUkAOlklihNGSOLSYGw': 'Las Vegas',
#  '5950WejSl2xLIa1bY1Du3Q': 'Las Vegas',
#  '6u49z3pjNVKs1O4rBmKXvA': 'Las Vegas',
#  'kRaJ_RuZqje3j5wOJe7R4w': 'Las Vegas',
#  'tJTv3DUwksO8FKYi48wmqQ': 'Las Vegas',
#  'ZtSzW0n2gSqWRAmQ_stkXQ': 'Las Vegas',
#  '_d74r_wGLwE4E8MxRKk-FQ': 'Las Vegas',
#  'EMqsN7DTFnR_VywY1SEc5w': 'Las Vegas',
#  'okwnuHs_LG62gq-QC0rpMw': 'Las Vegas',
#  'dY6GK465j-kLlrXalgdsNA': 'Las Vegas',
#  'knoQSph_vnj9SiugRB1BpA': 'Las Vegas',
#  'rvkVh-FNvg2fYSgHjG4mkQ': 'Las Vegas',
#  'Ktd04SKOw89dE2DPOCj2wQ': 'Las Vegas',
#  'U2f_VCU5GrfOZlZHsJjetg': 'Las Vegas',
#  'SvwD0zPT9So6cqgEsAhmWg': 'Las Vegas',
#  'KCD6daAp293FoOUoTjT_YA': 'Las Vegas',
#  'BNKWo55_3v5WNUgj-hsDZg': 'Toronto',
#  'UEhKQKMXGm-eOMvM-QD-AQ': 'Toronto',
#  'BGzavA_ddMr-jGmhArv7fg': 'Toronto',
#  'm-zwmnax4uMi8Fdy5iZlBA': 'Toronto',
#  '6UPWBTOfNoaGRahqTX14Ag': 'Toronto',
#  '-RCD8F7qbsLfzT3k1HtMxg': 'Toronto',
#  'uJ_gB_KrVeHbO82BiHc3mw': 'Toronto',
#  'HFECrzYDpgbS5EmTBtj2zQ': 'Las Vegas',
#  'eZZyuJDouIg4p-GYB3PV_A': 'Las Vegas',
#  'pngNlr9t4HObDgecGH_jaw': 'Las Vegas',
#  'kJOkmWQoL0Jy8iTea_V6og': 'Las Vegas',
#  'f81Y2EzuRqefayCrL1Ra3Q': 'Las Vegas',
#  'tH0uKD-vNwMoEc3Xk3Cbdg': 'Las Vegas',
#  'KL65Qt5OJzCt8LhioBw4Pg': 'Las Vegas',
#  'IDl8QswIXwI6Fr6KW3TbRw': 'Las Vegas',
#  'P62V2QfGKaubelwcdFbquA': 'Las Vegas',
#  'H3wPBzQCKCKiHcV7GZK4kg': 'Las Vegas',
#  'tL4NRC4uraCxjF8ZQ6GTTw': 'Las Vegas',
#  'MjdQiKzPs_JXizd0cRVFFw': 'Las Vegas',
#  'QEpNF4Hag6_W9Stc-1Frvg': 'Las Vegas',
#  'ELfzWgdf64VBLi5z1ECItw': 'Las Vegas',
#  'T3p9EIkwmsdlcX5Voi9XFQ': 'Las Vegas',
#  '6B9ICWLdY9C7gGPkRX93ZQ': 'Las Vegas',
#  'owbC7FP8SNAlwv6f9S5Stw': 'Las Vegas',
#  'Xsuv6bKcPUVDWih0DtEBbA': 'Las Vegas',
#  'cMts4uQI_MvF6Smk2erBLA': 'Las Vegas',
#  'BQkC6RneYfvfG6wRe0hsvQ': 'Las Vegas',
#  '0uo7LHVMFaDf1PkcGZprNg': 'Las Vegas',
#  'TEjjF9HcoR1hH017gWChjg': 'Las Vegas',
#  '8bn_HfSMq93mnd_ARHbvPg': 'Las Vegas',
#  'MSXlz6s0zOLsoXNg6pTXmQ': 'Las Vegas',
#  'UIdX_cI1awxvPH7kIFKpXw': 'Las Vegas',
#  'pohMK1VbTn9pod91xr1O9g': 'Las Vegas',
#  'Thew2366O9v9n8fKcQUYxQ': 'Las Vegas',
#  'S6cz25GMphB3QdpfCqOopQ': 'Las Vegas',
#  '9kEi_TTQSIgP52D7bto7EA': 'Las Vegas',
#  't_9U_94WuP_HUSEXnBgL1A': 'Las Vegas',
#  'yDbtyjFQKhqLhCFjfqQ08A': 'Las Vegas',
#  'IYk2DG_yBByVXxrVTo-BOg': 'Las Vegas',
#  'JADdo9NEeO5Az9aOYbyvZA': 'Las Vegas',
#  '-gO-X4lMH1eKnic4Z-bdCQ': 'Las Vegas',
#  'Kw6qblhrjvnZWfxMbUZokQ': 'Las Vegas',
#  'oNeyHF8MKilKZOUENpTk3Q': 'Las Vegas',
#  '5n-q5h4xYeJVSNk1TKMMeQ': 'Las Vegas',
#  'Zn8tgekH0oCfyk4SUtygoA': 'Las Vegas',
#  'cQC1gobqlD7FqR7MnQ5vug': 'Las Vegas',
#  'epkRB3J_oBEiyiwahvdmGg': 'Las Vegas',
#  'vivFH2_uIcOyqel-cHmxLA': 'Las Vegas',
#  'QNSL8oCbpiukOFIiX4cwmQ': 'Las Vegas',
#  'MNwZmi-SnicA5FNYVohMuw': 'Henderson',
#  '3yP6ieJBXvee4IpCZP3Jvw': 'Las Vegas',
#  'cpz2a48-fkOrnogYU3B3qQ': 'Las Vegas',
#  'opPpHVIp8SKHMJg3_y5Lew': 'Las Vegas',
#  '3Apvsrrf4wJuG4NdwIfXwA': 'Las Vegas',
#  'PYRIiQilTl1rkx83hm8ttA': 'Las Vegas',
#  '7KsXJ8MvU9VIG78W10s0SQ': 'Las Vegas',
#  'lml6FykyqAxURGJaGA8tdQ': 'Las Vegas',
#  'VD8Ox-akHloK3-QV3FxY-g': 'Las Vegas',
#  'AXuHgGQoNPkiSXTxHlQc0A': 'Las Vegas',
#  '0MtvvszO23F_GQGpaycwPA': 'Las Vegas',
#  'L8P5OWO1Jh4B2HLa1Fnbng': 'Las Vegas',
#  '8YaRW6wCKTm12Y87vdOp6g': 'Las Vegas',
#  'Ovmw7wC78-PD8BUDS3xM5Q': 'Las Vegas',
#  'OLn8EvPsu4hNug8V5PF2jA': 'Las Vegas',
#  'PePWIBvMyZ529fhrJLzgJQ': 'Las Vegas',
#  'ID7ccpPgEZ-BdqO0lSFqnQ': 'Las Vegas',
#  '1IAuZhwpbGl8jwN2DTkh-w': 'Las Vegas',
#  'o_cyGX4KjLPAraYn9yR4sA': 'Las Vegas',
#  'VUHoKtYxwzjF-PHk3LBn6Q': 'Las Vegas',
#  '7taWMcaCMQ1F2qVP1W3jCw': 'Las Vegas',
#  '1PQYGqxBCMpAIkmFJi9orw': 'Las Vegas',
#  'fxcyt4lx9XDgTPoAwW7roQ': 'Las Vegas',
#  'mAynnMvVJVdHLOFkmLyftg': 'Las Vegas',
#  'B1829_hxXSEpDPEDJtYeIw': 'Las Vegas',
#  'n0r_0HkCFaC175vXtIVcaQ': 'Henderson',
#  'IsR8VRaHhY9u3baj9m8SbQ': 'Las Vegas',
#  'J-MhhFKS_QFCjbIWJZGMQg': 'Las Vegas',
#  'lnMz0MZIAmCbclLJf7W9zQ': 'Las Vegas',
#  'KJ5gfIAWhE-IZ2DEqgS1nQ': 'Las Vegas',
#  'WSJJF_FyRz0osgBQgndlDg': 'Las Vegas',
#  'O-m_9oMnS45NrnxQ6JlNEA': 'Las Vegas',
#  'Ot-ODtUth8kGGujm_AscdQ': 'Las Vegas',
#  'os-sDQoh-hCt2Lg76z6ZUA': 'Las Vegas',
#  'O9pMFJSPg80YVzpMfNikxw': 'Las Vegas',
#  'MMXwhTMpy9W7rvpltcZglg': 'Las Vegas',
#  'EBveE4oDk6AYWNUEs937mg': 'Las Vegas',
#  'nS36RRnJJH-tZRJJ0Ovqzg': 'Las Vegas',
#  'K3aR8F0EVHULAcv6Pfkohw': 'Las Vegas',
#  'YApG_XpSXamn_itlOXQCBw': 'Las Vegas',
#  'LBD7yJez6snerKLrfJ8zcw': 'Las Vegas',
#  '4aRespr3mEIxRRoW9tio2A': 'Las Vegas',
#  'BT4KVJ28kfC_SRjS7SEIDQ': 'Las Vegas',
#  'xo0Mz2XOJL_mgIfSXagLXg': 'Las Vegas',
#  'hq5en1N5_OKK3Wx6RU2MTw': 'Las Vegas',
#  'w8N0kRTYwhmny3w2rO-pgA': 'Las Vegas',
#  'SD1zZNbpvlPntS2ykQYhOQ': 'Las Vegas',
#  'AIOKETfl1yvdRpI3dLFEYw': 'Las Vegas',
#  'BBEzfl86lYQjjsRa4JIn-g': 'Las Vegas',
#  'osvdz1TnYj50QcaV10_40Q': 'Las Vegas',
#  'VupFODj-mzL4wwipJKN9aw': 'Las Vegas',
#  'yU3Fjjta3OYMuK2YHQaGsA': 'Las Vegas',
#  'sFZjAfSAJ2hZ1CHLsJscxA': 'Las Vegas',
#  '_4fVJIqou00rrhU9OOJm2w': 'Las Vegas',
#  'iqsUoSxTpzAxt8AX8OgSZA': 'Las Vegas',
#  'oe5hzmFkN8bk0AzUEVGAqw': 'Las Vegas',
#  'q0N61z8h2dj3NxdU2_uwWA': 'Las Vegas',
#  'aK_IdNCJUdk2haKC3GuM_Q': 'Las Vegas',
#  'uERlyO-ASZag6XXouCrkhg': 'Las Vegas',
#  '9Ngo1ITdph18GePHuY-cRA': 'Las Vegas',
#  'jULSmuImPcuPjAEV84IBPQ': 'Las Vegas',
#  't9MtHB_hwKfwkW0Ie1yEoQ': 'Las Vegas',
#  'q6xgj7izoqXoTOWE2QyS1w': 'Las Vegas',
#  'acoVn9Vbp0fnuc3n-1M2EA': 'Las Vegas',
#  '7QLwWlojfQP0KUZrRRJwlw': 'Las Vegas',
#  'Cq0XdCjGFhzWMnVx8cb4Og': 'Las Vegas',
#  'o9D90Dr6z27JL6AlivsoFw': 'Las Vegas',
#  'DWpDDBJvO_fLqhwEwY2joQ': 'Las Vegas',
#  'ZuWAof5l6yKeft-F1QCWSQ': 'Las Vegas',
#  'p_6-Q9uAqn3i8NLjudkJ1A': 'Las Vegas',
#  'Yj9TXFf1qNuIyVFT3EHzDA': 'Las Vegas',
#  'lXZ7aziyUJyA6V0FlIR1Wg': 'Las Vegas',
#  '53PjYuZ4KJgiYNUnrG75hQ': 'Las Vegas',
#  '0k2UHwH241QP3f_QzvLmQw': 'Las Vegas',
#  'IWyLfneOLl37s1cW0Y85jg': 'Las Vegas',
#  '2B5r4nspOc_cLbg_l2n5tg': 'Las Vegas',
#  'O8G7YD1ohYIiqpq6e67nVA': 'Las Vegas',
#  'NZj2NbJTjWCZSyALTUyerA': 'Las Vegas',
#  'Wj0tIFlWz_1Uam1VDWYG5g': 'Las Vegas',
#  'sJYLKDza9ixc2kbGE3yHUw': 'Tempe',
#  'QHX3NxFAlda3I32taYzI8w': 'Las Vegas',
#  'isIgfxN4EezltNageG2Tzw': 'Las Vegas',
#  'E60LiRK4LHg7jquMZj6AOw': 'Las Vegas',
#  'WPe2n-x6xBNy2GIC5LcpdA': 'Las Vegas',
#  '4CCtrA2Db1utNAwIO1-aBQ': 'Las Vegas',
#  'Gab1_sLsjJLAJojoFd-d-g': 'Las Vegas',
#  'hOUXgXGHEBbleF01CTULIg': 'Las Vegas',
#  'pDW59eBTeawgV16s4731xQ': 'Las Vegas',
#  'EIx86LrVLyO4xoCF1bezVg': 'Las Vegas',
#  '6kR2tbwocCtgha0uFL4E7A': 'Las Vegas',
#  'n4HGMhXSTrM4j-ZX6UJjvQ': 'Henderson',
#  'f2c0zHEZf64GPxAcjP6pzw': 'Las Vegas',
#  'UDe9DmQMv5UV1a3O1DMZaw': 'Las Vegas',
#  'ag2TbtKPO9HTyLqxgBP3kQ': 'Las Vegas',
#  'DN-GanvndaTAAuVYCJ9f3Q': 'Henderson',
#  '4vbY4Iq8aqfuEcLuBPGvAA': 'Las Vegas',
#  ...}
